# %%
# %load_ext autoreload
# %autoreload 2
import os
from time import sleep
import numpy as np
import torch
import scipy
import pandas as pd
import random
from scipy import stats
from load_datasets import SynDataOneSrc
from models_train import *
from evaluation import Evaluation

# %%
if torch.cuda.is_available():
  # torch.set_default_tensor_type('torch.cuda.FloatTensor')
  print('Use ***GPU***')
  print(torch.cuda.get_device_properties(0).total_memory/1024/1024/1024,'GB')
else:
  print('Use CPU')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Use ***GPU***
# 14.726318359375 GB

# %% [markdown]
# # Train the model

# %%
# Configuration
OUTPUT_DIR = 'save_outputs/save_one_source_F'
dim_z = [35, 40, 45, 50, 55] # Varying z-dim
training_iter = 5000
transfer_flag = FLAGS_LEARN_TRANSFER
n_samples = 100
reg_alpha_w, lr_w = 1e-1, 1e-3
reg_alpha_y, reg_noise_y, lr_y =1e-2, 1e-1, 1e-3
reg_alpha_zy, lr_zy =1e-1, 1e-2
N_target_train = 50

# Lists to store results
learn_transfer_trans_factor_lst = []
learn_transfer_test_stats_lst = []
learn_transfer_test_stats_w_lst = []
learn_transfer_test_stats_y_lst = []

# Load data
source_size = 1000
dataset = SynDataOneSrc()
m = 1 # number of sources

# Create output directory
if not os.path.exists(OUTPUT_DIR):
  os.makedirs(OUTPUT_DIR)

# Train the models
for j in range(1):
  loss_lst = []
  trans_factors = []
  test_stats = []
  test_stats_w = []
  test_stats_y = []
  for i, (datas, datat) in enumerate(dataset.get_source_target(discrepancy_idx=j)):
  # for i in range(10):
  #   datas, datat = get_source_target(datas_lst, datat_lst, i, j)
    print('======================================================================================')
    print('Dataset: {}, Replicate: {}'.format(j+1, i+1))
    print('======================================================================================')
    sleep(0.5)
    # Source data to tensor
    Ws, Ys, Y_cfs, mus, Xs = datas[0][1].reshape(-1), datas[0][2].reshape(-1), datas[1][0].reshape(-1),\
                              np.concatenate((datas[1][1],datas[1][2]),axis=1), datas[0][0]
    Ts = len(Ys)
    xs = torch.from_numpy(Xs.reshape(Ts,-1)).float().to(device)
    ys = torch.from_numpy(Ys.reshape(-1,1)).float().to(device)
    ws = torch.from_numpy(Ws.reshape(-1,1)).float().to(device)

    # Target train data to tensor
    Wt, Yt, Y_cft, mut, Xt = datat[0][1].reshape(-1)[:N_target_train],\
                              datat[0][2].reshape(-1)[:N_target_train],\
                              datat[1][0].reshape(-1)[:N_target_train],\
                              np.concatenate((datat[1][1],datat[1][2]),axis=1)[:N_target_train],\
                              datat[0][0][:N_target_train,:]
    Tt = len(Yt)
    xt = torch.from_numpy(Xt.reshape(Tt,-1)).float().to(device)
    yt = torch.from_numpy(Yt.reshape(-1,1)).float().to(device)
    wt = torch.from_numpy(Wt.reshape(-1,1)).float().to(device)

    # Target test data to tensor
    Wtte, Ytte, Y_cftte, mutte, Xtte = datat[0][1].reshape(-1)[N_target_train:],\
                                        datat[0][2].reshape(-1)[N_target_train:],\
                                        datat[1][0].reshape(-1)[N_target_train:],\
                                        np.concatenate((datat[1][1],datat[1][2]),axis=1)[N_target_train:],\
                                        datat[0][0][:,:][N_target_train:]
    Ttte = len(Ytte)
    xtte = torch.from_numpy(Xtte.reshape(Ttte,-1)).float().to(device)
    ytte = torch.from_numpy(Ytte.reshape(-1,1)).float().to(device)
    wtte = torch.from_numpy(Wtte.reshape(-1,1)).float().to(device)

    # Train
    source_ranges = [(idx, idx+source_size) for idx in range(0,m*source_size,source_size)]
    domain_ranges =  source_ranges + [(m*source_size, m*source_size+N_target_train)]
    print('*** P(W|X)')
    model_w = trainW(train_x=torch.cat((xs,xt),dim=0),
                     train_w=torch.cat((ws,wt),dim=0).reshape(-1),
                     n_domains=m+1, domain_ranges=domain_ranges,
                     training_iter=training_iter, transfer_flag=transfer_flag,
                     reg_alpha=reg_alpha_w, lr=lr_w)
    w_samples = model_w.sample(x=xtte,n_samples=n_samples)

    print('*** P(Y|X,W)')
    model_y = trainY(train_x=torch.cat((xs,xt),dim=0),
                     train_y=torch.cat((ys,yt),dim=0),
                     train_w=torch.cat((ws,wt),dim=0),
                     n_domains=m+1, domain_ranges=domain_ranges,
                     training_iter=training_iter, transfer_flag=transfer_flag,
                     reg_alpha=reg_alpha_y, reg_noise=reg_noise_y, lr=lr_y)
    y_samples_xw = model_y.sample(x=xtte,w_samples=w_samples,n_samples=n_samples)

    print('*** P(Z|Y,X,W) and P(Y|W,Z)')
    model_zy = trainZY(train_x=torch.cat((xs,xt),dim=0),
                       train_y=torch.cat((ys,yt),dim=0),
                       train_w=torch.cat((ws,wt),dim=0),
                       n_domains=m+1, domain_ranges=domain_ranges, dim_z=dim_z[j],
                       training_iter=training_iter, transfer_flag=transfer_flag,
                       reg_alpha=reg_alpha_zy, lr=lr_zy)
    
    
    # Evaluate P(W|X)
    accur = torch.sum((model_w.pred(xtte, domain_ranges=[(0,0)]*m+[(0,xtte.shape[0])])>0)*1.0==wtte.reshape(-1))/len(xtte)
    test_stats_w.append(np.insert(model_w.trans_factor().cpu().detach().numpy(),0,accur.cpu().detach().numpy()))

    # Evaluate P(Y|X,W)
    mae = torch.mean(torch.abs(model_y.pred(xtte, wtte, domain_ranges=[(0,0)]*m+[(0,xtte.shape[0])]).reshape(-1) - ytte.reshape(-1)))
    rmse = torch.sqrt(torch.mean((model_y.pred(xtte, wtte, domain_ranges=[(0,0)]*m+[(0,xtte.shape[0])]).reshape(-1) - ytte.reshape(-1))**2))
    test_stats_y.append(np.concatenate((np.asarray([mae.cpu().detach().numpy(), rmse.cpu().detach().numpy()]),
                                        model_y.trans_factor().cpu().detach().numpy())))

    # Evaluate ATE, ITE
    y_samples_do0,_ = model_zy.sample_v2(xtte, do_w=torch.zeros((xtte.shape[0],1),device=device),
                                         y_samples=y_samples_xw, w_samples=w_samples, n_samples=n_samples)
    y_samples_do1,_ = model_zy.sample_v2(xtte, do_w=torch.ones((xtte.shape[0],1),device=device),
                                         y_samples=y_samples_xw, w_samples=w_samples, n_samples=n_samples)
    
    y_do0_mean = torch.mean(y_samples_do0,dim=1)
    y_do1_mean = torch.mean(y_samples_do1,dim=1)

    # Y0tte = (1-Wtte)*Ytte + Wtte*Y_cftte
    # Y1tte = Wtte*Ytte + (1-Wtte)*Y_cftte
    eval = Evaluation(m0=mutte[:,0], m1=mutte[:,1])
    abs_err = eval.absolute_err_ate(y_do0_mean.cpu().detach().numpy(), y_do1_mean.cpu().detach().numpy())
    pehe = eval.pehe(y_do0_mean.cpu().detach().numpy(), y_do1_mean.cpu().detach().numpy())

    test_stats.append((abs_err, pehe))
    trans_factors.append(np.concatenate((model_w.trans_factor().cpu().detach().numpy(), model_y.trans_factor().cpu().detach().numpy(),
                                        model_zy.trans_factor().cpu().detach().numpy())))
    
    # Save output of replicate i+1
    np.savez(OUTPUT_DIR + '/graphs_learn_transfer_varying_zdim_{}_replicate_{}.npz'.format(j+1,i+1),
            trans_factors=trans_factors,
            test_stats=test_stats,
            test_stats_w=test_stats_w,
            test_stats_y=test_stats_y)

  learn_transfer_trans_factor_lst.append(trans_factors)
  learn_transfer_test_stats_lst.append(test_stats)
  learn_transfer_test_stats_w_lst.append(test_stats_w)
  learn_transfer_test_stats_y_lst.append(test_stats_y)

  # Save outputs
  learn_transfer_stats_mean = np.array([np.mean(test_stats,axis=0) for test_stats in learn_transfer_test_stats_lst])
  learn_transfer_stats_stderr = np.array([stats.sem(test_stats,axis=0) for test_stats in learn_transfer_test_stats_lst])
  np.savez(OUTPUT_DIR + '/graphs_learn_transfer_stats_varying_zdim.npz',
          stats_mean=learn_transfer_stats_mean,
          stats_stderr=learn_transfer_stats_stderr)
  
  learn_transfer_trans_factor_mean = np.array([np.mean(test_stats,axis=0) for test_stats in learn_transfer_trans_factor_lst])
  learn_transfer_trans_factor_stderr = np.array([stats.sem(test_stats,axis=0) for test_stats in learn_transfer_trans_factor_lst])
  np.savez(OUTPUT_DIR + '/graphs_learn_transfer_trans_factor_varying_zdim.npz',
          stats_mean=learn_transfer_trans_factor_mean,
          stats_stderr=learn_transfer_trans_factor_stderr)
  
  learn_transfer_stats_w_mean = np.asarray([np.mean(test_stats,axis=0) for test_stats in  learn_transfer_test_stats_w_lst])
  learn_transfer_stats_w_stderr = np.asarray([stats.sem(test_stats,axis=0) for test_stats in  learn_transfer_test_stats_w_lst])
  np.savez(OUTPUT_DIR + '/graphs_w_learn_transfer_stats_varying_zdim.npz',
          stats_mean=learn_transfer_stats_w_mean,
          stats_stderr=learn_transfer_stats_w_stderr)
  
  learn_transfer_stats_y_mean = np.array([np.mean(test_stats,axis=0) for test_stats in learn_transfer_test_stats_y_lst])
  learn_transfer_stats_y_stderr = np.array([stats.sem(test_stats,axis=0) for test_stats in learn_transfer_test_stats_y_lst])
  np.savez(OUTPUT_DIR + '/graphs_y_learn_transfer_stats_varying_zdim.npz',
          stats_mean=learn_transfer_stats_y_mean,
          stats_stderr=learn_transfer_stats_y_stderr)
# Out:
# ======================================================================================
# Dataset: 1, Replicate: 1
# ======================================================================================
# *** P(W|X)
# Iter 100/5000 - Loss: 2130.879   Transfer Ratio: [0.478]
# Iter 200/5000 - Loss: 1519.055   Transfer Ratio: [0.461]
# Iter 300/5000 - Loss: 1141.298   Transfer Ratio: [0.45]
# Iter 400/5000 - Loss: 893.074   Transfer Ratio: [0.443]
# Iter 500/5000 - Loss: 725.176   Transfer Ratio: [0.439]
# Iter 600/5000 - Loss: 611.561   Transfer Ratio: [0.438]
# Iter 700/5000 - Loss: 534.223   Transfer Ratio: [0.439]
# Iter 800/5000 - Loss: 479.947   Transfer Ratio: [0.442]
# Iter 900/5000 - Loss: 440.229   Transfer Ratio: [0.447]
# Iter 1000/5000 - Loss: 410.026   Transfer Ratio: [0.452]
# Iter 1100/5000 - Loss: 386.351   Transfer Ratio: [0.459]
# Iter 1200/5000 - Loss: 367.381   Transfer Ratio: [0.467]
# Iter 1300/5000 - Loss: 351.947   Transfer Ratio: [0.475]
# Iter 1400/5000 - Loss: 339.253   Transfer Ratio: [0.484]
# Iter 1500/5000 - Loss: 328.709   Transfer Ratio: [0.493]
# Iter 1600/5000 - Loss: 319.855   Transfer Ratio: [0.503]
# Iter 1700/5000 - Loss: 312.318   Transfer Ratio: [0.513]
# Iter 1800/5000 - Loss: 305.790   Transfer Ratio: [0.523]
# Iter 1900/5000 - Loss: 300.025   Transfer Ratio: [0.533]
# Iter 2000/5000 - Loss: 294.833   Transfer Ratio: [0.543]
# Iter 2100/5000 - Loss: 290.072   Transfer Ratio: [0.553]
# Iter 2200/5000 - Loss: 285.637   Transfer Ratio: [0.564]
# Iter 2300/5000 - Loss: 281.459   Transfer Ratio: [0.574]
# Iter 2400/5000 - Loss: 277.488   Transfer Ratio: [0.585]
# Iter 2500/5000 - Loss: 273.691   Transfer Ratio: [0.595]
# Iter 2600/5000 - Loss: 270.047   Transfer Ratio: [0.606]
# Iter 2700/5000 - Loss: 266.540   Transfer Ratio: [0.616]
# Iter 2800/5000 - Loss: 263.161   Transfer Ratio: [0.627]
# Iter 2900/5000 - Loss: 259.904   Transfer Ratio: [0.638]
# Iter 3000/5000 - Loss: 256.765   Transfer Ratio: [0.648]
# Iter 3100/5000 - Loss: 253.742   Transfer Ratio: [0.659]
# Iter 3200/5000 - Loss: 250.835   Transfer Ratio: [0.669]
# Iter 3300/5000 - Loss: 248.043   Transfer Ratio: [0.68]
# Iter 3400/5000 - Loss: 245.367   Transfer Ratio: [0.69]
# Iter 3500/5000 - Loss: 242.807   Transfer Ratio: [0.7]
# Iter 3600/5000 - Loss: 240.362   Transfer Ratio: [0.71]
# Iter 3700/5000 - Loss: 238.034   Transfer Ratio: [0.72]
# Iter 3800/5000 - Loss: 235.822   Transfer Ratio: [0.729]
# Iter 3900/5000 - Loss: 233.725   Transfer Ratio: [0.739]
# Iter 4000/5000 - Loss: 231.742   Transfer Ratio: [0.748]
# Iter 4100/5000 - Loss: 229.873   Transfer Ratio: [0.756]
# Iter 4200/5000 - Loss: 228.114   Transfer Ratio: [0.765]
# Iter 4300/5000 - Loss: 226.464   Transfer Ratio: [0.773]
# Iter 4400/5000 - Loss: 224.920   Transfer Ratio: [0.781]
# Iter 4500/5000 - Loss: 223.479   Transfer Ratio: [0.789]
# Iter 4600/5000 - Loss: 222.136   Transfer Ratio: [0.796]
# Iter 4700/5000 - Loss: 220.889   Transfer Ratio: [0.803]
# Iter 4800/5000 - Loss: 219.732   Transfer Ratio: [0.81]
# Iter 4900/5000 - Loss: 218.662   Transfer Ratio: [0.817]
# Iter 5000/5000 - Loss: 217.675   Transfer Ratio: [0.823]
# *** P(Y|X,W)
# Iter 100/5000 - Loss: 13393.776   Transfer Ratio: [0.526]
# Iter 200/5000 - Loss: 9657.253   Transfer Ratio: [0.552]
# Iter 300/5000 - Loss: 7224.127   Transfer Ratio: [0.577]
# Iter 400/5000 - Loss: 5459.451   Transfer Ratio: [0.599]
# Iter 500/5000 - Loss: 4158.981   Transfer Ratio: [0.619]
# Iter 600/5000 - Loss: 3225.652   Transfer Ratio: [0.637]
# Iter 700/5000 - Loss: 2595.767   Transfer Ratio: [0.653]
# Iter 800/5000 - Loss: 2202.720   Transfer Ratio: [0.667]
# Iter 900/5000 - Loss: 1968.134   Transfer Ratio: [0.68]
# Iter 1000/5000 - Loss: 1822.178   Transfer Ratio: [0.692]
# Iter 1100/5000 - Loss: 1721.094   Transfer Ratio: [0.703]
# Iter 1200/5000 - Loss: 1643.862   Transfer Ratio: [0.713]
# Iter 1300/5000 - Loss: 1581.362   Transfer Ratio: [0.723]
# Iter 1400/5000 - Loss: 1529.294   Transfer Ratio: [0.732]
# Iter 1500/5000 - Loss: 1485.231   Transfer Ratio: [0.741]
# Iter 1600/5000 - Loss: 1447.579   Transfer Ratio: [0.749]
# Iter 1700/5000 - Loss: 1415.181   Transfer Ratio: [0.757]
# Iter 1800/5000 - Loss: 1387.143   Transfer Ratio: [0.765]
# Iter 1900/5000 - Loss: 1362.757   Transfer Ratio: [0.772]
# Iter 2000/5000 - Loss: 1341.442   Transfer Ratio: [0.779]
# Iter 2100/5000 - Loss: 1322.719   Transfer Ratio: [0.785]
# Iter 2200/5000 - Loss: 1306.190   Transfer Ratio: [0.792]
# Iter 2300/5000 - Loss: 1291.521   Transfer Ratio: [0.798]
# Iter 2400/5000 - Loss: 1278.430   Transfer Ratio: [0.803]
# Iter 2500/5000 - Loss: 1266.678   Transfer Ratio: [0.809]
# Iter 2600/5000 - Loss: 1256.065   Transfer Ratio: [0.814]
# Iter 2700/5000 - Loss: 1246.418   Transfer Ratio: [0.819]
# Iter 2800/5000 - Loss: 1237.590   Transfer Ratio: [0.824]
# Iter 2900/5000 - Loss: 1229.455   Transfer Ratio: [0.829]
# Iter 3000/5000 - Loss: 1221.907   Transfer Ratio: [0.833]
# Iter 3100/5000 - Loss: 1214.854   Transfer Ratio: [0.837]
# Iter 3200/5000 - Loss: 1208.217   Transfer Ratio: [0.842]
# Iter 3300/5000 - Loss: 1201.929   Transfer Ratio: [0.846]
# Iter 3400/5000 - Loss: 1195.934   Transfer Ratio: [0.85]
# Iter 3500/5000 - Loss: 1190.184   Transfer Ratio: [0.854]
# Iter 3600/5000 - Loss: 1184.638   Transfer Ratio: [0.857]
# Iter 3700/5000 - Loss: 1179.261   Transfer Ratio: [0.861]
# Iter 3800/5000 - Loss: 1174.026   Transfer Ratio: [0.864]
# Iter 3900/5000 - Loss: 1168.910   Transfer Ratio: [0.868]
# Iter 4000/5000 - Loss: 1163.892   Transfer Ratio: [0.871]
# Iter 4100/5000 - Loss: 1158.959   Transfer Ratio: [0.874]
# Iter 4200/5000 - Loss: 1154.097   Transfer Ratio: [0.877]
# Iter 4300/5000 - Loss: 1149.297   Transfer Ratio: [0.88]
# Iter 4400/5000 - Loss: 1144.553   Transfer Ratio: [0.883]
# Iter 4500/5000 - Loss: 1139.860   Transfer Ratio: [0.886]
# Iter 4600/5000 - Loss: 1135.214   Transfer Ratio: [0.889]
# Iter 4700/5000 - Loss: 1130.614   Transfer Ratio: [0.892]
# Iter 4800/5000 - Loss: 1126.059   Transfer Ratio: [0.895]
# Iter 4900/5000 - Loss: 1121.549   Transfer Ratio: [0.897]
# Iter 5000/5000 - Loss: 1117.084   Transfer Ratio: [0.9]
# *** P(Z|Y,X,W) and P(Y|W,Z)
# Iter 100/5000 - Loss: 81660.258   Transfer Ratio: [0.422]
# Iter 200/5000 - Loss: 65759.789   Transfer Ratio: [0.441]
# Iter 300/5000 - Loss: 36720.492   Transfer Ratio: [0.643]
# Iter 400/5000 - Loss: 32246.766   Transfer Ratio: [0.768]
# Iter 500/5000 - Loss: 30721.949   Transfer Ratio: [0.816]
# Iter 600/5000 - Loss: 30214.977   Transfer Ratio: [0.84]
# Iter 700/5000 - Loss: 29684.762   Transfer Ratio: [0.855]
# Iter 800/5000 - Loss: 29482.635   Transfer Ratio: [0.865]
# Iter 900/5000 - Loss: 29378.441   Transfer Ratio: [0.87]
# Iter 1000/5000 - Loss: 29082.086   Transfer Ratio: [0.874]
# Iter 1100/5000 - Loss: 29038.842   Transfer Ratio: [0.878]
# Iter 1200/5000 - Loss: 28771.627   Transfer Ratio: [0.882]
# Iter 1300/5000 - Loss: 28638.127   Transfer Ratio: [0.885]
# Iter 1400/5000 - Loss: 28575.441   Transfer Ratio: [0.886]
# Iter 1500/5000 - Loss: 28610.057   Transfer Ratio: [0.888]
# Iter 1600/5000 - Loss: 28408.012   Transfer Ratio: [0.889]
# Iter 1700/5000 - Loss: 28180.533   Transfer Ratio: [0.891]
# Iter 1800/5000 - Loss: 28262.926   Transfer Ratio: [0.894]
# Iter 1900/5000 - Loss: 28230.742   Transfer Ratio: [0.896]
# Iter 2000/5000 - Loss: 28244.951   Transfer Ratio: [0.898]
# Iter 2100/5000 - Loss: 27999.094   Transfer Ratio: [0.9]
# Iter 2200/5000 - Loss: 27999.793   Transfer Ratio: [0.901]
# Iter 2300/5000 - Loss: 28036.629   Transfer Ratio: [0.902]
# Iter 2400/5000 - Loss: 27825.758   Transfer Ratio: [0.904]
# Iter 2500/5000 - Loss: 27717.422   Transfer Ratio: [0.906]
# Iter 2600/5000 - Loss: 27633.803   Transfer Ratio: [0.908]
# Iter 2700/5000 - Loss: 27856.291   Transfer Ratio: [0.909]
# Iter 2800/5000 - Loss: 27699.863   Transfer Ratio: [0.91]
# Iter 2900/5000 - Loss: 27815.438   Transfer Ratio: [0.911]
# Iter 3000/5000 - Loss: 27422.129   Transfer Ratio: [0.911]
# Iter 3100/5000 - Loss: 27581.705   Transfer Ratio: [0.913]
# Iter 3200/5000 - Loss: 27593.332   Transfer Ratio: [0.914]
# Iter 3300/5000 - Loss: 27463.551   Transfer Ratio: [0.914]
# Iter 3400/5000 - Loss: 27510.674   Transfer Ratio: [0.917]
# Iter 3500/5000 - Loss: 27670.047   Transfer Ratio: [0.917]
# Iter 3600/5000 - Loss: 27321.881   Transfer Ratio: [0.918]
# Iter 3700/5000 - Loss: 27760.102   Transfer Ratio: [0.919]
# Iter 3800/5000 - Loss: 27438.484   Transfer Ratio: [0.921]
# Iter 3900/5000 - Loss: 27522.920   Transfer Ratio: [0.923]
# Iter 4000/5000 - Loss: 27711.066   Transfer Ratio: [0.923]
# Iter 4100/5000 - Loss: 27571.510   Transfer Ratio: [0.921]
# Iter 4200/5000 - Loss: 27622.236   Transfer Ratio: [0.923]
# Iter 4300/5000 - Loss: 27284.715   Transfer Ratio: [0.923]
# Iter 4400/5000 - Loss: 27539.834   Transfer Ratio: [0.924]
# Iter 4500/5000 - Loss: 27338.480   Transfer Ratio: [0.925]
# Iter 4600/5000 - Loss: 27683.557   Transfer Ratio: [0.926]
# Iter 4700/5000 - Loss: 27592.105   Transfer Ratio: [0.928]
# Iter 4800/5000 - Loss: 27269.029   Transfer Ratio: [0.927]
# Iter 4900/5000 - Loss: 27513.227   Transfer Ratio: [0.929]
# Iter 5000/5000 - Loss: 27295.834   Transfer Ratio: [0.929]
# ======================================================================================
# Dataset: 1, Replicate: 2
# ======================================================================================
# *** P(W|X)
# Iter 100/5000 - Loss: 2241.854   Transfer Ratio: [0.477]
# Iter 200/5000 - Loss: 1606.266   Transfer Ratio: [0.459]
# Iter 300/5000 - Loss: 1196.468   Transfer Ratio: [0.446]
# Iter 400/5000 - Loss: 913.095   Transfer Ratio: [0.436]
# Iter 500/5000 - Loss: 714.120   Transfer Ratio: [0.43]
# Iter 600/5000 - Loss: 582.945   Transfer Ratio: [0.428]
# Iter 700/5000 - Loss: 501.881   Transfer Ratio: [0.427]
# Iter 800/5000 - Loss: 450.226   Transfer Ratio: [0.429]
# Iter 900/5000 - Loss: 414.444   Transfer Ratio: [0.432]
# Iter 1000/5000 - Loss: 387.697   Transfer Ratio: [0.435]
# Iter 1100/5000 - Loss: 366.629   Transfer Ratio: [0.44]
# Iter 1200/5000 - Loss: 349.492   Transfer Ratio: [0.444]
# Iter 1300/5000 - Loss: 335.291   Transfer Ratio: [0.449]
# Iter 1400/5000 - Loss: 323.401   Transfer Ratio: [0.455]
# Iter 1500/5000 - Loss: 313.379   Transfer Ratio: [0.46]
# Iter 1600/5000 - Loss: 304.879   Transfer Ratio: [0.466]
# Iter 1700/5000 - Loss: 297.607   Transfer Ratio: [0.472]
# Iter 1800/5000 - Loss: 291.308   Transfer Ratio: [0.478]
# Iter 1900/5000 - Loss: 285.763   Transfer Ratio: [0.485]
# Iter 2000/5000 - Loss: 280.791   Transfer Ratio: [0.491]
# Iter 2100/5000 - Loss: 276.247   Transfer Ratio: [0.498]
# Iter 2200/5000 - Loss: 272.024   Transfer Ratio: [0.505]
# Iter 2300/5000 - Loss: 268.044   Transfer Ratio: [0.512]
# Iter 2400/5000 - Loss: 264.253   Transfer Ratio: [0.519]
# Iter 2500/5000 - Loss: 260.619   Transfer Ratio: [0.526]
# Iter 2600/5000 - Loss: 257.118   Transfer Ratio: [0.534]
# Iter 2700/5000 - Loss: 253.740   Transfer Ratio: [0.542]
# Iter 2800/5000 - Loss: 250.475   Transfer Ratio: [0.55]
# Iter 2900/5000 - Loss: 247.320   Transfer Ratio: [0.558]
# Iter 3000/5000 - Loss: 244.274   Transfer Ratio: [0.567]
# Iter 3100/5000 - Loss: 241.335   Transfer Ratio: [0.575]
# Iter 3200/5000 - Loss: 238.505   Transfer Ratio: [0.584]
# Iter 3300/5000 - Loss: 235.784   Transfer Ratio: [0.593]
# Iter 3400/5000 - Loss: 233.174   Transfer Ratio: [0.602]
# Iter 3500/5000 - Loss: 230.676   Transfer Ratio: [0.611]
# Iter 3600/5000 - Loss: 228.291   Transfer Ratio: [0.621]
# Iter 3700/5000 - Loss: 226.021   Transfer Ratio: [0.63]
# Iter 3800/5000 - Loss: 223.865   Transfer Ratio: [0.639]
# Iter 3900/5000 - Loss: 221.825   Transfer Ratio: [0.649]
# Iter 4000/5000 - Loss: 219.898   Transfer Ratio: [0.658]
# Iter 4100/5000 - Loss: 218.084   Transfer Ratio: [0.667]
# Iter 4200/5000 - Loss: 216.381   Transfer Ratio: [0.676]
# Iter 4300/5000 - Loss: 214.787   Transfer Ratio: [0.685]
# Iter 4400/5000 - Loss: 213.298   Transfer Ratio: [0.694]
# Iter 4500/5000 - Loss: 211.912   Transfer Ratio: [0.702]
# Iter 4600/5000 - Loss: 210.625   Transfer Ratio: [0.711]
# Iter 4700/5000 - Loss: 209.432   Transfer Ratio: [0.719]
# Iter 4800/5000 - Loss: 208.330   Transfer Ratio: [0.727]
# Iter 4900/5000 - Loss: 207.313   Transfer Ratio: [0.735]
# Iter 5000/5000 - Loss: 206.377   Transfer Ratio: [0.743]
# *** P(Y|X,W)
# Iter 100/5000 - Loss: 12983.802   Transfer Ratio: [0.497]
# Iter 200/5000 - Loss: 9058.396   Transfer Ratio: [0.529]
# Iter 300/5000 - Loss: 6481.111   Transfer Ratio: [0.561]
# Iter 400/5000 - Loss: 4729.390   Transfer Ratio: [0.589]
# Iter 500/5000 - Loss: 3551.284   Transfer Ratio: [0.615]
# Iter 600/5000 - Loss: 2785.473   Transfer Ratio: [0.637]
# Iter 700/5000 - Loss: 2308.419   Transfer Ratio: [0.657]
# Iter 800/5000 - Loss: 2015.929   Transfer Ratio: [0.674]
# Iter 900/5000 - Loss: 1829.064   Transfer Ratio: [0.689]
# Iter 1000/5000 - Loss: 1699.970   Transfer Ratio: [0.703]
# Iter 1100/5000 - Loss: 1604.723   Transfer Ratio: [0.715]
# Iter 1200/5000 - Loss: 1531.823   Transfer Ratio: [0.726]
# Iter 1300/5000 - Loss: 1474.904   Transfer Ratio: [0.736]
# Iter 1400/5000 - Loss: 1429.759   Transfer Ratio: [0.746]
# Iter 1500/5000 - Loss: 1393.348   Transfer Ratio: [0.754]
# Iter 1600/5000 - Loss: 1363.425   Transfer Ratio: [0.762]
# Iter 1700/5000 - Loss: 1338.339   Transfer Ratio: [0.769]
# Iter 1800/5000 - Loss: 1316.888   Transfer Ratio: [0.776]
# Iter 1900/5000 - Loss: 1298.206   Transfer Ratio: [0.782]
# Iter 2000/5000 - Loss: 1281.675   Transfer Ratio: [0.788]
# Iter 2100/5000 - Loss: 1266.856   Transfer Ratio: [0.794]
# Iter 2200/5000 - Loss: 1253.431   Transfer Ratio: [0.799]
# Iter 2300/5000 - Loss: 1241.172   Transfer Ratio: [0.804]
# Iter 2400/5000 - Loss: 1229.907   Transfer Ratio: [0.808]
# Iter 2500/5000 - Loss: 1219.502   Transfer Ratio: [0.813]
# Iter 2600/5000 - Loss: 1209.851   Transfer Ratio: [0.817]
# Iter 2700/5000 - Loss: 1200.865   Transfer Ratio: [0.821]
# Iter 2800/5000 - Loss: 1192.466   Transfer Ratio: [0.824]
# Iter 2900/5000 - Loss: 1184.589   Transfer Ratio: [0.828]
# Iter 3000/5000 - Loss: 1177.174   Transfer Ratio: [0.831]
# Iter 3100/5000 - Loss: 1170.166   Transfer Ratio: [0.834]
# Iter 3200/5000 - Loss: 1163.516   Transfer Ratio: [0.837]
# Iter 3300/5000 - Loss: 1157.181   Transfer Ratio: [0.84]
# Iter 3400/5000 - Loss: 1151.120   Transfer Ratio: [0.843]
# Iter 3500/5000 - Loss: 1145.298   Transfer Ratio: [0.845]
# Iter 3600/5000 - Loss: 1139.681   Transfer Ratio: [0.847]
# Iter 3700/5000 - Loss: 1134.243   Transfer Ratio: [0.85]
# Iter 3800/5000 - Loss: 1128.955   Transfer Ratio: [0.852]
# Iter 3900/5000 - Loss: 1123.798   Transfer Ratio: [0.854]
# Iter 4000/5000 - Loss: 1118.750   Transfer Ratio: [0.856]
# Iter 4100/5000 - Loss: 1113.796   Transfer Ratio: [0.857]
# Iter 4200/5000 - Loss: 1108.921   Transfer Ratio: [0.859]
# Iter 4300/5000 - Loss: 1104.114   Transfer Ratio: [0.86]
# Iter 4400/5000 - Loss: 1099.366   Transfer Ratio: [0.862]
# Iter 4500/5000 - Loss: 1094.667   Transfer Ratio: [0.863]
# Iter 4600/5000 - Loss: 1090.014   Transfer Ratio: [0.864]
# Iter 4700/5000 - Loss: 1085.400   Transfer Ratio: [0.865]
# Iter 4800/5000 - Loss: 1080.822   Transfer Ratio: [0.866]
# Iter 4900/5000 - Loss: 1076.278   Transfer Ratio: [0.866]
# Iter 5000/5000 - Loss: 1071.765   Transfer Ratio: [0.867]
# *** P(Z|Y,X,W) and P(Y|W,Z)
# Iter 100/5000 - Loss: 83198.820   Transfer Ratio: [0.419]
# Iter 200/5000 - Loss: 68309.484   Transfer Ratio: [0.425]
# Iter 300/5000 - Loss: 38023.352   Transfer Ratio: [0.522]
# Iter 400/5000 - Loss: 32323.439   Transfer Ratio: [0.633]
# Iter 500/5000 - Loss: 30953.650   Transfer Ratio: [0.682]
# Iter 600/5000 - Loss: 30330.666   Transfer Ratio: [0.709]
# Iter 700/5000 - Loss: 29931.055   Transfer Ratio: [0.728]
# Iter 800/5000 - Loss: 29651.049   Transfer Ratio: [0.742]
# Iter 900/5000 - Loss: 29611.777   Transfer Ratio: [0.752]
# Iter 1000/5000 - Loss: 29275.020   Transfer Ratio: [0.762]
# Iter 1100/5000 - Loss: 29107.805   Transfer Ratio: [0.768]
# Iter 1200/5000 - Loss: 28940.848   Transfer Ratio: [0.774]
# Iter 1300/5000 - Loss: 28925.613   Transfer Ratio: [0.781]
# Iter 1400/5000 - Loss: 28776.457   Transfer Ratio: [0.785]
# Iter 1500/5000 - Loss: 28678.072   Transfer Ratio: [0.791]
# Iter 1600/5000 - Loss: 28638.066   Transfer Ratio: [0.796]
# Iter 1700/5000 - Loss: 28238.172   Transfer Ratio: [0.802]
# Iter 1800/5000 - Loss: 28398.344   Transfer Ratio: [0.809]
# Iter 1900/5000 - Loss: 28281.059   Transfer Ratio: [0.814]
# Iter 2000/5000 - Loss: 28306.791   Transfer Ratio: [0.818]
# Iter 2100/5000 - Loss: 28168.596   Transfer Ratio: [0.822]
# Iter 2200/5000 - Loss: 27897.361   Transfer Ratio: [0.824]
# Iter 2300/5000 - Loss: 27935.523   Transfer Ratio: [0.828]
# Iter 2400/5000 - Loss: 27817.543   Transfer Ratio: [0.833]
# Iter 2500/5000 - Loss: 27621.246   Transfer Ratio: [0.835]
# Iter 2600/5000 - Loss: 27793.104   Transfer Ratio: [0.837]
# Iter 2700/5000 - Loss: 27717.918   Transfer Ratio: [0.839]
# Iter 2800/5000 - Loss: 27876.988   Transfer Ratio: [0.842]
# Iter 2900/5000 - Loss: 27621.340   Transfer Ratio: [0.845]
# Iter 3000/5000 - Loss: 27658.381   Transfer Ratio: [0.848]
# Iter 3100/5000 - Loss: 27576.465   Transfer Ratio: [0.849]
# Iter 3200/5000 - Loss: 27823.607   Transfer Ratio: [0.852]
# Iter 3300/5000 - Loss: 27660.102   Transfer Ratio: [0.852]
# Iter 3400/5000 - Loss: 27671.828   Transfer Ratio: [0.854]
# Iter 3500/5000 - Loss: 27568.430   Transfer Ratio: [0.854]
# Iter 3600/5000 - Loss: 27535.969   Transfer Ratio: [0.854]
# Iter 3700/5000 - Loss: 27712.051   Transfer Ratio: [0.858]
# Iter 3800/5000 - Loss: 27525.539   Transfer Ratio: [0.86]
# Iter 3900/5000 - Loss: 27583.732   Transfer Ratio: [0.86]
# Iter 4000/5000 - Loss: 27581.537   Transfer Ratio: [0.86]
# Iter 4100/5000 - Loss: 27534.408   Transfer Ratio: [0.864]
# Iter 4200/5000 - Loss: 27505.783   Transfer Ratio: [0.868]
# Iter 4300/5000 - Loss: 27525.045   Transfer Ratio: [0.866]
# Iter 4400/5000 - Loss: 27547.586   Transfer Ratio: [0.867]
# Iter 4500/5000 - Loss: 27445.514   Transfer Ratio: [0.868]
# Iter 4600/5000 - Loss: 27620.531   Transfer Ratio: [0.87]
# Iter 4700/5000 - Loss: 27476.309   Transfer Ratio: [0.87]
# Iter 4800/5000 - Loss: 27437.881   Transfer Ratio: [0.872]
# Iter 4900/5000 - Loss: 27365.236   Transfer Ratio: [0.873]
# Iter 5000/5000 - Loss: 27527.672   Transfer Ratio: [0.875]
# ======================================================================================
# Dataset: 1, Replicate: 3
# ======================================================================================
# *** P(W|X)
# Iter 100/5000 - Loss: 1918.295   Transfer Ratio: [0.477]
# Iter 200/5000 - Loss: 1386.046   Transfer Ratio: [0.46]
# Iter 300/5000 - Loss: 1063.925   Transfer Ratio: [0.447]
# Iter 400/5000 - Loss: 854.030   Transfer Ratio: [0.438]
# Iter 500/5000 - Loss: 710.950   Transfer Ratio: [0.432]
# Iter 600/5000 - Loss: 611.225   Transfer Ratio: [0.429]
# Iter 700/5000 - Loss: 540.045   Transfer Ratio: [0.427]
# Iter 800/5000 - Loss: 487.626   Transfer Ratio: [0.427]
# Iter 900/5000 - Loss: 447.743   Transfer Ratio: [0.429]
# Iter 1000/5000 - Loss: 416.435   Transfer Ratio: [0.431]
# Iter 1100/5000 - Loss: 391.192   Transfer Ratio: [0.435]
# Iter 1200/5000 - Loss: 370.442   Transfer Ratio: [0.439]
# Iter 1300/5000 - Loss: 353.184   Transfer Ratio: [0.444]
# Iter 1400/5000 - Loss: 338.752   Transfer Ratio: [0.45]
# Iter 1500/5000 - Loss: 326.655   Transfer Ratio: [0.456]
# Iter 1600/5000 - Loss: 316.493   Transfer Ratio: [0.462]
# Iter 1700/5000 - Loss: 307.914   Transfer Ratio: [0.469]
# Iter 1800/5000 - Loss: 300.603   Transfer Ratio: [0.476]
# Iter 1900/5000 - Loss: 294.279   Transfer Ratio: [0.482]
# Iter 2000/5000 - Loss: 288.707   Transfer Ratio: [0.489]
# Iter 2100/5000 - Loss: 283.697   Transfer Ratio: [0.496]
# Iter 2200/5000 - Loss: 279.105   Transfer Ratio: [0.503]
# Iter 2300/5000 - Loss: 274.827   Transfer Ratio: [0.51]
# Iter 2400/5000 - Loss: 270.791   Transfer Ratio: [0.518]
# Iter 2500/5000 - Loss: 266.950   Transfer Ratio: [0.525]
# Iter 2600/5000 - Loss: 263.275   Transfer Ratio: [0.532]
# Iter 2700/5000 - Loss: 259.746   Transfer Ratio: [0.54]
# Iter 2800/5000 - Loss: 256.354   Transfer Ratio: [0.548]
# Iter 2900/5000 - Loss: 253.093   Transfer Ratio: [0.556]
# Iter 3000/5000 - Loss: 249.959   Transfer Ratio: [0.564]
# Iter 3100/5000 - Loss: 246.952   Transfer Ratio: [0.572]
# Iter 3200/5000 - Loss: 244.072   Transfer Ratio: [0.581]
# Iter 3300/5000 - Loss: 241.318   Transfer Ratio: [0.589]
# Iter 3400/5000 - Loss: 238.691   Transfer Ratio: [0.598]
# Iter 3500/5000 - Loss: 236.191   Transfer Ratio: [0.607]
# Iter 3600/5000 - Loss: 233.817   Transfer Ratio: [0.615]
# Iter 3700/5000 - Loss: 231.569   Transfer Ratio: [0.624]
# Iter 3800/5000 - Loss: 229.447   Transfer Ratio: [0.632]
# Iter 3900/5000 - Loss: 227.447   Transfer Ratio: [0.641]
# Iter 4000/5000 - Loss: 225.568   Transfer Ratio: [0.65]
# Iter 4100/5000 - Loss: 223.807   Transfer Ratio: [0.658]
# Iter 4200/5000 - Loss: 222.161   Transfer Ratio: [0.666]
# Iter 4300/5000 - Loss: 220.627   Transfer Ratio: [0.675]
# Iter 4400/5000 - Loss: 219.199   Transfer Ratio: [0.683]
# Iter 4500/5000 - Loss: 217.874   Transfer Ratio: [0.691]
# Iter 4600/5000 - Loss: 216.648   Transfer Ratio: [0.698]
# Iter 4700/5000 - Loss: 215.514   Transfer Ratio: [0.706]
# Iter 4800/5000 - Loss: 214.469   Transfer Ratio: [0.714]
# Iter 4900/5000 - Loss: 213.507   Transfer Ratio: [0.721]
# Iter 5000/5000 - Loss: 212.624   Transfer Ratio: [0.728]
# *** P(Y|X,W)
# Iter 100/5000 - Loss: 11288.700   Transfer Ratio: [0.486]
# Iter 200/5000 - Loss: 7797.754   Transfer Ratio: [0.497]
# Iter 300/5000 - Loss: 5541.324   Transfer Ratio: [0.521]
# Iter 400/5000 - Loss: 4081.112   Transfer Ratio: [0.551]
# Iter 500/5000 - Loss: 3161.925   Transfer Ratio: [0.579]
# Iter 600/5000 - Loss: 2612.387   Transfer Ratio: [0.606]
# Iter 700/5000 - Loss: 2294.202   Transfer Ratio: [0.628]
# Iter 800/5000 - Loss: 2102.764   Transfer Ratio: [0.648]
# Iter 900/5000 - Loss: 1974.838   Transfer Ratio: [0.664]
# Iter 1000/5000 - Loss: 1879.633   Transfer Ratio: [0.679]
# Iter 1100/5000 - Loss: 1803.629   Transfer Ratio: [0.692]
# Iter 1200/5000 - Loss: 1740.598   Transfer Ratio: [0.703]
# Iter 1300/5000 - Loss: 1687.184   Transfer Ratio: [0.713]
# Iter 1400/5000 - Loss: 1641.286   Transfer Ratio: [0.723]
# Iter 1500/5000 - Loss: 1601.441   Transfer Ratio: [0.732]
# Iter 1600/5000 - Loss: 1566.578   Transfer Ratio: [0.74]
# Iter 1700/5000 - Loss: 1535.879   Transfer Ratio: [0.747]
# Iter 1800/5000 - Loss: 1508.706   Transfer Ratio: [0.754]
# Iter 1900/5000 - Loss: 1484.546   Transfer Ratio: [0.761]
# Iter 2000/5000 - Loss: 1462.982   Transfer Ratio: [0.767]
# Iter 2100/5000 - Loss: 1443.668   Transfer Ratio: [0.773]
# Iter 2200/5000 - Loss: 1426.311   Transfer Ratio: [0.778]
# Iter 2300/5000 - Loss: 1410.664   Transfer Ratio: [0.784]
# Iter 2400/5000 - Loss: 1396.514   Transfer Ratio: [0.789]
# Iter 2500/5000 - Loss: 1383.676   Transfer Ratio: [0.794]
# Iter 2600/5000 - Loss: 1371.991   Transfer Ratio: [0.798]
# Iter 2700/5000 - Loss: 1361.318   Transfer Ratio: [0.803]
# Iter 2800/5000 - Loss: 1351.533   Transfer Ratio: [0.808]
# Iter 2900/5000 - Loss: 1342.529   Transfer Ratio: [0.812]
# Iter 3000/5000 - Loss: 1334.209   Transfer Ratio: [0.816]
# Iter 3100/5000 - Loss: 1326.489   Transfer Ratio: [0.821]
# Iter 3200/5000 - Loss: 1319.295   Transfer Ratio: [0.825]
# Iter 3300/5000 - Loss: 1312.561   Transfer Ratio: [0.829]
# Iter 3400/5000 - Loss: 1306.230   Transfer Ratio: [0.833]
# Iter 3500/5000 - Loss: 1300.252   Transfer Ratio: [0.837]
# Iter 3600/5000 - Loss: 1294.583   Transfer Ratio: [0.841]
# Iter 3700/5000 - Loss: 1289.185   Transfer Ratio: [0.845]
# Iter 3800/5000 - Loss: 1284.025   Transfer Ratio: [0.848]
# Iter 3900/5000 - Loss: 1279.075   Transfer Ratio: [0.852]
# Iter 4000/5000 - Loss: 1274.310   Transfer Ratio: [0.856]
# Iter 4100/5000 - Loss: 1269.710   Transfer Ratio: [0.859]
# Iter 4200/5000 - Loss: 1265.256   Transfer Ratio: [0.863]
# Iter 4300/5000 - Loss: 1260.932   Transfer Ratio: [0.867]
# Iter 4400/5000 - Loss: 1256.726   Transfer Ratio: [0.87]
# Iter 4500/5000 - Loss: 1252.623   Transfer Ratio: [0.874]
# Iter 4600/5000 - Loss: 1248.613   Transfer Ratio: [0.877]
# Iter 4700/5000 - Loss: 1244.686   Transfer Ratio: [0.88]
# Iter 4800/5000 - Loss: 1240.832   Transfer Ratio: [0.883]
# Iter 4900/5000 - Loss: 1237.043   Transfer Ratio: [0.886]
# Iter 5000/5000 - Loss: 1233.309   Transfer Ratio: [0.889]
# *** P(Z|Y,X,W) and P(Y|W,Z)
# Iter 100/5000 - Loss: 84252.195   Transfer Ratio: [0.421]
# Iter 200/5000 - Loss: 68204.195   Transfer Ratio: [0.425]
# Iter 300/5000 - Loss: 35428.746   Transfer Ratio: [0.505]
# Iter 400/5000 - Loss: 32016.535   Transfer Ratio: [0.592]
# Iter 500/5000 - Loss: 30845.318   Transfer Ratio: [0.644]
# Iter 600/5000 - Loss: 30307.281   Transfer Ratio: [0.677]
# Iter 700/5000 - Loss: 29956.941   Transfer Ratio: [0.701]
# Iter 800/5000 - Loss: 29684.564   Transfer Ratio: [0.719]
# Iter 900/5000 - Loss: 29437.592   Transfer Ratio: [0.734]
# Iter 1000/5000 - Loss: 29460.102   Transfer Ratio: [0.747]
# Iter 1100/5000 - Loss: 29091.592   Transfer Ratio: [0.758]
# Iter 1200/5000 - Loss: 29060.930   Transfer Ratio: [0.767]
# Iter 1300/5000 - Loss: 28659.463   Transfer Ratio: [0.774]
# Iter 1400/5000 - Loss: 28737.598   Transfer Ratio: [0.781]
# Iter 1500/5000 - Loss: 28771.352   Transfer Ratio: [0.787]
# Iter 1600/5000 - Loss: 28748.193   Transfer Ratio: [0.795]
# Iter 1700/5000 - Loss: 28276.723   Transfer Ratio: [0.801]
# Iter 1800/5000 - Loss: 28505.646   Transfer Ratio: [0.807]
# Iter 1900/5000 - Loss: 28333.211   Transfer Ratio: [0.812]
# Iter 2000/5000 - Loss: 28182.904   Transfer Ratio: [0.817]
# Iter 2100/5000 - Loss: 28002.135   Transfer Ratio: [0.821]
# Iter 2200/5000 - Loss: 27977.250   Transfer Ratio: [0.824]
# Iter 2300/5000 - Loss: 27892.684   Transfer Ratio: [0.828]
# Iter 2400/5000 - Loss: 28017.238   Transfer Ratio: [0.83]
# Iter 2500/5000 - Loss: 27893.564   Transfer Ratio: [0.833]
# Iter 2600/5000 - Loss: 27895.736   Transfer Ratio: [0.834]
# Iter 2700/5000 - Loss: 27832.990   Transfer Ratio: [0.837]
# Iter 2800/5000 - Loss: 27819.254   Transfer Ratio: [0.84]
# Iter 2900/5000 - Loss: 27962.500   Transfer Ratio: [0.842]
# Iter 3000/5000 - Loss: 27840.955   Transfer Ratio: [0.844]
# Iter 3100/5000 - Loss: 27702.117   Transfer Ratio: [0.846]
# Iter 3200/5000 - Loss: 27588.570   Transfer Ratio: [0.846]
# Iter 3300/5000 - Loss: 27582.516   Transfer Ratio: [0.847]
# Iter 3400/5000 - Loss: 27640.768   Transfer Ratio: [0.849]
# Iter 3500/5000 - Loss: 27617.158   Transfer Ratio: [0.854]
# Iter 3600/5000 - Loss: 27669.188   Transfer Ratio: [0.858]
# Iter 3700/5000 - Loss: 27600.430   Transfer Ratio: [0.859]
# Iter 3800/5000 - Loss: 27379.393   Transfer Ratio: [0.86]
# Iter 3900/5000 - Loss: 27589.527   Transfer Ratio: [0.86]
# Iter 4000/5000 - Loss: 27813.668   Transfer Ratio: [0.861]
# Iter 4100/5000 - Loss: 27558.168   Transfer Ratio: [0.861]
# Iter 4200/5000 - Loss: 27380.656   Transfer Ratio: [0.861]
# Iter 4300/5000 - Loss: 27899.701   Transfer Ratio: [0.861]
# Iter 4400/5000 - Loss: 27699.732   Transfer Ratio: [0.863]
# Iter 4500/5000 - Loss: 27515.539   Transfer Ratio: [0.864]
# Iter 4600/5000 - Loss: 27585.422   Transfer Ratio: [0.865]
# Iter 4700/5000 - Loss: 27375.871   Transfer Ratio: [0.865]
# Iter 4800/5000 - Loss: 27668.217   Transfer Ratio: [0.867]
# Iter 4900/5000 - Loss: 27445.307   Transfer Ratio: [0.87]
# Iter 5000/5000 - Loss: 27521.520   Transfer Ratio: [0.873]
# ======================================================================================
# Dataset: 1, Replicate: 4
# ======================================================================================
# *** P(W|X)
# Iter 100/5000 - Loss: 2091.089   Transfer Ratio: [0.477]
# Iter 200/5000 - Loss: 1495.716   Transfer Ratio: [0.46]
# Iter 300/5000 - Loss: 1125.846   Transfer Ratio: [0.447]
# Iter 400/5000 - Loss: 880.443   Transfer Ratio: [0.437]
# Iter 500/5000 - Loss: 713.081   Transfer Ratio: [0.431]
# Iter 600/5000 - Loss: 599.553   Transfer Ratio: [0.427]
# Iter 700/5000 - Loss: 523.660   Transfer Ratio: [0.426]
# Iter 800/5000 - Loss: 472.014   Transfer Ratio: [0.426]
# Iter 900/5000 - Loss: 434.930   Transfer Ratio: [0.428]
# Iter 1000/5000 - Loss: 406.736   Transfer Ratio: [0.43]
# Iter 1100/5000 - Loss: 384.349   Transfer Ratio: [0.433]
# Iter 1200/5000 - Loss: 366.057   Transfer Ratio: [0.437]
# Iter 1300/5000 - Loss: 350.847   Transfer Ratio: [0.442]
# Iter 1400/5000 - Loss: 338.070   Transfer Ratio: [0.447]
# Iter 1500/5000 - Loss: 327.265   Transfer Ratio: [0.453]
# Iter 1600/5000 - Loss: 318.074   Transfer Ratio: [0.459]
# Iter 1700/5000 - Loss: 310.200   Transfer Ratio: [0.465]
# Iter 1800/5000 - Loss: 303.388   Transfer Ratio: [0.472]
# Iter 1900/5000 - Loss: 297.421   Transfer Ratio: [0.479]
# Iter 2000/5000 - Loss: 292.114   Transfer Ratio: [0.486]
# Iter 2100/5000 - Loss: 287.319   Transfer Ratio: [0.493]
# Iter 2200/5000 - Loss: 282.918   Transfer Ratio: [0.5]
# Iter 2300/5000 - Loss: 278.821   Transfer Ratio: [0.507]
# Iter 2400/5000 - Loss: 274.959   Transfer Ratio: [0.515]
# Iter 2500/5000 - Loss: 271.287   Transfer Ratio: [0.523]
# Iter 2600/5000 - Loss: 267.772   Transfer Ratio: [0.53]
# Iter 2700/5000 - Loss: 264.392   Transfer Ratio: [0.538]
# Iter 2800/5000 - Loss: 261.135   Transfer Ratio: [0.546]
# Iter 2900/5000 - Loss: 257.994   Transfer Ratio: [0.554]
# Iter 3000/5000 - Loss: 254.964   Transfer Ratio: [0.563]
# Iter 3100/5000 - Loss: 252.046   Transfer Ratio: [0.571]
# Iter 3200/5000 - Loss: 249.238   Transfer Ratio: [0.579]
# Iter 3300/5000 - Loss: 246.541   Transfer Ratio: [0.588]
# Iter 3400/5000 - Loss: 243.957   Transfer Ratio: [0.596]
# Iter 3500/5000 - Loss: 241.485   Transfer Ratio: [0.605]
# Iter 3600/5000 - Loss: 239.127   Transfer Ratio: [0.614]
# Iter 3700/5000 - Loss: 236.883   Transfer Ratio: [0.622]
# Iter 3800/5000 - Loss: 234.754   Transfer Ratio: [0.631]
# Iter 3900/5000 - Loss: 232.740   Transfer Ratio: [0.639]
# Iter 4000/5000 - Loss: 230.839   Transfer Ratio: [0.647]
# Iter 4100/5000 - Loss: 229.050   Transfer Ratio: [0.656]
# Iter 4200/5000 - Loss: 227.372   Transfer Ratio: [0.664]
# Iter 4300/5000 - Loss: 225.802   Transfer Ratio: [0.672]
# Iter 4400/5000 - Loss: 224.337   Transfer Ratio: [0.68]
# Iter 4500/5000 - Loss: 222.973   Transfer Ratio: [0.688]
# Iter 4600/5000 - Loss: 221.706   Transfer Ratio: [0.696]
# Iter 4700/5000 - Loss: 220.533   Transfer Ratio: [0.703]
# Iter 4800/5000 - Loss: 219.448   Transfer Ratio: [0.711]
# Iter 4900/5000 - Loss: 218.448   Transfer Ratio: [0.718]
# Iter 5000/5000 - Loss: 217.528   Transfer Ratio: [0.725]
# *** P(Y|X,W)
# Iter 100/5000 - Loss: 13851.432   Transfer Ratio: [0.503]
# Iter 200/5000 - Loss: 9907.515   Transfer Ratio: [0.536]
# Iter 300/5000 - Loss: 7302.600   Transfer Ratio: [0.566]
# Iter 400/5000 - Loss: 5493.907   Transfer Ratio: [0.592]
# Iter 500/5000 - Loss: 4233.096   Transfer Ratio: [0.614]
# Iter 600/5000 - Loss: 3363.227   Transfer Ratio: [0.633]
# Iter 700/5000 - Loss: 2779.424   Transfer Ratio: [0.65]
# Iter 800/5000 - Loss: 2399.409   Transfer Ratio: [0.665]
# Iter 900/5000 - Loss: 2152.871   Transfer Ratio: [0.679]
# Iter 1000/5000 - Loss: 1986.587   Transfer Ratio: [0.691]
# Iter 1100/5000 - Loss: 1867.431   Transfer Ratio: [0.703]
# Iter 1200/5000 - Loss: 1777.326   Transfer Ratio: [0.713]
# Iter 1300/5000 - Loss: 1706.501   Transfer Ratio: [0.722]
# Iter 1400/5000 - Loss: 1649.236   Transfer Ratio: [0.731]
# Iter 1500/5000 - Loss: 1601.880   Transfer Ratio: [0.74]
# Iter 1600/5000 - Loss: 1561.974   Transfer Ratio: [0.747]
# Iter 1700/5000 - Loss: 1527.802   Transfer Ratio: [0.755]
# Iter 1800/5000 - Loss: 1498.141   Transfer Ratio: [0.762]
# Iter 1900/5000 - Loss: 1472.091   Transfer Ratio: [0.768]
# Iter 2000/5000 - Loss: 1448.984   Transfer Ratio: [0.775]
# Iter 2100/5000 - Loss: 1428.307   Transfer Ratio: [0.781]
# Iter 2200/5000 - Loss: 1409.663   Transfer Ratio: [0.787]
# Iter 2300/5000 - Loss: 1392.738   Transfer Ratio: [0.792]
# Iter 2400/5000 - Loss: 1377.284   Transfer Ratio: [0.798]
# Iter 2500/5000 - Loss: 1363.098   Transfer Ratio: [0.803]
# Iter 2600/5000 - Loss: 1350.016   Transfer Ratio: [0.808]
# Iter 2700/5000 - Loss: 1337.900   Transfer Ratio: [0.813]
# Iter 2800/5000 - Loss: 1326.633   Transfer Ratio: [0.818]
# Iter 2900/5000 - Loss: 1316.117   Transfer Ratio: [0.823]
# Iter 3000/5000 - Loss: 1306.264   Transfer Ratio: [0.827]
# Iter 3100/5000 - Loss: 1296.998   Transfer Ratio: [0.832]
# Iter 3200/5000 - Loss: 1288.253   Transfer Ratio: [0.836]
# Iter 3300/5000 - Loss: 1279.968   Transfer Ratio: [0.84]
# Iter 3400/5000 - Loss: 1272.090   Transfer Ratio: [0.844]
# Iter 3500/5000 - Loss: 1264.572   Transfer Ratio: [0.848]
# Iter 3600/5000 - Loss: 1257.371   Transfer Ratio: [0.852]
# Iter 3700/5000 - Loss: 1250.450   Transfer Ratio: [0.856]
# Iter 3800/5000 - Loss: 1243.776   Transfer Ratio: [0.86]
# Iter 3900/5000 - Loss: 1237.320   Transfer Ratio: [0.864]
# Iter 4000/5000 - Loss: 1231.057   Transfer Ratio: [0.867]
# Iter 4100/5000 - Loss: 1224.967   Transfer Ratio: [0.871]
# Iter 4200/5000 - Loss: 1219.032   Transfer Ratio: [0.874]
# Iter 4300/5000 - Loss: 1213.237   Transfer Ratio: [0.878]
# Iter 4400/5000 - Loss: 1207.571   Transfer Ratio: [0.881]
# Iter 4500/5000 - Loss: 1202.025   Transfer Ratio: [0.884]
# Iter 4600/5000 - Loss: 1196.591   Transfer Ratio: [0.888]
# Iter 4700/5000 - Loss: 1191.265   Transfer Ratio: [0.891]
# Iter 4800/5000 - Loss: 1186.042   Transfer Ratio: [0.894]
# Iter 4900/5000 - Loss: 1180.918   Transfer Ratio: [0.897]
# Iter 5000/5000 - Loss: 1175.891   Transfer Ratio: [0.9]
# *** P(Z|Y,X,W) and P(Y|W,Z)
# Iter 100/5000 - Loss: 84618.164   Transfer Ratio: [0.421]
# Iter 200/5000 - Loss: 69884.156   Transfer Ratio: [0.426]
# Iter 300/5000 - Loss: 38461.172   Transfer Ratio: [0.514]
# Iter 400/5000 - Loss: 32858.648   Transfer Ratio: [0.62]
# Iter 500/5000 - Loss: 31645.127   Transfer Ratio: [0.678]
# Iter 600/5000 - Loss: 31135.861   Transfer Ratio: [0.716]
# Iter 700/5000 - Loss: 30430.561   Transfer Ratio: [0.744]
# Iter 800/5000 - Loss: 30042.930   Transfer Ratio: [0.767]
# Iter 900/5000 - Loss: 29921.504   Transfer Ratio: [0.785]
# Iter 1000/5000 - Loss: 29496.801   Transfer Ratio: [0.797]
# Iter 1100/5000 - Loss: 29487.104   Transfer Ratio: [0.808]
# Iter 1200/5000 - Loss: 29106.779   Transfer Ratio: [0.816]
# Iter 1300/5000 - Loss: 28910.861   Transfer Ratio: [0.824]
# Iter 1400/5000 - Loss: 28860.178   Transfer Ratio: [0.83]
# Iter 1500/5000 - Loss: 28684.803   Transfer Ratio: [0.835]
# Iter 1600/5000 - Loss: 28285.221   Transfer Ratio: [0.841]
# Iter 1700/5000 - Loss: 28450.750   Transfer Ratio: [0.846]
# Iter 1800/5000 - Loss: 28302.992   Transfer Ratio: [0.849]
# Iter 1900/5000 - Loss: 28259.373   Transfer Ratio: [0.854]
# Iter 2000/5000 - Loss: 28069.973   Transfer Ratio: [0.856]
# Iter 2100/5000 - Loss: 28071.160   Transfer Ratio: [0.857]
# Iter 2200/5000 - Loss: 27973.936   Transfer Ratio: [0.86]
# Iter 2300/5000 - Loss: 27929.936   Transfer Ratio: [0.863]
# Iter 2400/5000 - Loss: 28024.213   Transfer Ratio: [0.865]
# Iter 2500/5000 - Loss: 27752.986   Transfer Ratio: [0.867]
# Iter 2600/5000 - Loss: 27766.244   Transfer Ratio: [0.868]
# Iter 2700/5000 - Loss: 27749.400   Transfer Ratio: [0.874]
# Iter 2800/5000 - Loss: 27681.158   Transfer Ratio: [0.875]
# Iter 2900/5000 - Loss: 27662.840   Transfer Ratio: [0.877]
# Iter 3000/5000 - Loss: 27727.688   Transfer Ratio: [0.879]
# Iter 3100/5000 - Loss: 27685.375   Transfer Ratio: [0.881]
# Iter 3200/5000 - Loss: 27533.236   Transfer Ratio: [0.882]
# Iter 3300/5000 - Loss: 27620.977   Transfer Ratio: [0.884]
# Iter 3400/5000 - Loss: 27477.738   Transfer Ratio: [0.885]
# Iter 3500/5000 - Loss: 27536.789   Transfer Ratio: [0.887]
# Iter 3600/5000 - Loss: 27605.680   Transfer Ratio: [0.888]
# Iter 3700/5000 - Loss: 27634.264   Transfer Ratio: [0.888]
# Iter 3800/5000 - Loss: 27507.266   Transfer Ratio: [0.889]
# Iter 3900/5000 - Loss: 27554.543   Transfer Ratio: [0.89]
# Iter 4000/5000 - Loss: 27524.363   Transfer Ratio: [0.891]
# Iter 4100/5000 - Loss: 27538.314   Transfer Ratio: [0.893]
# Iter 4200/5000 - Loss: 27442.500   Transfer Ratio: [0.893]
# Iter 4300/5000 - Loss: 27548.711   Transfer Ratio: [0.895]
# Iter 4400/5000 - Loss: 27742.205   Transfer Ratio: [0.895]
# Iter 4500/5000 - Loss: 27510.504   Transfer Ratio: [0.897]
# Iter 4600/5000 - Loss: 27432.234   Transfer Ratio: [0.897]
# Iter 4700/5000 - Loss: 27505.307   Transfer Ratio: [0.898]
# Iter 4800/5000 - Loss: 27379.020   Transfer Ratio: [0.898]
# Iter 4900/5000 - Loss: 27537.754   Transfer Ratio: [0.898]
# Iter 5000/5000 - Loss: 27453.326   Transfer Ratio: [0.902]
# ======================================================================================
# Dataset: 1, Replicate: 5
# ======================================================================================
# *** P(W|X)
# Iter 100/5000 - Loss: 2296.667   Transfer Ratio: [0.477]
# Iter 200/5000 - Loss: 1639.884   Transfer Ratio: [0.459]
# Iter 300/5000 - Loss: 1225.471   Transfer Ratio: [0.446]
# Iter 400/5000 - Loss: 948.444   Transfer Ratio: [0.436]
# Iter 500/5000 - Loss: 761.001   Transfer Ratio: [0.43]
# Iter 600/5000 - Loss: 638.073   Transfer Ratio: [0.427]
# Iter 700/5000 - Loss: 558.342   Transfer Ratio: [0.426]
# Iter 800/5000 - Loss: 504.339   Transfer Ratio: [0.427]
# Iter 900/5000 - Loss: 465.289   Transfer Ratio: [0.429]
# Iter 1000/5000 - Loss: 435.407   Transfer Ratio: [0.432]
# Iter 1100/5000 - Loss: 411.595   Transfer Ratio: [0.436]
# Iter 1200/5000 - Loss: 392.092   Transfer Ratio: [0.44]
# Iter 1300/5000 - Loss: 375.834   Transfer Ratio: [0.445]
# Iter 1400/5000 - Loss: 362.137   Transfer Ratio: [0.45]
# Iter 1500/5000 - Loss: 350.531   Transfer Ratio: [0.456]
# Iter 1600/5000 - Loss: 340.658   Transfer Ratio: [0.462]
# Iter 1700/5000 - Loss: 332.229   Transfer Ratio: [0.469]
# Iter 1800/5000 - Loss: 324.986   Transfer Ratio: [0.475]
# Iter 1900/5000 - Loss: 318.702   Transfer Ratio: [0.482]
# Iter 2000/5000 - Loss: 313.175   Transfer Ratio: [0.489]
# Iter 2100/5000 - Loss: 308.230   Transfer Ratio: [0.497]
# Iter 2200/5000 - Loss: 303.726   Transfer Ratio: [0.504]
# Iter 2300/5000 - Loss: 299.552   Transfer Ratio: [0.512]
# Iter 2400/5000 - Loss: 295.627   Transfer Ratio: [0.52]
# Iter 2500/5000 - Loss: 291.896   Transfer Ratio: [0.528]
# Iter 2600/5000 - Loss: 288.321   Transfer Ratio: [0.536]
# Iter 2700/5000 - Loss: 284.880   Transfer Ratio: [0.544]
# Iter 2800/5000 - Loss: 281.557   Transfer Ratio: [0.553]
# Iter 2900/5000 - Loss: 278.345   Transfer Ratio: [0.562]
# Iter 3000/5000 - Loss: 275.238   Transfer Ratio: [0.57]
# Iter 3100/5000 - Loss: 272.234   Transfer Ratio: [0.579]
# Iter 3200/5000 - Loss: 269.330   Transfer Ratio: [0.588]
# Iter 3300/5000 - Loss: 266.525   Transfer Ratio: [0.598]
# Iter 3400/5000 - Loss: 263.819   Transfer Ratio: [0.607]
# Iter 3500/5000 - Loss: 261.211   Transfer Ratio: [0.616]
# Iter 3600/5000 - Loss: 258.703   Transfer Ratio: [0.626]
# Iter 3700/5000 - Loss: 256.294   Transfer Ratio: [0.635]
# Iter 3800/5000 - Loss: 253.985   Transfer Ratio: [0.644]
# Iter 3900/5000 - Loss: 251.778   Transfer Ratio: [0.654]
# Iter 4000/5000 - Loss: 249.673   Transfer Ratio: [0.663]
# Iter 4100/5000 - Loss: 247.671   Transfer Ratio: [0.672]
# Iter 4200/5000 - Loss: 245.773   Transfer Ratio: [0.681]
# Iter 4300/5000 - Loss: 243.977   Transfer Ratio: [0.69]
# Iter 4400/5000 - Loss: 242.284   Transfer Ratio: [0.699]
# Iter 4500/5000 - Loss: 240.691   Transfer Ratio: [0.708]
# Iter 4600/5000 - Loss: 239.198   Transfer Ratio: [0.716]
# Iter 4700/5000 - Loss: 237.802   Transfer Ratio: [0.725]
# Iter 4800/5000 - Loss: 236.500   Transfer Ratio: [0.733]
# Iter 4900/5000 - Loss: 235.289   Transfer Ratio: [0.741]
# Iter 5000/5000 - Loss: 234.165   Transfer Ratio: [0.749]
# *** P(Y|X,W)
# Iter 100/5000 - Loss: 13429.469   Transfer Ratio: [0.528]
# Iter 200/5000 - Loss: 9596.284   Transfer Ratio: [0.556]
# Iter 300/5000 - Loss: 7186.966   Transfer Ratio: [0.582]
# Iter 400/5000 - Loss: 5484.242   Transfer Ratio: [0.606]
# Iter 500/5000 - Loss: 4253.872   Transfer Ratio: [0.627]
# Iter 600/5000 - Loss: 3375.428   Transfer Ratio: [0.647]
# Iter 700/5000 - Loss: 2768.267   Transfer Ratio: [0.664]
# Iter 800/5000 - Loss: 2364.460   Transfer Ratio: [0.68]
# Iter 900/5000 - Loss: 2100.848   Transfer Ratio: [0.694]
# Iter 1000/5000 - Loss: 1924.559   Transfer Ratio: [0.707]
# Iter 1100/5000 - Loss: 1799.409   Transfer Ratio: [0.719]
# Iter 1200/5000 - Loss: 1704.762   Transfer Ratio: [0.73]
# Iter 1300/5000 - Loss: 1629.839   Transfer Ratio: [0.74]
# Iter 1400/5000 - Loss: 1568.802   Transfer Ratio: [0.75]
# Iter 1500/5000 - Loss: 1518.122   Transfer Ratio: [0.759]
# Iter 1600/5000 - Loss: 1475.430   Transfer Ratio: [0.767]
# Iter 1700/5000 - Loss: 1439.038   Transfer Ratio: [0.775]
# Iter 1800/5000 - Loss: 1407.709   Transfer Ratio: [0.783]
# Iter 1900/5000 - Loss: 1380.511   Transfer Ratio: [0.79]
# Iter 2000/5000 - Loss: 1356.730   Transfer Ratio: [0.797]
# Iter 2100/5000 - Loss: 1335.806   Transfer Ratio: [0.803]
# Iter 2200/5000 - Loss: 1317.290   Transfer Ratio: [0.809]
# Iter 2300/5000 - Loss: 1300.816   Transfer Ratio: [0.814]
# Iter 2400/5000 - Loss: 1286.081   Transfer Ratio: [0.819]
# Iter 2500/5000 - Loss: 1272.830   Transfer Ratio: [0.824]
# Iter 2600/5000 - Loss: 1260.849   Transfer Ratio: [0.829]
# Iter 2700/5000 - Loss: 1249.954   Transfer Ratio: [0.833]
# Iter 2800/5000 - Loss: 1239.990   Transfer Ratio: [0.837]
# Iter 2900/5000 - Loss: 1230.824   Transfer Ratio: [0.841]
# Iter 3000/5000 - Loss: 1222.340   Transfer Ratio: [0.844]
# Iter 3100/5000 - Loss: 1214.441   Transfer Ratio: [0.848]
# Iter 3200/5000 - Loss: 1207.044   Transfer Ratio: [0.851]
# Iter 3300/5000 - Loss: 1200.078   Transfer Ratio: [0.854]
# Iter 3400/5000 - Loss: 1193.482   Transfer Ratio: [0.857]
# Iter 3500/5000 - Loss: 1187.205   Transfer Ratio: [0.86]
# Iter 3600/5000 - Loss: 1181.202   Transfer Ratio: [0.862]
# Iter 3700/5000 - Loss: 1175.436   Transfer Ratio: [0.865]
# Iter 3800/5000 - Loss: 1169.876   Transfer Ratio: [0.867]
# Iter 3900/5000 - Loss: 1164.496   Transfer Ratio: [0.869]
# Iter 4000/5000 - Loss: 1159.273   Transfer Ratio: [0.872]
# Iter 4100/5000 - Loss: 1154.188   Transfer Ratio: [0.874]
# Iter 4200/5000 - Loss: 1149.225   Transfer Ratio: [0.875]
# Iter 4300/5000 - Loss: 1144.371   Transfer Ratio: [0.877]
# Iter 4400/5000 - Loss: 1139.616   Transfer Ratio: [0.879]
# Iter 4500/5000 - Loss: 1134.950   Transfer Ratio: [0.88]
# Iter 4600/5000 - Loss: 1130.365   Transfer Ratio: [0.882]
# Iter 4700/5000 - Loss: 1125.857   Transfer Ratio: [0.883]
# Iter 4800/5000 - Loss: 1121.419   Transfer Ratio: [0.885]
# Iter 4900/5000 - Loss: 1117.048   Transfer Ratio: [0.886]
# Iter 5000/5000 - Loss: 1112.739   Transfer Ratio: [0.887]
# *** P(Z|Y,X,W) and P(Y|W,Z)
# Iter 100/5000 - Loss: 80566.547   Transfer Ratio: [0.418]
# Iter 200/5000 - Loss: 65411.098   Transfer Ratio: [0.429]
# Iter 300/5000 - Loss: 37044.598   Transfer Ratio: [0.585]
# Iter 400/5000 - Loss: 32449.574   Transfer Ratio: [0.726]
# Iter 500/5000 - Loss: 30945.832   Transfer Ratio: [0.783]
# Iter 600/5000 - Loss: 30354.451   Transfer Ratio: [0.81]
# Iter 700/5000 - Loss: 30101.633   Transfer Ratio: [0.824]
# Iter 800/5000 - Loss: 29549.441   Transfer Ratio: [0.835]
# Iter 900/5000 - Loss: 29627.102   Transfer Ratio: [0.842]
# Iter 1000/5000 - Loss: 29216.598   Transfer Ratio: [0.847]
# Iter 1100/5000 - Loss: 29089.377   Transfer Ratio: [0.85]
# Iter 1200/5000 - Loss: 28829.133   Transfer Ratio: [0.852]
# Iter 1300/5000 - Loss: 28619.549   Transfer Ratio: [0.852]
# Iter 1400/5000 - Loss: 28628.717   Transfer Ratio: [0.852]
# Iter 1500/5000 - Loss: 28575.547   Transfer Ratio: [0.852]
# Iter 1600/5000 - Loss: 28390.436   Transfer Ratio: [0.852]
# Iter 1700/5000 - Loss: 28175.301   Transfer Ratio: [0.853]
# Iter 1800/5000 - Loss: 28053.146   Transfer Ratio: [0.853]
# Iter 1900/5000 - Loss: 27958.395   Transfer Ratio: [0.855]
# Iter 2000/5000 - Loss: 27874.762   Transfer Ratio: [0.857]
# Iter 2100/5000 - Loss: 27752.572   Transfer Ratio: [0.858]
# Iter 2200/5000 - Loss: 27949.014   Transfer Ratio: [0.86]
# Iter 2300/5000 - Loss: 27763.242   Transfer Ratio: [0.86]
# Iter 2400/5000 - Loss: 27761.568   Transfer Ratio: [0.862]
# Iter 2500/5000 - Loss: 27543.533   Transfer Ratio: [0.864]
# Iter 2600/5000 - Loss: 27639.020   Transfer Ratio: [0.866]
# Iter 2700/5000 - Loss: 27623.674   Transfer Ratio: [0.868]
# Iter 2800/5000 - Loss: 27502.963   Transfer Ratio: [0.869]
# Iter 2900/5000 - Loss: 27588.830   Transfer Ratio: [0.873]
# Iter 3000/5000 - Loss: 27619.645   Transfer Ratio: [0.872]
# Iter 3100/5000 - Loss: 27839.939   Transfer Ratio: [0.875]
# Iter 3200/5000 - Loss: 27362.461   Transfer Ratio: [0.876]
# Iter 3300/5000 - Loss: 27970.578   Transfer Ratio: [0.877]
# Iter 3400/5000 - Loss: 27578.697   Transfer Ratio: [0.879]
# Iter 3500/5000 - Loss: 27762.619   Transfer Ratio: [0.882]
# Iter 3600/5000 - Loss: 27407.266   Transfer Ratio: [0.884]
# Iter 3700/5000 - Loss: 27444.947   Transfer Ratio: [0.887]
# Iter 3800/5000 - Loss: 27534.387   Transfer Ratio: [0.888]
# Iter 3900/5000 - Loss: 27410.391   Transfer Ratio: [0.889]
# Iter 4000/5000 - Loss: 27414.729   Transfer Ratio: [0.888]
# Iter 4100/5000 - Loss: 27311.246   Transfer Ratio: [0.892]
# Iter 4200/5000 - Loss: 27341.203   Transfer Ratio: [0.893]
# Iter 4300/5000 - Loss: 27498.393   Transfer Ratio: [0.895]
# Iter 4400/5000 - Loss: 27701.277   Transfer Ratio: [0.897]
# Iter 4500/5000 - Loss: 27662.633   Transfer Ratio: [0.898]
# Iter 4600/5000 - Loss: 27365.648   Transfer Ratio: [0.899]
# Iter 4700/5000 - Loss: 27338.871   Transfer Ratio: [0.9]
# Iter 4800/5000 - Loss: 27270.299   Transfer Ratio: [0.901]
# Iter 4900/5000 - Loss: 27305.395   Transfer Ratio: [0.903]
# Iter 5000/5000 - Loss: 27459.564   Transfer Ratio: [0.904]
# ======================================================================================
# Dataset: 1, Replicate: 6
# ======================================================================================
# *** P(W|X)
# Iter 100/5000 - Loss: 2333.839   Transfer Ratio: [0.477]
# Iter 200/5000 - Loss: 1668.681   Transfer Ratio: [0.46]
# Iter 300/5000 - Loss: 1247.694   Transfer Ratio: [0.446]
# Iter 400/5000 - Loss: 962.818   Transfer Ratio: [0.437]
# Iter 500/5000 - Loss: 762.757   Transfer Ratio: [0.43]
# Iter 600/5000 - Loss: 623.553   Transfer Ratio: [0.427]
# Iter 700/5000 - Loss: 531.121   Transfer Ratio: [0.426]
# Iter 800/5000 - Loss: 470.976   Transfer Ratio: [0.427]
# Iter 900/5000 - Loss: 430.005   Transfer Ratio: [0.429]
# Iter 1000/5000 - Loss: 400.057   Transfer Ratio: [0.432]
# Iter 1100/5000 - Loss: 376.862   Transfer Ratio: [0.436]
# Iter 1200/5000 - Loss: 358.186   Transfer Ratio: [0.44]
# Iter 1300/5000 - Loss: 342.775   Transfer Ratio: [0.445]
# Iter 1400/5000 - Loss: 329.866   Transfer Ratio: [0.45]
# Iter 1500/5000 - Loss: 318.946   Transfer Ratio: [0.456]
# Iter 1600/5000 - Loss: 309.641   Transfer Ratio: [0.462]
# Iter 1700/5000 - Loss: 301.656   Transfer Ratio: [0.468]
# Iter 1800/5000 - Loss: 294.746   Transfer Ratio: [0.475]
# Iter 1900/5000 - Loss: 288.700   Transfer Ratio: [0.481]
# Iter 2000/5000 - Loss: 283.339   Transfer Ratio: [0.488]
# Iter 2100/5000 - Loss: 278.512   Transfer Ratio: [0.496]
# Iter 2200/5000 - Loss: 274.095   Transfer Ratio: [0.503]
# Iter 2300/5000 - Loss: 269.992   Transfer Ratio: [0.51]
# Iter 2400/5000 - Loss: 266.130   Transfer Ratio: [0.518]
# Iter 2500/5000 - Loss: 262.457   Transfer Ratio: [0.526]
# Iter 2600/5000 - Loss: 258.936   Transfer Ratio: [0.534]
# Iter 2700/5000 - Loss: 255.545   Transfer Ratio: [0.542]
# Iter 2800/5000 - Loss: 252.268   Transfer Ratio: [0.55]
# Iter 2900/5000 - Loss: 249.095   Transfer Ratio: [0.559]
# Iter 3000/5000 - Loss: 246.020   Transfer Ratio: [0.567]
# Iter 3100/5000 - Loss: 243.040   Transfer Ratio: [0.576]
# Iter 3200/5000 - Loss: 240.151   Transfer Ratio: [0.585]
# Iter 3300/5000 - Loss: 237.355   Transfer Ratio: [0.594]
# Iter 3400/5000 - Loss: 234.650   Transfer Ratio: [0.603]
# Iter 3500/5000 - Loss: 232.038   Transfer Ratio: [0.612]
# Iter 3600/5000 - Loss: 229.522   Transfer Ratio: [0.622]
# Iter 3700/5000 - Loss: 227.103   Transfer Ratio: [0.631]
# Iter 3800/5000 - Loss: 224.784   Transfer Ratio: [0.64]
# Iter 3900/5000 - Loss: 222.567   Transfer Ratio: [0.65]
# Iter 4000/5000 - Loss: 220.453   Transfer Ratio: [0.659]
# Iter 4100/5000 - Loss: 218.444   Transfer Ratio: [0.668]
# Iter 4200/5000 - Loss: 216.541   Transfer Ratio: [0.677]
# Iter 4300/5000 - Loss: 214.743   Transfer Ratio: [0.686]
# Iter 4400/5000 - Loss: 213.050   Transfer Ratio: [0.695]
# Iter 4500/5000 - Loss: 211.460   Transfer Ratio: [0.704]
# Iter 4600/5000 - Loss: 209.971   Transfer Ratio: [0.713]
# Iter 4700/5000 - Loss: 208.582   Transfer Ratio: [0.722]
# Iter 4800/5000 - Loss: 207.287   Transfer Ratio: [0.73]
# Iter 4900/5000 - Loss: 206.085   Transfer Ratio: [0.738]
# Iter 5000/5000 - Loss: 204.971   Transfer Ratio: [0.747]
# *** P(Y|X,W)
# Iter 100/5000 - Loss: 14848.681   Transfer Ratio: [0.492]
# Iter 200/5000 - Loss: 10589.173   Transfer Ratio: [0.517]
# Iter 300/5000 - Loss: 7843.432   Transfer Ratio: [0.547]
# Iter 400/5000 - Loss: 5901.253   Transfer Ratio: [0.574]
# Iter 500/5000 - Loss: 4515.609   Transfer Ratio: [0.597]
# Iter 600/5000 - Loss: 3545.401   Transfer Ratio: [0.618]
# ...
# Iter 3000/5000 - Loss: 254.717   Transfer Ratio: [0.545]
# Iter 3100/5000 - Loss: 251.592   Transfer Ratio: [0.553]
# Iter 3200/5000 - Loss: 248.578   Transfer Ratio: [0.561]
# Iter 3300/5000 - Loss: 245.675   Transfer Ratio: [0.569]
# Iter 3400/5000 - Loss: 242.883   Transfer Ratio: [0.577]
# Iter 3500/5000 - Loss: 240.206   Transfer Ratio: [0.585]
# Iter 3600/5000 - Loss: 237.643   Transfer Ratio: [0.593]
# Iter 3700/5000 - Loss: 235.198   Transfer Ratio: [0.601]
# Iter 3800/5000 - Loss: 232.872   Transfer Ratio: [0.609]
# Iter 3900/5000 - Loss: 230.665   Transfer Ratio: [0.617]
# Iter 4000/5000 - Loss: 228.579   Transfer Ratio: [0.625]
# Iter 4100/5000 - Loss: 226.612   Transfer Ratio: [0.633]
# Iter 4200/5000 - Loss: 224.763   Transfer Ratio: [0.641]
# Iter 4300/5000 - Loss: 223.031   Transfer Ratio: [0.649]
# Iter 4400/5000 - Loss: 221.413   Transfer Ratio: [0.657]
# Iter 4500/5000 - Loss: 219.905   Transfer Ratio: [0.664]
# Iter 4600/5000 - Loss: 218.505   Transfer Ratio: [0.672]
# Iter 4700/5000 - Loss: 217.207   Transfer Ratio: [0.679]
# Iter 4800/5000 - Loss: 216.008   Transfer Ratio: [0.686]
# Iter 4900/5000 - Loss: 214.901   Transfer Ratio: [0.693]
# Iter 5000/5000 - Loss: 213.884   Transfer Ratio: [0.7]
# *** P(Y|X,W)
# Iter 100/5000 - Loss: 12133.139   Transfer Ratio: [0.522]
# Iter 200/5000 - Loss: 8373.756   Transfer Ratio: [0.553]
# Iter 300/5000 - Loss: 5921.199   Transfer Ratio: [0.579]
# Iter 400/5000 - Loss: 4315.093   Transfer Ratio: [0.603]
# Iter 500/5000 - Loss: 3285.597   Transfer Ratio: [0.625]
# Iter 600/5000 - Loss: 2653.846   Transfer Ratio: [0.646]
# Iter 700/5000 - Loss: 2280.392   Transfer Ratio: [0.666]
# Iter 800/5000 - Loss: 2055.571   Transfer Ratio: [0.685]
# Iter 900/5000 - Loss: 1908.097   Transfer Ratio: [0.702]
# Iter 1000/5000 - Loss: 1801.057   Transfer Ratio: [0.717]
# Iter 1100/5000 - Loss: 1717.715   Transfer Ratio: [0.732]
# Iter 1200/5000 - Loss: 1650.280   Transfer Ratio: [0.745]
# Iter 1300/5000 - Loss: 1594.517   Transfer Ratio: [0.757]
# Iter 1400/5000 - Loss: 1547.729   Transfer Ratio: [0.768]
# Iter 1500/5000 - Loss: 1508.021   Transfer Ratio: [0.778]
# Iter 1600/5000 - Loss: 1473.996   Transfer Ratio: [0.787]
# Iter 1700/5000 - Loss: 1444.591   Transfer Ratio: [0.796]
# Iter 1800/5000 - Loss: 1418.980   Transfer Ratio: [0.804]
# Iter 1900/5000 - Loss: 1396.512   Transfer Ratio: [0.812]
# Iter 2000/5000 - Loss: 1376.666   Transfer Ratio: [0.819]
# Iter 2100/5000 - Loss: 1359.023   Transfer Ratio: [0.826]
# Iter 2200/5000 - Loss: 1343.240   Transfer Ratio: [0.832]
# Iter 2300/5000 - Loss: 1329.035   Transfer Ratio: [0.838]
# Iter 2400/5000 - Loss: 1316.176   Transfer Ratio: [0.843]
# Iter 2500/5000 - Loss: 1304.470   Transfer Ratio: [0.848]
# Iter 2600/5000 - Loss: 1293.753   Transfer Ratio: [0.853]
# Iter 2700/5000 - Loss: 1283.888   Transfer Ratio: [0.858]
# Iter 2800/5000 - Loss: 1274.757   Transfer Ratio: [0.862]
# Iter 2900/5000 - Loss: 1266.261   Transfer Ratio: [0.866]
# Iter 3000/5000 - Loss: 1258.312   Transfer Ratio: [0.87]
# Iter 3100/5000 - Loss: 1250.835   Transfer Ratio: [0.874]
# Iter 3200/5000 - Loss: 1243.763   Transfer Ratio: [0.878]
# Iter 3300/5000 - Loss: 1237.041   Transfer Ratio: [0.881]
# Iter 3400/5000 - Loss: 1230.616   Transfer Ratio: [0.885]
# Iter 3500/5000 - Loss: 1224.446   Transfer Ratio: [0.888]
# Iter 3600/5000 - Loss: 1218.493   Transfer Ratio: [0.891]
# Iter 3700/5000 - Loss: 1212.722   Transfer Ratio: [0.894]
# Iter 3800/5000 - Loss: 1207.106   Transfer Ratio: [0.897]
# Iter 3900/5000 - Loss: 1201.620   Transfer Ratio: [0.9]
# Iter 4000/5000 - Loss: 1196.245   Transfer Ratio: [0.902]
# Iter 4100/5000 - Loss: 1190.963   Transfer Ratio: [0.905]
# Iter 4200/5000 - Loss: 1185.760   Transfer Ratio: [0.907]
# Iter 4300/5000 - Loss: 1180.626   Transfer Ratio: [0.91]
# Iter 4400/5000 - Loss: 1175.553   Transfer Ratio: [0.912]
# Iter 4500/5000 - Loss: 1170.534   Transfer Ratio: [0.915]
# Iter 4600/5000 - Loss: 1165.566   Transfer Ratio: [0.917]
# Iter 4700/5000 - Loss: 1160.645   Transfer Ratio: [0.919]
# Iter 4800/5000 - Loss: 1155.771   Transfer Ratio: [0.921]
# Iter 4900/5000 - Loss: 1150.943   Transfer Ratio: [0.923]
# Iter 5000/5000 - Loss: 1146.161   Transfer Ratio: [0.925]
# *** P(Z|Y,X,W) and P(Y|W,Z)
# Iter 100/5000 - Loss: 85858.391   Transfer Ratio: [0.423]
# Iter 200/5000 - Loss: 69435.906   Transfer Ratio: [0.434]
# Iter 300/5000 - Loss: 36052.668   Transfer Ratio: [0.591]
# Iter 400/5000 - Loss: 31890.350   Transfer Ratio: [0.724]
# Iter 500/5000 - Loss: 30960.135   Transfer Ratio: [0.791]
# Iter 600/5000 - Loss: 30688.428   Transfer Ratio: [0.828]
# Iter 700/5000 - Loss: 30232.568   Transfer Ratio: [0.851]
# Iter 800/5000 - Loss: 30032.717   Transfer Ratio: [0.867]
# Iter 900/5000 - Loss: 29538.180   Transfer Ratio: [0.879]
# Iter 1000/5000 - Loss: 29677.375   Transfer Ratio: [0.888]
# Iter 1100/5000 - Loss: 29228.393   Transfer Ratio: [0.895]
# Iter 1200/5000 - Loss: 29228.734   Transfer Ratio: [0.901]
# Iter 1300/5000 - Loss: 28756.771   Transfer Ratio: [0.906]
# Iter 1400/5000 - Loss: 28906.926   Transfer Ratio: [0.91]
# Iter 1500/5000 - Loss: 28842.074   Transfer Ratio: [0.913]
# Iter 1600/5000 - Loss: 28482.275   Transfer Ratio: [0.915]
# Iter 1700/5000 - Loss: 28737.051   Transfer Ratio: [0.918]
# Iter 1800/5000 - Loss: 28356.473   Transfer Ratio: [0.921]
# Iter 1900/5000 - Loss: 28281.625   Transfer Ratio: [0.923]
# Iter 2000/5000 - Loss: 28250.389   Transfer Ratio: [0.925]
# Iter 2100/5000 - Loss: 28122.652   Transfer Ratio: [0.927]
# Iter 2200/5000 - Loss: 28144.211   Transfer Ratio: [0.929]
# Iter 2300/5000 - Loss: 28024.109   Transfer Ratio: [0.931]
# Iter 2400/5000 - Loss: 27894.271   Transfer Ratio: [0.933]
# Iter 2500/5000 - Loss: 27800.059   Transfer Ratio: [0.934]
# Iter 2600/5000 - Loss: 27926.779   Transfer Ratio: [0.935]
# Iter 2700/5000 - Loss: 27785.107   Transfer Ratio: [0.936]
# Iter 2800/5000 - Loss: 27737.900   Transfer Ratio: [0.937]
# Iter 2900/5000 - Loss: 27824.887   Transfer Ratio: [0.938]
# Iter 3000/5000 - Loss: 27678.582   Transfer Ratio: [0.939]
# Iter 3100/5000 - Loss: 27743.205   Transfer Ratio: [0.94]
# Iter 3200/5000 - Loss: 27639.150   Transfer Ratio: [0.942]
# Iter 3300/5000 - Loss: 27571.832   Transfer Ratio: [0.943]
# Iter 3400/5000 - Loss: 28453.820   Transfer Ratio: [0.944]
# Iter 3500/5000 - Loss: 27607.637   Transfer Ratio: [0.944]
# Iter 3600/5000 - Loss: 27632.027   Transfer Ratio: [0.946]
# Iter 3700/5000 - Loss: 27599.395   Transfer Ratio: [0.948]
# Iter 3800/5000 - Loss: 27792.191   Transfer Ratio: [0.949]
# Iter 3900/5000 - Loss: 27521.600   Transfer Ratio: [0.949]
# Iter 4000/5000 - Loss: 27616.568   Transfer Ratio: [0.951]
# Iter 4100/5000 - Loss: 27612.121   Transfer Ratio: [0.952]
# Iter 4200/5000 - Loss: 27593.668   Transfer Ratio: [0.953]
# Iter 4300/5000 - Loss: 27567.527   Transfer Ratio: [0.954]
# Iter 4400/5000 - Loss: 27535.070   Transfer Ratio: [0.955]
# Iter 4500/5000 - Loss: 27623.078   Transfer Ratio: [0.955]
# Iter 4600/5000 - Loss: 27539.842   Transfer Ratio: [0.956]
# Iter 4700/5000 - Loss: 27729.541   Transfer Ratio: [0.958]
# Iter 4800/5000 - Loss: 27513.889   Transfer Ratio: [0.958]
# Iter 4900/5000 - Loss: 27662.910   Transfer Ratio: [0.96]
# Iter 5000/5000 - Loss: 27564.797   Transfer Ratio: [0.961]
# ======================================================================================
# Dataset: 1, Replicate: 10
# ======================================================================================
# *** P(W|X)
# Iter 100/5000 - Loss: 2157.110   Transfer Ratio: [0.478]
# Iter 200/5000 - Loss: 1553.654   Transfer Ratio: [0.462]
# Iter 300/5000 - Loss: 1178.055   Transfer Ratio: [0.452]
# Iter 400/5000 - Loss: 926.987   Transfer Ratio: [0.448]
# Iter 500/5000 - Loss: 752.718   Transfer Ratio: [0.449]
# Iter 600/5000 - Loss: 631.182   Transfer Ratio: [0.453]
# Iter 700/5000 - Loss: 546.824   Transfer Ratio: [0.459]
# Iter 800/5000 - Loss: 487.740   Transfer Ratio: [0.467]
# Iter 900/5000 - Loss: 444.861   Transfer Ratio: [0.475]
# Iter 1000/5000 - Loss: 412.217   Transfer Ratio: [0.484]
# Iter 1100/5000 - Loss: 386.304   Transfer Ratio: [0.494]
# Iter 1200/5000 - Loss: 365.114   Transfer Ratio: [0.503]
# Iter 1300/5000 - Loss: 347.469   Transfer Ratio: [0.512]
# Iter 1400/5000 - Loss: 332.639   Transfer Ratio: [0.522]
# Iter 1500/5000 - Loss: 320.129   Transfer Ratio: [0.531]
# Iter 1600/5000 - Loss: 309.564   Transfer Ratio: [0.541]
# Iter 1700/5000 - Loss: 300.625   Transfer Ratio: [0.55]
# Iter 1800/5000 - Loss: 293.022   Transfer Ratio: [0.559]
# Iter 1900/5000 - Loss: 286.484   Transfer Ratio: [0.568]
# Iter 2000/5000 - Loss: 280.771   Transfer Ratio: [0.577]
# Iter 2100/5000 - Loss: 275.676   Transfer Ratio: [0.585]
# Iter 2200/5000 - Loss: 271.036   Transfer Ratio: [0.594]
# Iter 2300/5000 - Loss: 266.724   Transfer Ratio: [0.602]
# Iter 2400/5000 - Loss: 262.652   Transfer Ratio: [0.61]
# Iter 2500/5000 - Loss: 258.760   Transfer Ratio: [0.619]
# Iter 2600/5000 - Loss: 255.011   Transfer Ratio: [0.627]
# Iter 2700/5000 - Loss: 251.384   Transfer Ratio: [0.636]
# Iter 2800/5000 - Loss: 247.867   Transfer Ratio: [0.644]
# Iter 2900/5000 - Loss: 244.457   Transfer Ratio: [0.653]
# Iter 3000/5000 - Loss: 241.151   Transfer Ratio: [0.662]
# Iter 3100/5000 - Loss: 237.953   Transfer Ratio: [0.671]
# Iter 3200/5000 - Loss: 234.865   Transfer Ratio: [0.68]
# Iter 3300/5000 - Loss: 231.891   Transfer Ratio: [0.689]
# Iter 3400/5000 - Loss: 229.035   Transfer Ratio: [0.697]
# Iter 3500/5000 - Loss: 226.300   Transfer Ratio: [0.706]
# Iter 3600/5000 - Loss: 223.688   Transfer Ratio: [0.715]
# Iter 3700/5000 - Loss: 221.202   Transfer Ratio: [0.724]
# Iter 3800/5000 - Loss: 218.842   Transfer Ratio: [0.732]
# Iter 3900/5000 - Loss: 216.610   Transfer Ratio: [0.74]
# Iter 4000/5000 - Loss: 214.503   Transfer Ratio: [0.748]
# Iter 4100/5000 - Loss: 212.522   Transfer Ratio: [0.756]
# Iter 4200/5000 - Loss: 210.664   Transfer Ratio: [0.763]
# Iter 4300/5000 - Loss: 208.925   Transfer Ratio: [0.771]
# Iter 4400/5000 - Loss: 207.302   Transfer Ratio: [0.778]
# Iter 4500/5000 - Loss: 205.792   Transfer Ratio: [0.785]
# Iter 4600/5000 - Loss: 204.389   Transfer Ratio: [0.791]
# Iter 4700/5000 - Loss: 203.089   Transfer Ratio: [0.798]
# Iter 4800/5000 - Loss: 201.887   Transfer Ratio: [0.804]
# Iter 4900/5000 - Loss: 200.778   Transfer Ratio: [0.81]
# Iter 5000/5000 - Loss: 199.756   Transfer Ratio: [0.815]
# *** P(Y|X,W)
# Iter 100/5000 - Loss: 13409.967   Transfer Ratio: [0.528]
# Iter 200/5000 - Loss: 9484.016   Transfer Ratio: [0.556]
# Iter 300/5000 - Loss: 6868.335   Transfer Ratio: [0.58]
# Iter 400/5000 - Loss: 5070.184   Transfer Ratio: [0.602]
# Iter 500/5000 - Loss: 3856.753   Transfer Ratio: [0.622]
# Iter 600/5000 - Loss: 3077.734   Transfer Ratio: [0.639]
# Iter 700/5000 - Loss: 2604.550   Transfer Ratio: [0.654]
# Iter 800/5000 - Loss: 2320.943   Transfer Ratio: [0.667]
# Iter 900/5000 - Loss: 2140.201   Transfer Ratio: [0.68]
# Iter 1000/5000 - Loss: 2012.070   Transfer Ratio: [0.691]
# Iter 1100/5000 - Loss: 1912.508   Transfer Ratio: [0.702]
# Iter 1200/5000 - Loss: 1830.798   Transfer Ratio: [0.711]
# Iter 1300/5000 - Loss: 1761.809   Transfer Ratio: [0.721]
# Iter 1400/5000 - Loss: 1702.652   Transfer Ratio: [0.729]
# Iter 1500/5000 - Loss: 1651.431   Transfer Ratio: [0.737]
# Iter 1600/5000 - Loss: 1606.773   Transfer Ratio: [0.745]
# Iter 1700/5000 - Loss: 1567.628   Transfer Ratio: [0.752]
# Iter 1800/5000 - Loss: 1533.160   Transfer Ratio: [0.759]
# Iter 1900/5000 - Loss: 1502.692   Transfer Ratio: [0.765]
# Iter 2000/5000 - Loss: 1475.661   Transfer Ratio: [0.772]
# Iter 2100/5000 - Loss: 1451.597   Transfer Ratio: [0.777]
# Iter 2200/5000 - Loss: 1430.100   Transfer Ratio: [0.783]
# Iter 2300/5000 - Loss: 1410.832   Transfer Ratio: [0.788]
# Iter 2400/5000 - Loss: 1393.498   Transfer Ratio: [0.792]
# Iter 2500/5000 - Loss: 1377.847   Transfer Ratio: [0.797]
# Iter 2600/5000 - Loss: 1363.662   Transfer Ratio: [0.801]
# Iter 2700/5000 - Loss: 1350.752   Transfer Ratio: [0.805]
# Iter 2800/5000 - Loss: 1338.953   Transfer Ratio: [0.809]
# Iter 2900/5000 - Loss: 1328.124   Transfer Ratio: [0.813]
# Iter 3000/5000 - Loss: 1318.139   Transfer Ratio: [0.816]
# Iter 3100/5000 - Loss: 1308.890   Transfer Ratio: [0.819]
# Iter 3200/5000 - Loss: 1300.283   Transfer Ratio: [0.822]
# Iter 3300/5000 - Loss: 1292.235   Transfer Ratio: [0.825]
# Iter 3400/5000 - Loss: 1284.677   Transfer Ratio: [0.828]
# Iter 3500/5000 - Loss: 1277.545   Transfer Ratio: [0.83]
# Iter 3600/5000 - Loss: 1270.787   Transfer Ratio: [0.833]
# Iter 3700/5000 - Loss: 1264.357   Transfer Ratio: [0.835]
# Iter 3800/5000 - Loss: 1258.216   Transfer Ratio: [0.837]
# Iter 3900/5000 - Loss: 1252.328   Transfer Ratio: [0.839]
# Iter 4000/5000 - Loss: 1246.667   Transfer Ratio: [0.841]
# Iter 4100/5000 - Loss: 1241.207   Transfer Ratio: [0.843]
# Iter 4200/5000 - Loss: 1235.927   Transfer Ratio: [0.844]
# Iter 4300/5000 - Loss: 1230.810   Transfer Ratio: [0.846]
# Iter 4400/5000 - Loss: 1225.842   Transfer Ratio: [0.847]
# Iter 4500/5000 - Loss: 1221.008   Transfer Ratio: [0.849]
# Iter 4600/5000 - Loss: 1216.297   Transfer Ratio: [0.85]
# Iter 4700/5000 - Loss: 1211.700   Transfer Ratio: [0.851]
# Iter 4800/5000 - Loss: 1207.208   Transfer Ratio: [0.852]
# Iter 4900/5000 - Loss: 1202.811   Transfer Ratio: [0.853]
# Iter 5000/5000 - Loss: 1198.501   Transfer Ratio: [0.854]
# *** P(Z|Y,X,W) and P(Y|W,Z)
# Iter 100/5000 - Loss: 82313.195   Transfer Ratio: [0.421]
# Iter 200/5000 - Loss: 67390.719   Transfer Ratio: [0.434]
# Iter 300/5000 - Loss: 37880.375   Transfer Ratio: [0.588]
# Iter 400/5000 - Loss: 32893.973   Transfer Ratio: [0.7]
# Iter 500/5000 - Loss: 31456.844   Transfer Ratio: [0.743]
# Iter 600/5000 - Loss: 30785.078   Transfer Ratio: [0.763]
# Iter 700/5000 - Loss: 30193.232   Transfer Ratio: [0.775]
# Iter 800/5000 - Loss: 29915.926   Transfer Ratio: [0.783]
# Iter 900/5000 - Loss: 29766.400   Transfer Ratio: [0.789]
# Iter 1000/5000 - Loss: 29539.006   Transfer Ratio: [0.795]
# Iter 1100/5000 - Loss: 29071.576   Transfer Ratio: [0.799]
# Iter 1200/5000 - Loss: 29109.225   Transfer Ratio: [0.804]
# Iter 1300/5000 - Loss: 28931.418   Transfer Ratio: [0.809]
# Iter 1400/5000 - Loss: 28752.734   Transfer Ratio: [0.81]
# Iter 1500/5000 - Loss: 28755.207   Transfer Ratio: [0.812]
# Iter 1600/5000 - Loss: 28619.227   Transfer Ratio: [0.813]
# Iter 1700/5000 - Loss: 28349.807   Transfer Ratio: [0.814]
# Iter 1800/5000 - Loss: 28485.010   Transfer Ratio: [0.817]
# Iter 1900/5000 - Loss: 28260.768   Transfer Ratio: [0.818]
# Iter 2000/5000 - Loss: 28370.000   Transfer Ratio: [0.82]
# Iter 2100/5000 - Loss: 28117.014   Transfer Ratio: [0.823]
# Iter 2200/5000 - Loss: 28148.756   Transfer Ratio: [0.824]
# Iter 2300/5000 - Loss: 28120.457   Transfer Ratio: [0.824]
# Iter 2400/5000 - Loss: 28097.000   Transfer Ratio: [0.828]
# Iter 2500/5000 - Loss: 27953.482   Transfer Ratio: [0.827]
# Iter 2600/5000 - Loss: 27879.172   Transfer Ratio: [0.828]
# Iter 2700/5000 - Loss: 27818.951   Transfer Ratio: [0.831]
# Iter 2800/5000 - Loss: 28277.859   Transfer Ratio: [0.833]
# Iter 2900/5000 - Loss: 27819.367   Transfer Ratio: [0.834]
# Iter 3000/5000 - Loss: 27713.334   Transfer Ratio: [0.839]
# Iter 3100/5000 - Loss: 27807.738   Transfer Ratio: [0.839]
# Iter 3200/5000 - Loss: 27646.268   Transfer Ratio: [0.841]
# Iter 3300/5000 - Loss: 27761.031   Transfer Ratio: [0.843]
# Iter 3400/5000 - Loss: 27978.229   Transfer Ratio: [0.842]
# Iter 3500/5000 - Loss: 27725.219   Transfer Ratio: [0.844]
# Iter 3600/5000 - Loss: 27741.447   Transfer Ratio: [0.847]
# Iter 3700/5000 - Loss: 27794.885   Transfer Ratio: [0.848]
# Iter 3800/5000 - Loss: 27680.346   Transfer Ratio: [0.853]
# Iter 3900/5000 - Loss: 27629.541   Transfer Ratio: [0.852]
# Iter 4000/5000 - Loss: 27504.457   Transfer Ratio: [0.854]
# Iter 4100/5000 - Loss: 27547.215   Transfer Ratio: [0.854]
# Iter 4200/5000 - Loss: 27716.566   Transfer Ratio: [0.853]
# Iter 4300/5000 - Loss: 27787.215   Transfer Ratio: [0.854]
# Iter 4400/5000 - Loss: 27535.666   Transfer Ratio: [0.856]
# Iter 4500/5000 - Loss: 27670.463   Transfer Ratio: [0.855]
# Iter 4600/5000 - Loss: 27690.770   Transfer Ratio: [0.86]
# Iter 4700/5000 - Loss: 27650.969   Transfer Ratio: [0.86]
# Iter 4800/5000 - Loss: 27477.471   Transfer Ratio: [0.863]
# Iter 4900/5000 - Loss: 27470.801   Transfer Ratio: [0.863]
# Iter 5000/5000 - Loss: 27506.461   Transfer Ratio: [0.865]

# %% [markdown]
# ### Print $\epsilon_{\text{ATE}}, \sqrt{\epsilon_{\text{PEHE}}}$

# %%
learn_transfer_stats_mean = np.array([np.mean(test_stats,axis=0) for test_stats in learn_transfer_test_stats_lst])
learn_transfer_stats_stderr = np.array([stats.sem(test_stats,axis=0) for test_stats in learn_transfer_test_stats_lst])
learn_transfer_stats_mean
# Out:
# array([[0.11782894, 1.09099345],
#        [0.1497903 , 1.16562962],
#        [0.30114955, 1.24740887],
#        [0.26461714, 1.26342214],
#        [0.23610094, 1.26582838]])

# %%
learn_transfer_stats_mean = np.array([np.mean(test_stats,axis=0) for test_stats in learn_transfer_test_stats_lst]) # learn transfer
learn_transfer_stats_stderr = np.array([stats.sem(test_stats,axis=0) for test_stats in learn_transfer_test_stats_lst]) # learn transfer
# np.savetxt('save_one_source_F/graphs_learn_transfer_stats_varying_zdim.txt', np.concatenate((learn_transfer_stats_mean,learn_transfer_stats_stderr),axis=1))
learn_transfer_stats_mean
# Out:
# array([[0.11782675, 1.09099268],
#        [0.13794295, 1.17114677],
#        [0.223591  , 1.20371401],
#        [0.39212068, 1.30781013],
#        [0.29160374, 1.25623264]])

# %% [markdown]
# ### Print transfer factors

# %%
learn_transfer_trans_factor_mean = np.array([np.mean(test_stats,axis=0) for test_stats in learn_transfer_trans_factor_lst])
learn_transfer_trans_factor_stderr = np.array([stats.sem(test_stats,axis=0) for test_stats in learn_transfer_trans_factor_lst])
learn_transfer_trans_factor_mean
# Out:
# array([[0.7459139 , 0.87398607, 0.8885415 ],
#        [0.7467107 , 0.78075504, 0.81378233],
#        [0.73397964, 0.67152345, 0.7486127 ],
#        [0.72342414, 0.578894  , 0.6908272 ],
#        [0.7242181 , 0.5084177 , 0.63143694]], dtype=float32)

# %% [markdown]
# ### Print prediction accuracy of $P(W|X)$

# %%
learn_transfer_stats_w_mean = np.asarray([np.mean(test_stats,axis=0) for test_stats in  learn_transfer_test_stats_w_lst])
learn_transfer_stats_w_stderr = np.asarray([stats.sem(test_stats,axis=0) for test_stats in  learn_transfer_test_stats_w_lst])
learn_transfer_stats_w_mean
# Out:
# array([[0.89463156, 0.7459139 ],
#        [0.8930526 , 0.7467107 ],
#        [0.89231586, 0.73397964],
#        [0.89147365, 0.72342414],
#        [0.89263153, 0.7242181 ]], dtype=float32)

# %% [markdown]
# ### Print prediction error of $P(Y|W,X)$

# %%
learn_transfer_stats_y_mean = np.array([np.mean(test_stats,axis=0) for test_stats in learn_transfer_test_stats_y_lst])
learn_transfer_stats_y_stderr = np.array([stats.sem(test_stats,axis=0) for test_stats in learn_transfer_test_stats_y_lst])
learn_transfer_stats_y_mean
# Out:
# array([[1.5727255 , 2.3868768 , 0.87398607],
#        [1.5383657 , 2.3008652 , 0.78075504],
#        [1.542381  , 2.2997823 , 0.67152345],
#        [1.568529  , 2.335389  , 0.578894  ],
#        [1.5976369 , 2.3778934 , 0.5084177 ]], dtype=float32)
