# %%
# %load_ext autoreload
# %autoreload 2
import os
from time import sleep
import numpy as np
import torch
import scipy
import pandas as pd
import random
from scipy import stats
from load_datasets import TWINS
from models_train import *
from evaluation import Evaluation

# %%
if torch.cuda.is_available():
  # torch.set_default_tensor_type('torch.cuda.FloatTensor')
  print('Use ***GPU***')
  print(torch.cuda.get_device_properties(0).total_memory/1024/1024/1024,'GB')
else:
  print('Use CPU')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Use ***GPU***
# 14.726318359375 GB

# %% [markdown]
# # Train the model

# %%
# Configuration
OUTPUT_DIR = 'save_outputs/save_twins'
dim_z = 30
training_iter = 5000
transfer_flag = FLAGS_LEARN_TRANSFER
n_samples = 100
reg_alpha_w, lr_w = 1e-3, 1e-1
reg_alpha_y, reg_noise_y, lr_y =1e-2, 1e-2, 1e-1
reg_alpha_zy, lr_zy =1e-1, 1e-1
N_target_train = 100

# Lists to store results
learn_transfer_trans_factor_lst = []
learn_transfer_test_stats_lst = []
learn_transfer_test_stats_w_lst = []
learn_transfer_test_stats_y_lst = []

# Load data
dataset = TWINS()
m = 1 # number of sources

# Create output directory
if not os.path.exists(OUTPUT_DIR):
  os.makedirs(OUTPUT_DIR)

# Train the models
# for delta in [0.0, 0.5, 1.0, 1.5, 2.5]:
for delta in [0.0]: # This is an example with delta=0, uncomment the above to run all
  loss_lst = []
  trans_factors = []
  test_stats = []
  test_stats_w = []
  test_stats_y = []
  for i, (datas, datat, source_ranges) in enumerate(dataset.get_source_target(delta=delta)):
    print('======================================================================================')
    print('#Delta: {}, Replicate: {}'.format(delta, i+1))
    print('======================================================================================')
    sleep(0.5)
    # Source data to tensor
    Ws, Ys, Y_cfs, mus, Xs = datas[:,0].reshape(-1),\
                              datas[:,1].reshape(-1),\
                              datas[:,2].reshape(-1),\
                              np.concatenate((datas[:,3:4],datas[:,4:5]),axis=1),\
                              datas[:,5:]
    Ts = len(Ys)
    xs = torch.from_numpy(Xs.reshape(Ts,-1)).float().to(device)
    ys = torch.from_numpy(Ys.reshape(-1,1)).float().to(device)
    ws = torch.from_numpy(Ws.reshape(-1,1)).float().to(device)

    # Target train data to tensor
    Wt, Yt, Y_cft, mut, Xt = datat[:,0].reshape(-1)[:N_target_train],\
                              datat[:,1].reshape(-1)[:N_target_train],\
                              datat[:,2].reshape(-1)[:N_target_train],\
                              np.concatenate((datat[:,3:4],datat[:,4:5]),axis=1)[:N_target_train],\
                              datat[:N_target_train,5:]
    Tt = len(Yt)
    xt = torch.from_numpy(Xt.reshape(Tt,-1)).float().to(device)
    yt = torch.from_numpy(Yt.reshape(-1,1)).float().to(device)
    wt = torch.from_numpy(Wt.reshape(-1,1)).float().to(device)

    # Target test data to tensor
    Wtte, Ytte, Y_cftte, mutte, Xtte = datat[:,0].reshape(-1)[N_target_train:-100],\
                              datat[:,1].reshape(-1)[N_target_train:-100],\
                              datat[:,2].reshape(-1)[N_target_train:-100],\
                              np.concatenate((datat[:,3:4],datat[:,4:5]),axis=1)[N_target_train:-100],\
                              datat[N_target_train:-100,5:]
    Ttte = len(Ytte)
    xtte = torch.from_numpy(Xtte.reshape(Ttte,-1)).float().to(device)
    ytte = torch.from_numpy(Ytte.reshape(-1,1)).float().to(device)
    wtte = torch.from_numpy(Wtte.reshape(-1,1)).float().to(device)

    # Train
    domain_ranges =  list(source_ranges) + [(source_ranges[-1][1], source_ranges[-1][1]+N_target_train)]
    print('*** P(W|X)')
    model_w = trainW(train_x=torch.cat((xs,xt),dim=0),
                     train_w=torch.cat((ws,wt),dim=0).reshape(-1),
                     n_domains=m+1, domain_ranges=domain_ranges,
                     training_iter=training_iter, transfer_flag=transfer_flag,
                     reg_alpha=reg_alpha_w, lr=lr_w)
    w_samples = model_w.sample(x=xtte,n_samples=n_samples)

    print('*** P(Y|X,W)')
    model_y = trainY(train_x=torch.cat((xs,xt),dim=0),
                     train_y=torch.cat((ys,yt),dim=0),
                     train_w=torch.cat((ws,wt),dim=0),
                     n_domains=m+1, domain_ranges=domain_ranges, is_binary=True,
                     training_iter=training_iter, transfer_flag=transfer_flag,
                     reg_alpha=reg_alpha_y, reg_noise=reg_noise_y, lr=lr_y)
    y_samples_xw = model_y.sample(x=xtte,w_samples=w_samples,n_samples=n_samples,is_binary=True)

    print('*** P(Z|Y,X,W) and P(Y|W,Z)')
    model_zy = trainZY(train_x=torch.cat((xs,xt),dim=0),
                       train_y=torch.cat((ys,yt),dim=0),
                       train_w=torch.cat((ws,wt),dim=0),
                       n_domains=m+1, domain_ranges=domain_ranges, is_binary=True, dim_z=dim_z,
                       training_iter=training_iter, transfer_flag=transfer_flag,
                       reg_alpha=reg_alpha_zy, lr=lr_zy)
    
    
    # Evaluate P(W|X)
    accur = torch.sum((model_w.pred(xtte, domain_ranges=[(0,0)]*m+[(0,xtte.shape[0])])>0)*1.0==wtte.reshape(-1))/len(xtte)
    test_stats_w.append(np.insert(model_w.trans_factor().cpu().detach().numpy(),0,accur.cpu().detach().numpy()))

    # Evaluate P(Y|X,W)
    mae = torch.mean(torch.abs(model_y.pred(xtte, wtte, domain_ranges=[(0,0)]*m+[(0,xtte.shape[0])]).reshape(-1) - ytte.reshape(-1)))
    rmse = torch.sqrt(torch.mean((model_y.pred(xtte, wtte, domain_ranges=[(0,0)]*m+[(0,xtte.shape[0])]).reshape(-1) - ytte.reshape(-1))**2))
    test_stats_y.append(np.concatenate((np.asarray([mae.cpu().detach().numpy(), rmse.cpu().detach().numpy()]),
                                        model_y.trans_factor().cpu().detach().numpy())))

    # Evaluate ATE, ITE
    y_samples_do0,_ = model_zy.sample_v2(xtte, do_w=torch.zeros((xtte.shape[0],1),device=device),
                                         y_samples=y_samples_xw, w_samples=w_samples, n_samples=n_samples, is_binary=True)
    y_samples_do1,_ = model_zy.sample_v2(xtte, do_w=torch.ones((xtte.shape[0],1),device=device),
                                         y_samples=y_samples_xw, w_samples=w_samples, n_samples=n_samples, is_binary=True)
    
    y_do0_mean = torch.mean(y_samples_do0,dim=1)
    y_do1_mean = torch.mean(y_samples_do1,dim=1)

    # Y0tte = (1-Wtte)*Ytte + Wtte*Y_cftte
    # Y1tte = Wtte*Ytte + (1-Wtte)*Y_cftte
    eval = Evaluation(m0=mutte[:,0], m1=mutte[:,1])
    abs_err = eval.absolute_err_ate(y_do0_mean.cpu().detach().numpy(), y_do1_mean.cpu().detach().numpy())
    pehe = eval.pehe(y_do0_mean.cpu().detach().numpy(), y_do1_mean.cpu().detach().numpy())

    test_stats.append((abs_err, pehe))
    trans_factors.append(np.concatenate((model_w.trans_factor().cpu().detach().numpy(), model_y.trans_factor().cpu().detach().numpy(),
                                        model_zy.trans_factor().cpu().detach().numpy())))
    
    # Save output of replicate i+1
    np.savez(OUTPUT_DIR + '/graphs_learn_transfer_delta_{}_fold_{}.npz'.format(delta,i+1),
            trans_factors=trans_factors,
            test_stats=test_stats,
            test_stats_w=test_stats_w,
            test_stats_y=test_stats_y)

  learn_transfer_trans_factor_lst.append(trans_factors)
  learn_transfer_test_stats_lst.append(test_stats)
  learn_transfer_test_stats_w_lst.append(test_stats_w)
  learn_transfer_test_stats_y_lst.append(test_stats_y)

  # Save outputs
  learn_transfer_stats_mean = np.array([np.mean(test_stats,axis=0) for test_stats in learn_transfer_test_stats_lst])
  learn_transfer_stats_stderr = np.array([stats.sem(test_stats,axis=0) for test_stats in learn_transfer_test_stats_lst])
  np.savez(OUTPUT_DIR + '/graphs_learn_transfer_stats.npz',
          stats_mean=learn_transfer_stats_mean,
          stats_stderr=learn_transfer_stats_stderr)
  
  learn_transfer_trans_factor_mean = np.array([np.mean(test_stats,axis=0) for test_stats in learn_transfer_trans_factor_lst])
  learn_transfer_trans_factor_stderr = np.array([stats.sem(test_stats,axis=0) for test_stats in learn_transfer_trans_factor_lst])
  np.savez(OUTPUT_DIR + '/graphs_learn_transfer_trans_factor.npz',
          stats_mean=learn_transfer_trans_factor_mean,
          stats_stderr=learn_transfer_trans_factor_stderr)
  
  learn_transfer_stats_w_mean = np.asarray([np.mean(test_stats,axis=0) for test_stats in  learn_transfer_test_stats_w_lst])
  learn_transfer_stats_w_stderr = np.asarray([stats.sem(test_stats,axis=0) for test_stats in  learn_transfer_test_stats_w_lst])
  np.savez(OUTPUT_DIR + '/graphs_w_learn_transfer_stats.npz',
          stats_mean=learn_transfer_stats_w_mean,
          stats_stderr=learn_transfer_stats_w_stderr)
  
  learn_transfer_stats_y_mean = np.array([np.mean(test_stats,axis=0) for test_stats in learn_transfer_test_stats_y_lst])
  learn_transfer_stats_y_stderr = np.array([stats.sem(test_stats,axis=0) for test_stats in learn_transfer_test_stats_y_lst])
  np.savez(OUTPUT_DIR + '/graphs_y_learn_transfer_stats.npz',
          stats_mean=learn_transfer_stats_y_mean,
          stats_stderr=learn_transfer_stats_y_stderr)
# Out:
# ======================================================================================
# #Delta: 0.0, Replicate: 1
# ======================================================================================
# *** P(W|X)
# Iter 100/5000 - Loss: 33115.305   Transfer Ratio: [0.097]
# Iter 200/5000 - Loss: 6885.087   Transfer Ratio: [0.077]
# Iter 300/5000 - Loss: 11743.854   Transfer Ratio: [0.061]
# Iter 400/5000 - Loss: 20075.627   Transfer Ratio: [0.047]
# Iter 500/5000 - Loss: 18280.318   Transfer Ratio: [0.038]
# Iter 600/5000 - Loss: 6982.391   Transfer Ratio: [0.032]
# Iter 700/5000 - Loss: 19548.268   Transfer Ratio: [0.029]
# Iter 800/5000 - Loss: 15097.925   Transfer Ratio: [0.027]
# Iter 900/5000 - Loss: 20046.906   Transfer Ratio: [0.024]
# Iter 1000/5000 - Loss: 15301.428   Transfer Ratio: [0.022]
# Iter 1100/5000 - Loss: 9490.228   Transfer Ratio: [0.02]
# Iter 1200/5000 - Loss: 14960.640   Transfer Ratio: [0.019]
# Iter 1300/5000 - Loss: 18906.816   Transfer Ratio: [0.016]
# Iter 1400/5000 - Loss: 7600.539   Transfer Ratio: [0.015]
# Iter 1500/5000 - Loss: 10073.178   Transfer Ratio: [0.014]
# Iter 1600/5000 - Loss: 50302.336   Transfer Ratio: [0.013]
# Iter 1700/5000 - Loss: 35414.660   Transfer Ratio: [0.012]
# Iter 1800/5000 - Loss: 27699.939   Transfer Ratio: [0.011]
# Iter 1900/5000 - Loss: 11830.612   Transfer Ratio: [0.01]
# Iter 2000/5000 - Loss: 7863.592   Transfer Ratio: [0.009]
# Iter 2100/5000 - Loss: 12947.483   Transfer Ratio: [0.009]
# Iter 2200/5000 - Loss: 23319.338   Transfer Ratio: [0.008]
# Iter 2300/5000 - Loss: 18763.820   Transfer Ratio: [0.007]
# Iter 2400/5000 - Loss: 11256.099   Transfer Ratio: [0.007]
# Iter 2500/5000 - Loss: 17292.416   Transfer Ratio: [0.007]
# Iter 2600/5000 - Loss: 12823.376   Transfer Ratio: [0.006]
# Iter 2700/5000 - Loss: 35715.121   Transfer Ratio: [0.006]
# Iter 2800/5000 - Loss: 26521.736   Transfer Ratio: [0.006]
# Iter 2900/5000 - Loss: 8786.636   Transfer Ratio: [0.005]
# Iter 3000/5000 - Loss: 11646.398   Transfer Ratio: [0.005]
# Iter 3100/5000 - Loss: 15115.092   Transfer Ratio: [0.005]
# Iter 3200/5000 - Loss: 19694.105   Transfer Ratio: [0.004]
# Iter 3300/5000 - Loss: 25123.881   Transfer Ratio: [0.004]
# Iter 3400/5000 - Loss: 11053.030   Transfer Ratio: [0.004]
# Iter 3500/5000 - Loss: 25972.137   Transfer Ratio: [0.004]
# Iter 3600/5000 - Loss: 10104.519   Transfer Ratio: [0.003]
# Iter 3700/5000 - Loss: 24553.082   Transfer Ratio: [0.003]
# Iter 3800/5000 - Loss: 7664.881   Transfer Ratio: [0.003]
# Iter 3900/5000 - Loss: 6997.696   Transfer Ratio: [0.003]
# Iter 4000/5000 - Loss: 29218.154   Transfer Ratio: [0.003]
# Iter 4100/5000 - Loss: 13974.434   Transfer Ratio: [0.003]
# Iter 4200/5000 - Loss: 8764.174   Transfer Ratio: [0.003]
# Iter 4300/5000 - Loss: 19724.789   Transfer Ratio: [0.002]
# Iter 4400/5000 - Loss: 10158.178   Transfer Ratio: [0.002]
# Iter 4500/5000 - Loss: 8631.302   Transfer Ratio: [0.002]
# Iter 4600/5000 - Loss: 8610.932   Transfer Ratio: [0.002]
# Iter 4700/5000 - Loss: 8609.890   Transfer Ratio: [0.002]
# Iter 4800/5000 - Loss: 8608.827   Transfer Ratio: [0.002]
# Iter 4900/5000 - Loss: 8608.110   Transfer Ratio: [0.002]
# Iter 5000/5000 - Loss: 8607.468   Transfer Ratio: [0.002]
# *** P(Y|X,W)
# Iter 100/5000 - Loss: 11827.648   Transfer Ratio: [0.118]
# Iter 200/5000 - Loss: 11396.640   Transfer Ratio: [0.109]
# Iter 300/5000 - Loss: 12967.457   Transfer Ratio: [0.098]
# Iter 400/5000 - Loss: 25311.877   Transfer Ratio: [0.087]
# Iter 500/5000 - Loss: 11585.013   Transfer Ratio: [0.074]
# Iter 600/5000 - Loss: 9764.391   Transfer Ratio: [0.065]
# Iter 700/5000 - Loss: 17892.473   Transfer Ratio: [0.056]
# Iter 800/5000 - Loss: 11285.734   Transfer Ratio: [0.049]
# Iter 900/5000 - Loss: 8682.728   Transfer Ratio: [0.044]
# Iter 1000/5000 - Loss: 20002.914   Transfer Ratio: [0.04]
# Iter 1100/5000 - Loss: 14026.878   Transfer Ratio: [0.035]
# Iter 1200/5000 - Loss: 13784.374   Transfer Ratio: [0.032]
# Iter 1300/5000 - Loss: 15804.471   Transfer Ratio: [0.029]
# Iter 1400/5000 - Loss: 20807.617   Transfer Ratio: [0.026]
# Iter 1500/5000 - Loss: 13289.196   Transfer Ratio: [0.024]
# Iter 1600/5000 - Loss: 17859.818   Transfer Ratio: [0.022]
# Iter 1700/5000 - Loss: 16014.160   Transfer Ratio: [0.021]
# Iter 1800/5000 - Loss: 19297.262   Transfer Ratio: [0.019]
# Iter 1900/5000 - Loss: 10776.811   Transfer Ratio: [0.018]
# Iter 2000/5000 - Loss: 10136.048   Transfer Ratio: [0.017]
# Iter 2100/5000 - Loss: 14450.282   Transfer Ratio: [0.016]
# Iter 2200/5000 - Loss: 21600.379   Transfer Ratio: [0.015]
# Iter 2300/5000 - Loss: 15221.459   Transfer Ratio: [0.014]
# Iter 2400/5000 - Loss: 13553.114   Transfer Ratio: [0.013]
# Iter 2500/5000 - Loss: 16922.387   Transfer Ratio: [0.013]
# Iter 2600/5000 - Loss: 14675.107   Transfer Ratio: [0.012]
# Iter 2700/5000 - Loss: 16934.742   Transfer Ratio: [0.012]
# Iter 2800/5000 - Loss: 16572.547   Transfer Ratio: [0.011]
# Iter 2900/5000 - Loss: 13520.017   Transfer Ratio: [0.011]
# Iter 3000/5000 - Loss: 12416.333   Transfer Ratio: [0.01]
# Iter 3100/5000 - Loss: 19339.441   Transfer Ratio: [0.01]
# Iter 3200/5000 - Loss: 11351.095   Transfer Ratio: [0.009]
# Iter 3300/5000 - Loss: 12162.347   Transfer Ratio: [0.009]
# Iter 3400/5000 - Loss: 15803.861   Transfer Ratio: [0.008]
# Iter 3500/5000 - Loss: 21295.477   Transfer Ratio: [0.008]
# Iter 3600/5000 - Loss: 14473.132   Transfer Ratio: [0.007]
# Iter 3700/5000 - Loss: 18823.307   Transfer Ratio: [0.007]
# Iter 3800/5000 - Loss: 13975.082   Transfer Ratio: [0.007]
# Iter 3900/5000 - Loss: 17815.539   Transfer Ratio: [0.006]
# Iter 4000/5000 - Loss: 9340.500   Transfer Ratio: [0.006]
# Iter 4100/5000 - Loss: 19265.176   Transfer Ratio: [0.006]
# Iter 4200/5000 - Loss: 12810.245   Transfer Ratio: [0.006]
# Iter 4300/5000 - Loss: 18547.180   Transfer Ratio: [0.005]
# Iter 4400/5000 - Loss: 14799.046   Transfer Ratio: [0.005]
# Iter 4500/5000 - Loss: 17442.902   Transfer Ratio: [0.005]
# Iter 4600/5000 - Loss: 13307.612   Transfer Ratio: [0.005]
# Iter 4700/5000 - Loss: 11054.183   Transfer Ratio: [0.004]
# Iter 4800/5000 - Loss: 12471.081   Transfer Ratio: [0.004]
# Iter 4900/5000 - Loss: 11038.056   Transfer Ratio: [0.004]
# Iter 5000/5000 - Loss: 17211.447   Transfer Ratio: [0.004]
# *** P(Z|Y,X,W) and P(Y|W,Z)
# Iter 100/5000 - Loss: 374489.875   Transfer Ratio: [0.201]
# Iter 200/5000 - Loss: 139744.062   Transfer Ratio: [0.201]
# Iter 300/5000 - Loss: 118856.125   Transfer Ratio: [0.201]
# Iter 400/5000 - Loss: 110639.133   Transfer Ratio: [0.201]
# Iter 500/5000 - Loss: 107710.586   Transfer Ratio: [0.201]
# Iter 600/5000 - Loss: 106408.125   Transfer Ratio: [0.201]
# Iter 700/5000 - Loss: 106022.734   Transfer Ratio: [0.201]
# Iter 800/5000 - Loss: 105775.648   Transfer Ratio: [0.201]
# Iter 900/5000 - Loss: 105630.344   Transfer Ratio: [0.201]
# Iter 1000/5000 - Loss: 105729.742   Transfer Ratio: [0.201]
# Iter 1100/5000 - Loss: 105921.141   Transfer Ratio: [0.201]
# Iter 1200/5000 - Loss: 105741.188   Transfer Ratio: [0.201]
# Iter 1300/5000 - Loss: 105807.344   Transfer Ratio: [0.201]
# Iter 1400/5000 - Loss: 106111.062   Transfer Ratio: [0.201]
# Iter 1500/5000 - Loss: 105699.141   Transfer Ratio: [0.201]
# Iter 1600/5000 - Loss: 105249.047   Transfer Ratio: [0.201]
# Iter 1700/5000 - Loss: 108709.977   Transfer Ratio: [0.201]
# Iter 1800/5000 - Loss: 106280.938   Transfer Ratio: [0.201]
# Iter 1900/5000 - Loss: 105952.078   Transfer Ratio: [0.201]
# Iter 2000/5000 - Loss: 108301.625   Transfer Ratio: [0.201]
# Iter 2100/5000 - Loss: 106588.422   Transfer Ratio: [0.201]
# Iter 2200/5000 - Loss: 108008.812   Transfer Ratio: [0.201]
# Iter 2300/5000 - Loss: 113367.211   Transfer Ratio: [0.201]
# Iter 2400/5000 - Loss: 107326.578   Transfer Ratio: [0.201]
# Iter 2500/5000 - Loss: 106019.344   Transfer Ratio: [0.201]
# Iter 2600/5000 - Loss: 107654.477   Transfer Ratio: [0.201]
# Iter 2700/5000 - Loss: 107862.789   Transfer Ratio: [0.201]
# Iter 2800/5000 - Loss: 107919.141   Transfer Ratio: [0.201]
# Iter 2900/5000 - Loss: 107885.922   Transfer Ratio: [0.201]
# Iter 3000/5000 - Loss: 108041.625   Transfer Ratio: [0.201]
# Iter 3100/5000 - Loss: 108691.438   Transfer Ratio: [0.201]
# Iter 3200/5000 - Loss: 108581.711   Transfer Ratio: [0.201]
# Iter 3300/5000 - Loss: 109261.797   Transfer Ratio: [0.201]
# Iter 3400/5000 - Loss: 109874.422   Transfer Ratio: [0.201]
# Iter 3500/5000 - Loss: 110626.398   Transfer Ratio: [0.201]
# Iter 3600/5000 - Loss: 112641.734   Transfer Ratio: [0.201]
# Iter 3700/5000 - Loss: 148237.266   Transfer Ratio: [0.201]
# Iter 3800/5000 - Loss: 152083.031   Transfer Ratio: [0.201]
# Iter 3900/5000 - Loss: 148519.219   Transfer Ratio: [0.201]
# Iter 4000/5000 - Loss: 135856.531   Transfer Ratio: [0.201]
# Iter 4100/5000 - Loss: 108174.094   Transfer Ratio: [0.201]
# Iter 4200/5000 - Loss: 110400.281   Transfer Ratio: [0.201]
# Iter 4300/5000 - Loss: 113577.711   Transfer Ratio: [0.201]
# Iter 4400/5000 - Loss: 113820.609   Transfer Ratio: [0.201]
# Iter 4500/5000 - Loss: 112102.039   Transfer Ratio: [0.2]
# Iter 4600/5000 - Loss: 116161.672   Transfer Ratio: [0.2]
# Iter 4700/5000 - Loss: 114325.773   Transfer Ratio: [0.2]
# Iter 4800/5000 - Loss: 111499.562   Transfer Ratio: [0.2]
# Iter 4900/5000 - Loss: 109482.969   Transfer Ratio: [0.2]
# Iter 5000/5000 - Loss: 515633.406   Transfer Ratio: [0.2]
# ======================================================================================
# #Delta: 0.0, Replicate: 2
# ======================================================================================
# *** P(W|X)
# Iter 100/5000 - Loss: 31943.502   Transfer Ratio: [0.107]
# Iter 200/5000 - Loss: 15992.187   Transfer Ratio: [0.083]
# Iter 300/5000 - Loss: 24696.133   Transfer Ratio: [0.066]
# Iter 400/5000 - Loss: 6761.711   Transfer Ratio: [0.054]
# Iter 500/5000 - Loss: 31792.088   Transfer Ratio: [0.047]
# Iter 600/5000 - Loss: 12029.251   Transfer Ratio: [0.039]
# Iter 700/5000 - Loss: 32813.230   Transfer Ratio: [0.035]
# Iter 800/5000 - Loss: 19084.805   Transfer Ratio: [0.032]
# Iter 900/5000 - Loss: 13970.105   Transfer Ratio: [0.027]
# Iter 1000/5000 - Loss: 37345.906   Transfer Ratio: [0.024]
# Iter 1100/5000 - Loss: 18026.641   Transfer Ratio: [0.022]
# Iter 1200/5000 - Loss: 18428.838   Transfer Ratio: [0.02]
# Iter 1300/5000 - Loss: 21417.402   Transfer Ratio: [0.018]
# Iter 1400/5000 - Loss: 22529.604   Transfer Ratio: [0.017]
# Iter 1500/5000 - Loss: 27921.469   Transfer Ratio: [0.015]
# Iter 1600/5000 - Loss: 35441.531   Transfer Ratio: [0.014]
# Iter 1700/5000 - Loss: 29906.326   Transfer Ratio: [0.013]
# Iter 1800/5000 - Loss: 13379.635   Transfer Ratio: [0.012]
# Iter 1900/5000 - Loss: 15945.539   Transfer Ratio: [0.012]
# Iter 2000/5000 - Loss: 8203.074   Transfer Ratio: [0.011]
# Iter 2100/5000 - Loss: 29759.957   Transfer Ratio: [0.011]
# Iter 2200/5000 - Loss: 35219.500   Transfer Ratio: [0.01]
# Iter 2300/5000 - Loss: 11497.213   Transfer Ratio: [0.009]
# Iter 2400/5000 - Loss: 17768.246   Transfer Ratio: [0.009]
# Iter 2500/5000 - Loss: 21176.721   Transfer Ratio: [0.008]
# Iter 2600/5000 - Loss: 8304.234   Transfer Ratio: [0.008]
# Iter 2700/5000 - Loss: 10973.515   Transfer Ratio: [0.008]
# Iter 2800/5000 - Loss: 9704.614   Transfer Ratio: [0.007]
# Iter 2900/5000 - Loss: 21753.445   Transfer Ratio: [0.007]
# Iter 3000/5000 - Loss: 13362.211   Transfer Ratio: [0.006]
# Iter 3100/5000 - Loss: 12919.497   Transfer Ratio: [0.006]
# Iter 3200/5000 - Loss: 14500.423   Transfer Ratio: [0.006]
# Iter 3300/5000 - Loss: 28089.240   Transfer Ratio: [0.005]
# Iter 3400/5000 - Loss: 7791.801   Transfer Ratio: [0.005]
# Iter 3500/5000 - Loss: 11146.152   Transfer Ratio: [0.005]
# Iter 3600/5000 - Loss: 8173.758   Transfer Ratio: [0.005]
# Iter 3700/5000 - Loss: 9725.931   Transfer Ratio: [0.005]
# Iter 3800/5000 - Loss: 15358.181   Transfer Ratio: [0.004]
# Iter 3900/5000 - Loss: 24666.582   Transfer Ratio: [0.004]
# Iter 4000/5000 - Loss: 9179.425   Transfer Ratio: [0.004]
# Iter 4100/5000 - Loss: 10287.350   Transfer Ratio: [0.004]
# Iter 4200/5000 - Loss: 25721.803   Transfer Ratio: [0.003]
# Iter 4300/5000 - Loss: 11569.354   Transfer Ratio: [0.003]
# Iter 4400/5000 - Loss: 16041.128   Transfer Ratio: [0.003]
# Iter 4500/5000 - Loss: 4939.066   Transfer Ratio: [0.003]
# Iter 4600/5000 - Loss: 35769.707   Transfer Ratio: [0.003]
# Iter 4700/5000 - Loss: 18562.256   Transfer Ratio: [0.002]
# Iter 4800/5000 - Loss: 16045.587   Transfer Ratio: [0.002]
# Iter 4900/5000 - Loss: 10894.405   Transfer Ratio: [0.002]
# Iter 5000/5000 - Loss: 9733.004   Transfer Ratio: [0.002]
# *** P(Y|X,W)
# Iter 100/5000 - Loss: 13405.929   Transfer Ratio: [0.099]
# Iter 200/5000 - Loss: 17552.432   Transfer Ratio: [0.089]
# Iter 300/5000 - Loss: 15655.363   Transfer Ratio: [0.078]
# Iter 400/5000 - Loss: 13198.999   Transfer Ratio: [0.066]
# Iter 500/5000 - Loss: 16815.939   Transfer Ratio: [0.056]
# Iter 600/5000 - Loss: 13269.930   Transfer Ratio: [0.048]
# Iter 700/5000 - Loss: 16115.174   Transfer Ratio: [0.041]
# Iter 800/5000 - Loss: 13610.084   Transfer Ratio: [0.036]
# Iter 900/5000 - Loss: 17719.223   Transfer Ratio: [0.032]
# Iter 1000/5000 - Loss: 12448.973   Transfer Ratio: [0.029]
# Iter 1100/5000 - Loss: 10104.757   Transfer Ratio: [0.026]
# Iter 1200/5000 - Loss: 16994.510   Transfer Ratio: [0.023]
# Iter 1300/5000 - Loss: 18686.400   Transfer Ratio: [0.021]
# Iter 1400/5000 - Loss: 12083.463   Transfer Ratio: [0.019]
# Iter 1500/5000 - Loss: 11956.773   Transfer Ratio: [0.018]
# Iter 1600/5000 - Loss: 13237.533   Transfer Ratio: [0.016]
# Iter 1700/5000 - Loss: 11687.662   Transfer Ratio: [0.015]
# Iter 1800/5000 - Loss: 14615.006   Transfer Ratio: [0.014]
# Iter 1900/5000 - Loss: 10141.052   Transfer Ratio: [0.013]
# Iter 2000/5000 - Loss: 20870.734   Transfer Ratio: [0.012]
# Iter 2100/5000 - Loss: 12743.516   Transfer Ratio: [0.011]
# Iter 2200/5000 - Loss: 15150.858   Transfer Ratio: [0.011]
# Iter 2300/5000 - Loss: 22999.287   Transfer Ratio: [0.01]
# Iter 2400/5000 - Loss: 12478.988   Transfer Ratio: [0.009]
# Iter 2500/5000 - Loss: 10830.172   Transfer Ratio: [0.009]
# Iter 2600/5000 - Loss: 13277.775   Transfer Ratio: [0.008]
# Iter 2700/5000 - Loss: 17271.898   Transfer Ratio: [0.008]
# Iter 2800/5000 - Loss: 13060.009   Transfer Ratio: [0.007]
# Iter 2900/5000 - Loss: 16082.982   Transfer Ratio: [0.007]
# Iter 3000/5000 - Loss: 20361.287   Transfer Ratio: [0.007]
# Iter 3100/5000 - Loss: 11538.341   Transfer Ratio: [0.006]
# Iter 3200/5000 - Loss: 19722.379   Transfer Ratio: [0.006]
# Iter 3300/5000 - Loss: 20907.594   Transfer Ratio: [0.006]
# Iter 3400/5000 - Loss: 17434.363   Transfer Ratio: [0.006]
# Iter 3500/5000 - Loss: 13923.688   Transfer Ratio: [0.005]
# Iter 3600/5000 - Loss: 18523.746   Transfer Ratio: [0.005]
# Iter 3700/5000 - Loss: 17291.691   Transfer Ratio: [0.005]
# Iter 3800/5000 - Loss: 10244.914   Transfer Ratio: [0.005]
# Iter 3900/5000 - Loss: 16789.762   Transfer Ratio: [0.005]
# Iter 4000/5000 - Loss: 15105.752   Transfer Ratio: [0.004]
# Iter 4100/5000 - Loss: 16591.326   Transfer Ratio: [0.004]
# Iter 4200/5000 - Loss: 15359.378   Transfer Ratio: [0.004]
# Iter 4300/5000 - Loss: 21507.766   Transfer Ratio: [0.004]
# Iter 4400/5000 - Loss: 21631.086   Transfer Ratio: [0.004]
# Iter 4500/5000 - Loss: 14111.279   Transfer Ratio: [0.004]
# Iter 4600/5000 - Loss: 13624.257   Transfer Ratio: [0.004]
# Iter 4700/5000 - Loss: 17345.643   Transfer Ratio: [0.004]
# Iter 4800/5000 - Loss: 12452.693   Transfer Ratio: [0.004]
# Iter 4900/5000 - Loss: 20597.391   Transfer Ratio: [0.003]
# Iter 5000/5000 - Loss: 17762.846   Transfer Ratio: [0.003]
# *** P(Z|Y,X,W) and P(Y|W,Z)
# Iter 100/5000 - Loss: 387768.312   Transfer Ratio: [0.2]
# Iter 200/5000 - Loss: 138624.438   Transfer Ratio: [0.2]
# Iter 300/5000 - Loss: 118832.258   Transfer Ratio: [0.2]
# Iter 400/5000 - Loss: 111164.203   Transfer Ratio: [0.2]
# Iter 500/5000 - Loss: 108146.312   Transfer Ratio: [0.2]
# Iter 600/5000 - Loss: 106854.906   Transfer Ratio: [0.2]
# Iter 700/5000 - Loss: 106061.359   Transfer Ratio: [0.2]
# Iter 800/5000 - Loss: 105918.953   Transfer Ratio: [0.2]
# Iter 900/5000 - Loss: 105899.219   Transfer Ratio: [0.2]
# Iter 1000/5000 - Loss: 105692.297   Transfer Ratio: [0.2]
# Iter 1100/5000 - Loss: 105572.000   Transfer Ratio: [0.2]
# Iter 1200/5000 - Loss: 105815.391   Transfer Ratio: [0.2]
# Iter 1300/5000 - Loss: 106214.750   Transfer Ratio: [0.2]
# Iter 1400/5000 - Loss: 105606.523   Transfer Ratio: [0.2]
# Iter 1500/5000 - Loss: 105996.148   Transfer Ratio: [0.2]
# Iter 1600/5000 - Loss: 105390.430   Transfer Ratio: [0.2]
# Iter 1700/5000 - Loss: 107341.594   Transfer Ratio: [0.2]
# Iter 1800/5000 - Loss: 106460.484   Transfer Ratio: [0.2]
# Iter 1900/5000 - Loss: 107035.898   Transfer Ratio: [0.2]
# Iter 2000/5000 - Loss: 106878.367   Transfer Ratio: [0.2]
# Iter 2100/5000 - Loss: 107038.844   Transfer Ratio: [0.2]
# Iter 2200/5000 - Loss: 107068.281   Transfer Ratio: [0.2]
# Iter 2300/5000 - Loss: 107129.453   Transfer Ratio: [0.2]
# Iter 2400/5000 - Loss: 107538.062   Transfer Ratio: [0.2]
# Iter 2500/5000 - Loss: 107591.602   Transfer Ratio: [0.2]
# Iter 2600/5000 - Loss: 107583.883   Transfer Ratio: [0.2]
# Iter 2700/5000 - Loss: 107827.594   Transfer Ratio: [0.2]
# Iter 2800/5000 - Loss: 107978.477   Transfer Ratio: [0.2]
# Iter 2900/5000 - Loss: 108359.016   Transfer Ratio: [0.2]
# Iter 3000/5000 - Loss: 108580.867   Transfer Ratio: [0.2]
# Iter 3100/5000 - Loss: 108623.219   Transfer Ratio: [0.2]
# Iter 3200/5000 - Loss: 108868.977   Transfer Ratio: [0.2]
# Iter 3300/5000 - Loss: 109819.430   Transfer Ratio: [0.2]
# Iter 3400/5000 - Loss: 109623.055   Transfer Ratio: [0.2]
# Iter 3500/5000 - Loss: 110411.219   Transfer Ratio: [0.2]
# Iter 3600/5000 - Loss: 111570.383   Transfer Ratio: [0.2]
# Iter 3700/5000 - Loss: 117816.016   Transfer Ratio: [0.2]
# Iter 3800/5000 - Loss: 172982.656   Transfer Ratio: [0.2]
# Iter 3900/5000 - Loss: 168115.922   Transfer Ratio: [0.2]
# Iter 4000/5000 - Loss: 171227.422   Transfer Ratio: [0.2]
# Iter 4100/5000 - Loss: 154227.859   Transfer Ratio: [0.2]
# Iter 4200/5000 - Loss: 171065.844   Transfer Ratio: [0.2]
# Iter 4300/5000 - Loss: 141863.875   Transfer Ratio: [0.199]
# Iter 4400/5000 - Loss: 115556.281   Transfer Ratio: [0.199]
# Iter 4500/5000 - Loss: 125180.062   Transfer Ratio: [0.199]
# Iter 4600/5000 - Loss: 110145.188   Transfer Ratio: [0.199]
# Iter 4700/5000 - Loss: 111248.031   Transfer Ratio: [0.199]
# Iter 4800/5000 - Loss: 109370.523   Transfer Ratio: [0.199]
# Iter 4900/5000 - Loss: 114539.117   Transfer Ratio: [0.199]
# Iter 5000/5000 - Loss: 383211.125   Transfer Ratio: [0.198]
# ======================================================================================
# #Delta: 0.0, Replicate: 3
# ======================================================================================
# *** P(W|X)
# Iter 100/5000 - Loss: 17888.002   Transfer Ratio: [0.126]
# Iter 200/5000 - Loss: 24793.787   Transfer Ratio: [0.088]
# Iter 300/5000 - Loss: 11334.261   Transfer Ratio: [0.069]
# Iter 400/5000 - Loss: 14686.936   Transfer Ratio: [0.056]
# Iter 500/5000 - Loss: 40231.566   Transfer Ratio: [0.045]
# Iter 600/5000 - Loss: 12331.586   Transfer Ratio: [0.038]
# Iter 700/5000 - Loss: 24077.232   Transfer Ratio: [0.034]
# Iter 800/5000 - Loss: 14275.672   Transfer Ratio: [0.031]
# Iter 900/5000 - Loss: 12128.197   Transfer Ratio: [0.027]
# Iter 1000/5000 - Loss: 9311.431   Transfer Ratio: [0.025]
# Iter 1100/5000 - Loss: 16310.387   Transfer Ratio: [0.022]
# Iter 1200/5000 - Loss: 10609.554   Transfer Ratio: [0.02]
# Iter 1300/5000 - Loss: 9240.099   Transfer Ratio: [0.019]
# Iter 1400/5000 - Loss: 30642.104   Transfer Ratio: [0.017]
# Iter 1500/5000 - Loss: 26127.184   Transfer Ratio: [0.016]
# Iter 1600/5000 - Loss: 28814.170   Transfer Ratio: [0.014]
# Iter 1700/5000 - Loss: 11363.133   Transfer Ratio: [0.013]
# Iter 1800/5000 - Loss: 14872.569   Transfer Ratio: [0.012]
# Iter 1900/5000 - Loss: 17052.590   Transfer Ratio: [0.011]
# Iter 2000/5000 - Loss: 13453.818   Transfer Ratio: [0.01]
# Iter 2100/5000 - Loss: 14519.004   Transfer Ratio: [0.01]
# Iter 2200/5000 - Loss: 12309.194   Transfer Ratio: [0.009]
# Iter 2300/5000 - Loss: 22967.230   Transfer Ratio: [0.009]
# Iter 2400/5000 - Loss: 26803.324   Transfer Ratio: [0.008]
# Iter 2500/5000 - Loss: 19291.238   Transfer Ratio: [0.008]
# Iter 2600/5000 - Loss: 14491.521   Transfer Ratio: [0.007]
# Iter 2700/5000 - Loss: 16635.893   Transfer Ratio: [0.007]
# Iter 2800/5000 - Loss: 15807.364   Transfer Ratio: [0.006]
# Iter 2900/5000 - Loss: 11788.387   Transfer Ratio: [0.006]
# Iter 3000/5000 - Loss: 14410.293   Transfer Ratio: [0.006]
# Iter 3100/5000 - Loss: 29029.068   Transfer Ratio: [0.005]
# Iter 3200/5000 - Loss: 31196.223   Transfer Ratio: [0.005]
# Iter 3300/5000 - Loss: 16126.883   Transfer Ratio: [0.005]
# Iter 3400/5000 - Loss: 35601.703   Transfer Ratio: [0.005]
# Iter 3500/5000 - Loss: 30426.738   Transfer Ratio: [0.004]
# Iter 3600/5000 - Loss: 22182.094   Transfer Ratio: [0.004]
# Iter 3700/5000 - Loss: 28719.494   Transfer Ratio: [0.004]
# Iter 3800/5000 - Loss: 22290.572   Transfer Ratio: [0.004]
# Iter 3900/5000 - Loss: 32956.988   Transfer Ratio: [0.003]
# Iter 4000/5000 - Loss: 24998.018   Transfer Ratio: [0.003]
# Iter 4100/5000 - Loss: 22220.258   Transfer Ratio: [0.003]
# Iter 4200/5000 - Loss: 11286.691   Transfer Ratio: [0.003]
# Iter 4300/5000 - Loss: 23966.785   Transfer Ratio: [0.003]
# Iter 4400/5000 - Loss: 23829.662   Transfer Ratio: [0.003]
# Iter 4500/5000 - Loss: 26783.893   Transfer Ratio: [0.002]
# Iter 4600/5000 - Loss: 11274.589   Transfer Ratio: [0.002]
# Iter 4700/5000 - Loss: 38405.332   Transfer Ratio: [0.002]
# Iter 4800/5000 - Loss: 33865.531   Transfer Ratio: [0.002]
# Iter 4900/5000 - Loss: 18560.596   Transfer Ratio: [0.002]
# Iter 5000/5000 - Loss: 11643.535   Transfer Ratio: [0.002]
# *** P(Y|X,W)
# Iter 100/5000 - Loss: 11754.873   Transfer Ratio: [0.135]
# Iter 200/5000 - Loss: 13170.741   Transfer Ratio: [0.125]
# Iter 300/5000 - Loss: 15381.987   Transfer Ratio: [0.116]
# Iter 400/5000 - Loss: 13603.223   Transfer Ratio: [0.104]
# Iter 500/5000 - Loss: 15447.588   Transfer Ratio: [0.093]
# Iter 600/5000 - Loss: 13295.627   Transfer Ratio: [0.083]
# Iter 700/5000 - Loss: 11980.668   Transfer Ratio: [0.074]
# Iter 800/5000 - Loss: 12224.297   Transfer Ratio: [0.067]
# Iter 900/5000 - Loss: 21839.617   Transfer Ratio: [0.06]
# Iter 1000/5000 - Loss: 15935.950   Transfer Ratio: [0.053]
# Iter 1100/5000 - Loss: 14783.866   Transfer Ratio: [0.048]
# Iter 1200/5000 - Loss: 16885.652   Transfer Ratio: [0.044]
# Iter 1300/5000 - Loss: 15980.248   Transfer Ratio: [0.041]
# Iter 1400/5000 - Loss: 17969.523   Transfer Ratio: [0.038]
# Iter 1500/5000 - Loss: 17741.895   Transfer Ratio: [0.035]
# Iter 1600/5000 - Loss: 14941.546   Transfer Ratio: [0.033]
# Iter 1700/5000 - Loss: 17468.336   Transfer Ratio: [0.03]
# Iter 1800/5000 - Loss: 17215.096   Transfer Ratio: [0.028]
# Iter 1900/5000 - Loss: 20943.516   Transfer Ratio: [0.026]
# Iter 2000/5000 - Loss: 17743.389   Transfer Ratio: [0.025]
# Iter 2100/5000 - Loss: 9047.105   Transfer Ratio: [0.023]
# Iter 2200/5000 - Loss: 18998.529   Transfer Ratio: [0.021]
# Iter 2300/5000 - Loss: 17033.148   Transfer Ratio: [0.02]
# Iter 2400/5000 - Loss: 13770.884   Transfer Ratio: [0.019]
# Iter 2500/5000 - Loss: 12012.889   Transfer Ratio: [0.018]
# Iter 2600/5000 - Loss: 21322.289   Transfer Ratio: [0.017]
# Iter 2700/5000 - Loss: 12249.207   Transfer Ratio: [0.015]
# Iter 2800/5000 - Loss: 20775.393   Transfer Ratio: [0.015]
# Iter 2900/5000 - Loss: 16065.646   Transfer Ratio: [0.014]
# Iter 3000/5000 - Loss: 15023.111   Transfer Ratio: [0.013]
# Iter 3100/5000 - Loss: 11764.823   Transfer Ratio: [0.012]
# Iter 3200/5000 - Loss: 21357.234   Transfer Ratio: [0.012]
# Iter 3300/5000 - Loss: 14556.735   Transfer Ratio: [0.011]
# Iter 3400/5000 - Loss: 13651.895   Transfer Ratio: [0.01]
# Iter 3500/5000 - Loss: 22316.799   Transfer Ratio: [0.01]
# Iter 3600/5000 - Loss: 17475.260   Transfer Ratio: [0.009]
# Iter 3700/5000 - Loss: 11803.227   Transfer Ratio: [0.009]
# Iter 3800/5000 - Loss: 10413.536   Transfer Ratio: [0.008]
# Iter 3900/5000 - Loss: 11888.519   Transfer Ratio: [0.008]
# Iter 4000/5000 - Loss: 24357.529   Transfer Ratio: [0.008]
# Iter 4100/5000 - Loss: 13577.848   Transfer Ratio: [0.007]
# Iter 4200/5000 - Loss: 20176.402   Transfer Ratio: [0.007]
# Iter 4300/5000 - Loss: 20618.688   Transfer Ratio: [0.007]
# Iter 4400/5000 - Loss: 12603.938   Transfer Ratio: [0.006]
# Iter 4500/5000 - Loss: 13548.084   Transfer Ratio: [0.006]
# Iter 4600/5000 - Loss: 19812.447   Transfer Ratio: [0.006]
# Iter 4700/5000 - Loss: 22075.238   Transfer Ratio: [0.005]
# Iter 4800/5000 - Loss: 14341.273   Transfer Ratio: [0.005]
# Iter 4900/5000 - Loss: 21445.857   Transfer Ratio: [0.005]
# Iter 5000/5000 - Loss: 11075.104   Transfer Ratio: [0.005]
# *** P(Z|Y,X,W) and P(Y|W,Z)
# Iter 100/5000 - Loss: 388807.875   Transfer Ratio: [0.2]
# Iter 200/5000 - Loss: 139561.828   Transfer Ratio: [0.2]
# Iter 300/5000 - Loss: 118730.219   Transfer Ratio: [0.2]
# Iter 400/5000 - Loss: 111008.844   Transfer Ratio: [0.2]
# Iter 500/5000 - Loss: 107915.148   Transfer Ratio: [0.2]
# Iter 600/5000 - Loss: 106722.250   Transfer Ratio: [0.2]
# Iter 700/5000 - Loss: 106092.414   Transfer Ratio: [0.2]
# Iter 800/5000 - Loss: 105771.297   Transfer Ratio: [0.2]
# Iter 900/5000 - Loss: 105632.695   Transfer Ratio: [0.2]
# Iter 1000/5000 - Loss: 105603.391   Transfer Ratio: [0.2]
# Iter 1100/5000 - Loss: 105882.383   Transfer Ratio: [0.2]
# Iter 1200/5000 - Loss: 105852.930   Transfer Ratio: [0.2]
# Iter 1300/5000 - Loss: 105656.875   Transfer Ratio: [0.2]
# Iter 1400/5000 - Loss: 105308.844   Transfer Ratio: [0.2]
# Iter 1500/5000 - Loss: 106788.852   Transfer Ratio: [0.2]
# Iter 1600/5000 - Loss: 108804.781   Transfer Ratio: [0.2]
# Iter 1700/5000 - Loss: 106862.211   Transfer Ratio: [0.2]
# Iter 1800/5000 - Loss: 105790.742   Transfer Ratio: [0.2]
# Iter 1900/5000 - Loss: 105666.508   Transfer Ratio: [0.2]
# Iter 2000/5000 - Loss: 108530.211   Transfer Ratio: [0.2]
# Iter 2100/5000 - Loss: 109257.125   Transfer Ratio: [0.2]
# Iter 2200/5000 - Loss: 106784.672   Transfer Ratio: [0.2]
# Iter 2300/5000 - Loss: 112169.555   Transfer Ratio: [0.2]
# Iter 2400/5000 - Loss: 106136.352   Transfer Ratio: [0.2]
# Iter 2500/5000 - Loss: 106317.344   Transfer Ratio: [0.2]
# Iter 2600/5000 - Loss: 107753.727   Transfer Ratio: [0.2]
# Iter 2700/5000 - Loss: 107723.242   Transfer Ratio: [0.2]
# Iter 2800/5000 - Loss: 107748.469   Transfer Ratio: [0.2]
# Iter 2900/5000 - Loss: 108190.062   Transfer Ratio: [0.2]
# Iter 3000/5000 - Loss: 108476.164   Transfer Ratio: [0.2]
# Iter 3100/5000 - Loss: 108607.945   Transfer Ratio: [0.2]
# Iter 3200/5000 - Loss: 109084.266   Transfer Ratio: [0.2]
# Iter 3300/5000 - Loss: 109573.156   Transfer Ratio: [0.2]
# Iter 3400/5000 - Loss: 110282.625   Transfer Ratio: [0.2]
# Iter 3500/5000 - Loss: 110999.367   Transfer Ratio: [0.2]
# Iter 3600/5000 - Loss: 114394.891   Transfer Ratio: [0.2]
# Iter 3700/5000 - Loss: 139411.891   Transfer Ratio: [0.2]
# Iter 3800/5000 - Loss: 111666.070   Transfer Ratio: [0.2]
# Iter 3900/5000 - Loss: 111509.383   Transfer Ratio: [0.2]
# Iter 4000/5000 - Loss: 108809.352   Transfer Ratio: [0.2]
# Iter 4100/5000 - Loss: 108636.344   Transfer Ratio: [0.2]
# Iter 4200/5000 - Loss: 127098.445   Transfer Ratio: [0.2]
# Iter 4300/5000 - Loss: 123307.922   Transfer Ratio: [0.2]
# Iter 4400/5000 - Loss: 107338.953   Transfer Ratio: [0.2]
# Iter 4500/5000 - Loss: 112229.227   Transfer Ratio: [0.2]
# Iter 4600/5000 - Loss: 110451.109   Transfer Ratio: [0.2]
# Iter 4700/5000 - Loss: 162000.969   Transfer Ratio: [0.2]
# Iter 4800/5000 - Loss: 115756.523   Transfer Ratio: [0.199]
# Iter 4900/5000 - Loss: 108588.945   Transfer Ratio: [0.199]
# Iter 5000/5000 - Loss: 505344.062   Transfer Ratio: [0.199]
# ======================================================================================
# #Delta: 0.0, Replicate: 4
# ======================================================================================
# *** P(W|X)
# Iter 100/5000 - Loss: 7739.531   Transfer Ratio: [0.103]
# Iter 200/5000 - Loss: 27298.938   Transfer Ratio: [0.077]
# Iter 300/5000 - Loss: 8062.974   Transfer Ratio: [0.061]
# Iter 400/5000 - Loss: 37158.410   Transfer Ratio: [0.053]
# Iter 500/5000 - Loss: 14063.447   Transfer Ratio: [0.043]
# Iter 600/5000 - Loss: 8248.120   Transfer Ratio: [0.039]
# Iter 700/5000 - Loss: 29116.711   Transfer Ratio: [0.035]
# Iter 800/5000 - Loss: 33244.340   Transfer Ratio: [0.029]
# Iter 900/5000 - Loss: 16201.254   Transfer Ratio: [0.025]
# Iter 1000/5000 - Loss: 18824.211   Transfer Ratio: [0.023]
# Iter 1100/5000 - Loss: 11228.911   Transfer Ratio: [0.021]
# Iter 1200/5000 - Loss: 8629.680   Transfer Ratio: [0.02]
# Iter 1300/5000 - Loss: 9749.973   Transfer Ratio: [0.018]
# Iter 1400/5000 - Loss: 12027.543   Transfer Ratio: [0.016]
# Iter 1500/5000 - Loss: 8782.055   Transfer Ratio: [0.015]
# Iter 1600/5000 - Loss: 10305.282   Transfer Ratio: [0.014]
# Iter 1700/5000 - Loss: 7107.718   Transfer Ratio: [0.014]
# Iter 1800/5000 - Loss: 7897.521   Transfer Ratio: [0.013]
# Iter 1900/5000 - Loss: 10247.216   Transfer Ratio: [0.013]
# Iter 2000/5000 - Loss: 7112.165   Transfer Ratio: [0.012]
# Iter 2100/5000 - Loss: 7901.772   Transfer Ratio: [0.012]
# Iter 2200/5000 - Loss: 10250.203   Transfer Ratio: [0.011]
# Iter 2300/5000 - Loss: 7114.882   Transfer Ratio: [0.011]
# Iter 2400/5000 - Loss: 7903.960   Transfer Ratio: [0.01]
# Iter 2500/5000 - Loss: 10251.928   Transfer Ratio: [0.01]
# Iter 2600/5000 - Loss: 7116.589   Transfer Ratio: [0.009]
# Iter 2700/5000 - Loss: 7905.882   Transfer Ratio: [0.009]
# Iter 2800/5000 - Loss: 10253.155   Transfer Ratio: [0.009]
# Iter 2900/5000 - Loss: 7117.807   Transfer Ratio: [0.008]
# Iter 3000/5000 - Loss: 7906.602   Transfer Ratio: [0.008]
# Iter 3100/5000 - Loss: 10254.051   Transfer Ratio: [0.007]
# Iter 3200/5000 - Loss: 7118.614   Transfer Ratio: [0.007]
# Iter 3300/5000 - Loss: 7907.321   Transfer Ratio: [0.007]
# Iter 3400/5000 - Loss: 10254.809   Transfer Ratio: [0.006]
# Iter 3500/5000 - Loss: 7119.193   Transfer Ratio: [0.006]
# Iter 3600/5000 - Loss: 7907.862   Transfer Ratio: [0.006]
# Iter 3700/5000 - Loss: 10255.096   Transfer Ratio: [0.006]
# Iter 3800/5000 - Loss: 7119.733   Transfer Ratio: [0.005]
# Iter 3900/5000 - Loss: 7908.298   Transfer Ratio: [0.005]
# Iter 4000/5000 - Loss: 10255.248   Transfer Ratio: [0.005]
# Iter 4100/5000 - Loss: 7119.724   Transfer Ratio: [0.005]
# Iter 4200/5000 - Loss: 7908.402   Transfer Ratio: [0.004]
# Iter 4300/5000 - Loss: 10255.168   Transfer Ratio: [0.004]
# Iter 4400/5000 - Loss: 7120.155   Transfer Ratio: [0.004]
# Iter 4500/5000 - Loss: 7908.504   Transfer Ratio: [0.004]
# Iter 4600/5000 - Loss: 10255.537   Transfer Ratio: [0.004]
# Iter 4700/5000 - Loss: 7120.100   Transfer Ratio: [0.003]
# Iter 4800/5000 - Loss: 7908.432   Transfer Ratio: [0.003]
# Iter 4900/5000 - Loss: 10255.812   Transfer Ratio: [0.003]
# Iter 5000/5000 - Loss: 7120.434   Transfer Ratio: [0.003]
# *** P(Y|X,W)
# Iter 100/5000 - Loss: 11758.059   Transfer Ratio: [0.126]
# Iter 200/5000 - Loss: 16394.809   Transfer Ratio: [0.117]
# Iter 300/5000 - Loss: 14261.900   Transfer Ratio: [0.105]
# Iter 400/5000 - Loss: 13920.459   Transfer Ratio: [0.091]
# Iter 500/5000 - Loss: 16162.670   Transfer Ratio: [0.08]
# Iter 600/5000 - Loss: 17469.863   Transfer Ratio: [0.07]
# Iter 700/5000 - Loss: 11555.768   Transfer Ratio: [0.061]
# Iter 800/5000 - Loss: 16259.005   Transfer Ratio: [0.054]
# Iter 900/5000 - Loss: 12291.187   Transfer Ratio: [0.048]
# Iter 1000/5000 - Loss: 11141.821   Transfer Ratio: [0.044]
# Iter 1100/5000 - Loss: 14165.468   Transfer Ratio: [0.039]
# Iter 1200/5000 - Loss: 17209.391   Transfer Ratio: [0.036]
# Iter 1300/5000 - Loss: 14668.401   Transfer Ratio: [0.033]
# Iter 1400/5000 - Loss: 8182.402   Transfer Ratio: [0.03]
# Iter 1500/5000 - Loss: 16982.760   Transfer Ratio: [0.028]
# Iter 1600/5000 - Loss: 17850.941   Transfer Ratio: [0.025]
# Iter 1700/5000 - Loss: 15786.459   Transfer Ratio: [0.024]
# Iter 1800/5000 - Loss: 7594.577   Transfer Ratio: [0.022]
# Iter 1900/5000 - Loss: 16862.400   Transfer Ratio: [0.021]
# Iter 2000/5000 - Loss: 14300.786   Transfer Ratio: [0.019]
# Iter 2100/5000 - Loss: 10338.132   Transfer Ratio: [0.018]
# Iter 2200/5000 - Loss: 10995.013   Transfer Ratio: [0.017]
# Iter 2300/5000 - Loss: 14635.771   Transfer Ratio: [0.016]
# Iter 2400/5000 - Loss: 18371.777   Transfer Ratio: [0.015]
# Iter 2500/5000 - Loss: 9777.572   Transfer Ratio: [0.014]
# Iter 2600/5000 - Loss: 25758.385   Transfer Ratio: [0.013]
# Iter 2700/5000 - Loss: 20228.463   Transfer Ratio: [0.012]
# Iter 2800/5000 - Loss: 12599.295   Transfer Ratio: [0.012]
# Iter 2900/5000 - Loss: 19916.086   Transfer Ratio: [0.011]
# Iter 3000/5000 - Loss: 14803.588   Transfer Ratio: [0.011]
# Iter 3100/5000 - Loss: 15313.540   Transfer Ratio: [0.01]
# Iter 3200/5000 - Loss: 20496.139   Transfer Ratio: [0.009]
# Iter 3300/5000 - Loss: 17850.922   Transfer Ratio: [0.009]
# Iter 3400/5000 - Loss: 12991.215   Transfer Ratio: [0.009]
# Iter 3500/5000 - Loss: 11695.025   Transfer Ratio: [0.008]
# Iter 3600/5000 - Loss: 11488.167   Transfer Ratio: [0.008]
# Iter 3700/5000 - Loss: 12715.243   Transfer Ratio: [0.007]
# Iter 3800/5000 - Loss: 10269.631   Transfer Ratio: [0.007]
# Iter 3900/5000 - Loss: 11334.935   Transfer Ratio: [0.007]
# Iter 4000/5000 - Loss: 22329.137   Transfer Ratio: [0.006]
# Iter 4100/5000 - Loss: 13664.485   Transfer Ratio: [0.006]
# Iter 4200/5000 - Loss: 15202.972   Transfer Ratio: [0.006]
# Iter 4300/5000 - Loss: 9153.316   Transfer Ratio: [0.006]
# Iter 4400/5000 - Loss: 18415.693   Transfer Ratio: [0.005]
# Iter 4500/5000 - Loss: 12039.614   Transfer Ratio: [0.005]
# Iter 4600/5000 - Loss: 15889.817   Transfer Ratio: [0.005]
# Iter 4700/5000 - Loss: 16718.312   Transfer Ratio: [0.005]
# Iter 4800/5000 - Loss: 11749.520   Transfer Ratio: [0.004]
# Iter 4900/5000 - Loss: 16636.426   Transfer Ratio: [0.004]
# Iter 5000/5000 - Loss: 16279.640   Transfer Ratio: [0.004]
# *** P(Z|Y,X,W) and P(Y|W,Z)
# Iter 100/5000 - Loss: 374931.438   Transfer Ratio: [0.2]
# Iter 200/5000 - Loss: 140619.344   Transfer Ratio: [0.2]
# Iter 300/5000 - Loss: 119383.414   Transfer Ratio: [0.2]
# Iter 400/5000 - Loss: 111136.602   Transfer Ratio: [0.2]
# Iter 500/5000 - Loss: 107902.094   Transfer Ratio: [0.2]
# Iter 600/5000 - Loss: 106521.836   Transfer Ratio: [0.2]
# Iter 700/5000 - Loss: 106322.664   Transfer Ratio: [0.2]
# Iter 800/5000 - Loss: 105808.648   Transfer Ratio: [0.2]
# Iter 900/5000 - Loss: 105587.789   Transfer Ratio: [0.2]
# Iter 1000/5000 - Loss: 105569.203   Transfer Ratio: [0.2]
# Iter 1100/5000 - Loss: 105685.891   Transfer Ratio: [0.2]
# Iter 1200/5000 - Loss: 105843.750   Transfer Ratio: [0.2]
# Iter 1300/5000 - Loss: 105779.297   Transfer Ratio: [0.2]
# Iter 1400/5000 - Loss: 105199.781   Transfer Ratio: [0.2]
# Iter 1500/5000 - Loss: 106563.328   Transfer Ratio: [0.2]
# Iter 1600/5000 - Loss: 105606.727   Transfer Ratio: [0.2]
# Iter 1700/5000 - Loss: 105269.117   Transfer Ratio: [0.2]
# Iter 1800/5000 - Loss: 106118.195   Transfer Ratio: [0.2]
# Iter 1900/5000 - Loss: 105634.352   Transfer Ratio: [0.2]
# Iter 2000/5000 - Loss: 109060.984   Transfer Ratio: [0.2]
# Iter 2100/5000 - Loss: 106924.180   Transfer Ratio: [0.2]
# Iter 2200/5000 - Loss: 107168.406   Transfer Ratio: [0.2]
# Iter 2300/5000 - Loss: 108003.242   Transfer Ratio: [0.2]
# Iter 2400/5000 - Loss: 107445.484   Transfer Ratio: [0.2]
# Iter 2500/5000 - Loss: 107448.969   Transfer Ratio: [0.2]
# Iter 2600/5000 - Loss: 107618.914   Transfer Ratio: [0.2]
# Iter 2700/5000 - Loss: 108040.031   Transfer Ratio: [0.2]
# Iter 2800/5000 - Loss: 108117.000   Transfer Ratio: [0.2]
# Iter 2900/5000 - Loss: 108418.383   Transfer Ratio: [0.2]
# Iter 3000/5000 - Loss: 108472.547   Transfer Ratio: [0.2]
# Iter 3100/5000 - Loss: 108544.414   Transfer Ratio: [0.2]
# Iter 3200/5000 - Loss: 108688.070   Transfer Ratio: [0.2]
# Iter 3300/5000 - Loss: 109446.156   Transfer Ratio: [0.2]
# Iter 3400/5000 - Loss: 110173.016   Transfer Ratio: [0.2]
# Iter 3500/5000 - Loss: 110572.031   Transfer Ratio: [0.2]
# Iter 3600/5000 - Loss: 111702.133   Transfer Ratio: [0.2]
# Iter 3700/5000 - Loss: 137621.641   Transfer Ratio: [0.2]
# Iter 3800/5000 - Loss: 119454.859   Transfer Ratio: [0.2]
# Iter 3900/5000 - Loss: 121119.781   Transfer Ratio: [0.2]
# Iter 4000/5000 - Loss: 135666.953   Transfer Ratio: [0.2]
# Iter 4100/5000 - Loss: 130256.625   Transfer Ratio: [0.2]
# Iter 4200/5000 - Loss: 111710.109   Transfer Ratio: [0.2]
# Iter 4300/5000 - Loss: 113544.914   Transfer Ratio: [0.2]
# Iter 4400/5000 - Loss: 110697.297   Transfer Ratio: [0.2]
# Iter 4500/5000 - Loss: 121349.703   Transfer Ratio: [0.2]
# Iter 4600/5000 - Loss: 120160.797   Transfer Ratio: [0.2]
# Iter 4700/5000 - Loss: 154303.859   Transfer Ratio: [0.199]
# Iter 4800/5000 - Loss: 109506.594   Transfer Ratio: [0.199]
# Iter 4900/5000 - Loss: 109097.734   Transfer Ratio: [0.199]
# Iter 5000/5000 - Loss: 542773.750   Transfer Ratio: [0.199]
# ======================================================================================
# #Delta: 0.0, Replicate: 5
# ======================================================================================
# *** P(W|X)
# Iter 100/5000 - Loss: 23484.221   Transfer Ratio: [0.126]
# Iter 200/5000 - Loss: 19972.104   Transfer Ratio: [0.088]
# Iter 300/5000 - Loss: 23815.623   Transfer Ratio: [0.072]
# Iter 400/5000 - Loss: 20982.387   Transfer Ratio: [0.052]
# Iter 500/5000 - Loss: 6032.163   Transfer Ratio: [0.043]
# Iter 600/5000 - Loss: 3834.975   Transfer Ratio: [0.035]
# Iter 700/5000 - Loss: 11363.113   Transfer Ratio: [0.031]
# Iter 800/5000 - Loss: 11148.896   Transfer Ratio: [0.028]
# Iter 900/5000 - Loss: 22376.217   Transfer Ratio: [0.024]
# Iter 1000/5000 - Loss: 13184.141   Transfer Ratio: [0.022]
# Iter 1100/5000 - Loss: 15072.248   Transfer Ratio: [0.021]
# Iter 1200/5000 - Loss: 13728.062   Transfer Ratio: [0.019]
# Iter 1300/5000 - Loss: 12563.964   Transfer Ratio: [0.017]
# Iter 1400/5000 - Loss: 13568.178   Transfer Ratio: [0.016]
# Iter 1500/5000 - Loss: 21178.814   Transfer Ratio: [0.014]
# Iter 1600/5000 - Loss: 21473.654   Transfer Ratio: [0.013]
# Iter 1700/5000 - Loss: 27841.680   Transfer Ratio: [0.012]
# Iter 1800/5000 - Loss: 20287.873   Transfer Ratio: [0.011]
# Iter 1900/5000 - Loss: 31882.541   Transfer Ratio: [0.01]
# Iter 2000/5000 - Loss: 24443.604   Transfer Ratio: [0.01]
# Iter 2100/5000 - Loss: 10261.130   Transfer Ratio: [0.009]
# Iter 2200/5000 - Loss: 25025.289   Transfer Ratio: [0.008]
# Iter 2300/5000 - Loss: 28888.209   Transfer Ratio: [0.008]
# Iter 2400/5000 - Loss: 12435.499   Transfer Ratio: [0.007]
# Iter 2500/5000 - Loss: 17193.840   Transfer Ratio: [0.007]
# Iter 2600/5000 - Loss: 10953.892   Transfer Ratio: [0.007]
# Iter 2700/5000 - Loss: 12070.608   Transfer Ratio: [0.006]
# Iter 2800/5000 - Loss: 12041.631   Transfer Ratio: [0.006]
# Iter 2900/5000 - Loss: 12037.947   Transfer Ratio: [0.006]
# Iter 3000/5000 - Loss: 12034.620   Transfer Ratio: [0.006]
# Iter 3100/5000 - Loss: 12031.429   Transfer Ratio: [0.006]
# Iter 3200/5000 - Loss: 12028.832   Transfer Ratio: [0.006]
# Iter 3300/5000 - Loss: 12026.256   Transfer Ratio: [0.005]
# Iter 3400/5000 - Loss: 12024.199   Transfer Ratio: [0.005]
# Iter 3500/5000 - Loss: 12022.110   Transfer Ratio: [0.005]
# Iter 3600/5000 - Loss: 12020.441   Transfer Ratio: [0.005]
# Iter 3700/5000 - Loss: 12018.898   Transfer Ratio: [0.005]
# Iter 3800/5000 - Loss: 12017.569   Transfer Ratio: [0.005]
# Iter 3900/5000 - Loss: 12016.183   Transfer Ratio: [0.004]
# Iter 4000/5000 - Loss: 12014.999   Transfer Ratio: [0.004]
# Iter 4100/5000 - Loss: 12014.244   Transfer Ratio: [0.004]
# Iter 4200/5000 - Loss: 12013.135   Transfer Ratio: [0.004]
# Iter 4300/5000 - Loss: 12012.295   Transfer Ratio: [0.004]
# Iter 4400/5000 - Loss: 12011.639   Transfer Ratio: [0.004]
# Iter 4500/5000 - Loss: 12010.931   Transfer Ratio: [0.004]
# Iter 4600/5000 - Loss: 12010.336   Transfer Ratio: [0.003]
# Iter 4700/5000 - Loss: 12009.768   Transfer Ratio: [0.003]
# Iter 4800/5000 - Loss: 12009.281   Transfer Ratio: [0.003]
# Iter 4900/5000 - Loss: 12008.852   Transfer Ratio: [0.003]
# Iter 5000/5000 - Loss: 12008.469   Transfer Ratio: [0.003]
# *** P(Y|X,W)
# Iter 100/5000 - Loss: 14249.089   Transfer Ratio: [0.111]
# Iter 200/5000 - Loss: 13294.457   Transfer Ratio: [0.094]
# Iter 300/5000 - Loss: 13163.101   Transfer Ratio: [0.077]
# Iter 400/5000 - Loss: 6300.779   Transfer Ratio: [0.063]
# Iter 500/5000 - Loss: 13582.705   Transfer Ratio: [0.051]
# Iter 600/5000 - Loss: 15252.801   Transfer Ratio: [0.043]
# Iter 700/5000 - Loss: 22168.297   Transfer Ratio: [0.036]
# Iter 800/5000 - Loss: 13570.173   Transfer Ratio: [0.031]
# Iter 900/5000 - Loss: 12442.262   Transfer Ratio: [0.027]
# Iter 1000/5000 - Loss: 22451.434   Transfer Ratio: [0.023]
# Iter 1100/5000 - Loss: 14439.532   Transfer Ratio: [0.021]
# Iter 1200/5000 - Loss: 14289.250   Transfer Ratio: [0.019]
# Iter 1300/5000 - Loss: 19197.010   Transfer Ratio: [0.017]
# Iter 1400/5000 - Loss: 10325.865   Transfer Ratio: [0.016]
# Iter 1500/5000 - Loss: 12842.465   Transfer Ratio: [0.014]
# Iter 1600/5000 - Loss: 15495.343   Transfer Ratio: [0.013]
# Iter 1700/5000 - Loss: 12287.602   Transfer Ratio: [0.012]
# Iter 1800/5000 - Loss: 17777.566   Transfer Ratio: [0.011]
# Iter 1900/5000 - Loss: 19369.176   Transfer Ratio: [0.01]
# Iter 2000/5000 - Loss: 16347.017   Transfer Ratio: [0.01]
# Iter 2100/5000 - Loss: 15329.340   Transfer Ratio: [0.009]
# Iter 2200/5000 - Loss: 10856.336   Transfer Ratio: [0.008]
# Iter 2300/5000 - Loss: 10658.364   Transfer Ratio: [0.008]
# Iter 2400/5000 - Loss: 12073.548   Transfer Ratio: [0.008]
# Iter 2500/5000 - Loss: 13789.421   Transfer Ratio: [0.007]
# Iter 2600/5000 - Loss: 17491.393   Transfer Ratio: [0.007]
# Iter 2700/5000 - Loss: 16412.064   Transfer Ratio: [0.006]
# Iter 2800/5000 - Loss: 15555.219   Transfer Ratio: [0.006]
# Iter 2900/5000 - Loss: 14023.242   Transfer Ratio: [0.006]
# Iter 3000/5000 - Loss: 20486.855   Transfer Ratio: [0.006]
# Iter 3100/5000 - Loss: 14360.043   Transfer Ratio: [0.006]
# Iter 3200/5000 - Loss: 13971.384   Transfer Ratio: [0.005]
# Iter 3300/5000 - Loss: 16421.613   Transfer Ratio: [0.005]
# Iter 3400/5000 - Loss: 19433.219   Transfer Ratio: [0.005]
# Iter 3500/5000 - Loss: 18321.900   Transfer Ratio: [0.005]
# Iter 3600/5000 - Loss: 13346.336   Transfer Ratio: [0.005]
# Iter 3700/5000 - Loss: 16463.184   Transfer Ratio: [0.005]
# Iter 3800/5000 - Loss: 12788.874   Transfer Ratio: [0.005]
# Iter 3900/5000 - Loss: 27677.943   Transfer Ratio: [0.004]
# Iter 4000/5000 - Loss: 24877.703   Transfer Ratio: [0.004]
# Iter 4100/5000 - Loss: 17750.217   Transfer Ratio: [0.004]
# Iter 4200/5000 - Loss: 19329.570   Transfer Ratio: [0.004]
# Iter 4300/5000 - Loss: 17912.539   Transfer Ratio: [0.004]
# Iter 4400/5000 - Loss: 9142.411   Transfer Ratio: [0.004]
# Iter 4500/5000 - Loss: 16603.861   Transfer Ratio: [0.004]
# Iter 4600/5000 - Loss: 16042.001   Transfer Ratio: [0.004]
# Iter 4700/5000 - Loss: 17923.363   Transfer Ratio: [0.004]
# Iter 4800/5000 - Loss: 13483.333   Transfer Ratio: [0.004]
# Iter 4900/5000 - Loss: 14605.307   Transfer Ratio: [0.004]
# Iter 5000/5000 - Loss: 11300.211   Transfer Ratio: [0.004]
# *** P(Z|Y,X,W) and P(Y|W,Z)
# Iter 100/5000 - Loss: 381254.781   Transfer Ratio: [0.201]
# Iter 200/5000 - Loss: 140012.016   Transfer Ratio: [0.201]
# Iter 300/5000 - Loss: 119482.070   Transfer Ratio: [0.201]
# Iter 400/5000 - Loss: 111393.242   Transfer Ratio: [0.201]
# Iter 500/5000 - Loss: 108265.016   Transfer Ratio: [0.201]
# Iter 600/5000 - Loss: 106797.750   Transfer Ratio: [0.201]
# Iter 700/5000 - Loss: 106200.281   Transfer Ratio: [0.201]
# Iter 800/5000 - Loss: 105959.273   Transfer Ratio: [0.201]
# Iter 900/5000 - Loss: 105881.664   Transfer Ratio: [0.201]
# Iter 1000/5000 - Loss: 105842.227   Transfer Ratio: [0.201]
# Iter 1100/5000 - Loss: 105661.023   Transfer Ratio: [0.201]
# Iter 1200/5000 - Loss: 105938.094   Transfer Ratio: [0.201]
# Iter 1300/5000 - Loss: 105798.203   Transfer Ratio: [0.201]
# Iter 1400/5000 - Loss: 105570.680   Transfer Ratio: [0.201]
# Iter 1500/5000 - Loss: 105936.555   Transfer Ratio: [0.201]
# Iter 1600/5000 - Loss: 105758.750   Transfer Ratio: [0.201]
# Iter 1700/5000 - Loss: 105743.844   Transfer Ratio: [0.201]
# Iter 1800/5000 - Loss: 105970.367   Transfer Ratio: [0.201]
# Iter 1900/5000 - Loss: 107100.594   Transfer Ratio: [0.201]
# Iter 2000/5000 - Loss: 107121.586   Transfer Ratio: [0.201]
# Iter 2100/5000 - Loss: 107068.328   Transfer Ratio: [0.201]
# Iter 2200/5000 - Loss: 107110.812   Transfer Ratio: [0.201]
# Iter 2300/5000 - Loss: 107170.250   Transfer Ratio: [0.201]
# Iter 2400/5000 - Loss: 107482.633   Transfer Ratio: [0.201]
# Iter 2500/5000 - Loss: 107390.156   Transfer Ratio: [0.201]
# Iter 2600/5000 - Loss: 107669.977   Transfer Ratio: [0.201]
# Iter 2700/5000 - Loss: 107791.297   Transfer Ratio: [0.201]
# Iter 2800/5000 - Loss: 108104.539   Transfer Ratio: [0.201]
# Iter 2900/5000 - Loss: 108222.570   Transfer Ratio: [0.201]
# Iter 3000/5000 - Loss: 107935.625   Transfer Ratio: [0.201]
# Iter 3100/5000 - Loss: 108965.250   Transfer Ratio: [0.201]
# Iter 3200/5000 - Loss: 108501.766   Transfer Ratio: [0.201]
# Iter 3300/5000 - Loss: 109499.781   Transfer Ratio: [0.201]
# Iter 3400/5000 - Loss: 109989.859   Transfer Ratio: [0.201]
# Iter 3500/5000 - Loss: 110842.734   Transfer Ratio: [0.201]
# Iter 3600/5000 - Loss: 113955.391   Transfer Ratio: [0.201]
# Iter 3700/5000 - Loss: 184797.859   Transfer Ratio: [0.201]
# Iter 3800/5000 - Loss: 115071.469   Transfer Ratio: [0.201]
# Iter 3900/5000 - Loss: 108764.961   Transfer Ratio: [0.201]
# Iter 4000/5000 - Loss: 110002.688   Transfer Ratio: [0.201]
# Iter 4100/5000 - Loss: 109558.156   Transfer Ratio: [0.201]
# Iter 4200/5000 - Loss: 115664.281   Transfer Ratio: [0.201]
# Iter 4300/5000 - Loss: 111470.523   Transfer Ratio: [0.201]
# Iter 4400/5000 - Loss: 125529.195   Transfer Ratio: [0.201]
# Iter 4500/5000 - Loss: 114338.125   Transfer Ratio: [0.2]
# Iter 4600/5000 - Loss: 115798.391   Transfer Ratio: [0.2]
# Iter 4700/5000 - Loss: 113909.078   Transfer Ratio: [0.2]
# Iter 4800/5000 - Loss: 108904.859   Transfer Ratio: [0.2]
# Iter 4900/5000 - Loss: 108565.016   Transfer Ratio: [0.2]
# Iter 5000/5000 - Loss: 331088.500   Transfer Ratio: [0.2]
# ======================================================================================
# #Delta: 0.0, Replicate: 6
# ======================================================================================
# *** P(W|X)
# Iter 100/5000 - Loss: 17037.043   Transfer Ratio: [0.135]
# Iter 200/5000 - Loss: 35227.980   Transfer Ratio: [0.1]
# Iter 300/5000 - Loss: 17552.949   Transfer Ratio: [0.077]
# Iter 400/5000 - Loss: 11112.517   Transfer Ratio: [0.058]
# Iter 500/5000 - Loss: 11808.936   Transfer Ratio: [0.047]
# Iter 600/5000 - Loss: 32287.318   Transfer Ratio: [0.039]
# Iter 700/5000 - Loss: 9878.343   Transfer Ratio: [0.034]
# Iter 800/5000 - Loss: 20543.824   Transfer Ratio: [0.029]
# Iter 900/5000 - Loss: 17718.596   Transfer Ratio: [0.025]
# Iter 1000/5000 - Loss: 16888.611   Transfer Ratio: [0.023]
# Iter 1100/5000 - Loss: 31846.613   Transfer Ratio: [0.021]
# Iter 1200/5000 - Loss: 22625.088   Transfer Ratio: [0.018]
# Iter 1300/5000 - Loss: 24459.719   Transfer Ratio: [0.016]
# Iter 1400/5000 - Loss: 13476.317   Transfer Ratio: [0.014]
# Iter 1500/5000 - Loss: 11226.941   Transfer Ratio: [0.013]
# Iter 1600/5000 - Loss: 8811.054   Transfer Ratio: [0.013]
# Iter 1700/5000 - Loss: 11145.180   Transfer Ratio: [0.012]
# Iter 1800/5000 - Loss: 17570.348   Transfer Ratio: [0.011]
# Iter 1900/5000 - Loss: 27049.584   Transfer Ratio: [0.01]
# Iter 2000/5000 - Loss: 15889.425   Transfer Ratio: [0.01]
# Iter 2100/5000 - Loss: 10899.292   Transfer Ratio: [0.009]
# Iter 2200/5000 - Loss: 11526.636   Transfer Ratio: [0.009]
# Iter 2300/5000 - Loss: 28524.717   Transfer Ratio: [0.008]
# Iter 2400/5000 - Loss: 11134.075   Transfer Ratio: [0.008]
# Iter 2500/5000 - Loss: 18412.285   Transfer Ratio: [0.007]
# Iter 2600/5000 - Loss: 18786.422   Transfer Ratio: [0.007]
# Iter 2700/5000 - Loss: 8594.066   Transfer Ratio: [0.006]
# Iter 2800/5000 - Loss: 8723.122   Transfer Ratio: [0.006]
# Iter 2900/5000 - Loss: 14195.856   Transfer Ratio: [0.006]
# Iter 3000/5000 - Loss: 24186.072   Transfer Ratio: [0.006]
# Iter 3100/5000 - Loss: 17691.859   Transfer Ratio: [0.005]
# Iter 3200/5000 - Loss: 12408.327   Transfer Ratio: [0.005]
# Iter 3300/5000 - Loss: 18873.529   Transfer Ratio: [0.005]
# Iter 3400/5000 - Loss: 9942.501   Transfer Ratio: [0.004]
# Iter 3500/5000 - Loss: 13122.208   Transfer Ratio: [0.004]
# Iter 3600/5000 - Loss: 22974.895   Transfer Ratio: [0.004]
# Iter 3700/5000 - Loss: 11184.514   Transfer Ratio: [0.004]
# Iter 3800/5000 - Loss: 22117.465   Transfer Ratio: [0.003]
# Iter 3900/5000 - Loss: 11482.792   Transfer Ratio: [0.003]
# Iter 4000/5000 - Loss: 13271.257   Transfer Ratio: [0.003]
# Iter 4100/5000 - Loss: 8844.438   Transfer Ratio: [0.003]
# Iter 4200/5000 - Loss: 22962.982   Transfer Ratio: [0.003]
# Iter 4300/5000 - Loss: 23493.957   Transfer Ratio: [0.003]
# ...
# Iter 3400/5000 - Loss: 10398.913   Transfer Ratio: [0.004]
# Iter 3500/5000 - Loss: 20460.564   Transfer Ratio: [0.004]
# Iter 3600/5000 - Loss: 15833.921   Transfer Ratio: [0.004]
# Iter 3700/5000 - Loss: 15041.871   Transfer Ratio: [0.004]
# Iter 3800/5000 - Loss: 17366.992   Transfer Ratio: [0.003]
# Iter 3900/5000 - Loss: 27616.443   Transfer Ratio: [0.003]
# Iter 4000/5000 - Loss: 17902.012   Transfer Ratio: [0.003]
# Iter 4100/5000 - Loss: 11349.167   Transfer Ratio: [0.003]
# Iter 4200/5000 - Loss: 21343.057   Transfer Ratio: [0.003]
# Iter 4300/5000 - Loss: 31470.676   Transfer Ratio: [0.003]
# Iter 4400/5000 - Loss: 13831.583   Transfer Ratio: [0.002]
# Iter 4500/5000 - Loss: 10972.338   Transfer Ratio: [0.002]
# Iter 4600/5000 - Loss: 16156.122   Transfer Ratio: [0.002]
# Iter 4700/5000 - Loss: 12031.750   Transfer Ratio: [0.002]
# Iter 4800/5000 - Loss: 22758.307   Transfer Ratio: [0.002]
# Iter 4900/5000 - Loss: 14104.766   Transfer Ratio: [0.002]
# Iter 5000/5000 - Loss: 15722.428   Transfer Ratio: [0.002]
# *** P(Y|X,W)
# Iter 100/5000 - Loss: 18183.311   Transfer Ratio: [0.106]
# Iter 200/5000 - Loss: 10875.971   Transfer Ratio: [0.094]
# Iter 300/5000 - Loss: 15601.988   Transfer Ratio: [0.078]
# Iter 400/5000 - Loss: 8447.789   Transfer Ratio: [0.065]
# Iter 500/5000 - Loss: 13112.449   Transfer Ratio: [0.055]
# Iter 600/5000 - Loss: 15314.469   Transfer Ratio: [0.046]
# Iter 700/5000 - Loss: 18698.379   Transfer Ratio: [0.039]
# Iter 800/5000 - Loss: 10939.432   Transfer Ratio: [0.034]
# Iter 900/5000 - Loss: 12654.257   Transfer Ratio: [0.03]
# Iter 1000/5000 - Loss: 18078.271   Transfer Ratio: [0.026]
# Iter 1100/5000 - Loss: 11732.139   Transfer Ratio: [0.023]
# Iter 1200/5000 - Loss: 13366.886   Transfer Ratio: [0.021]
# Iter 1300/5000 - Loss: 15480.554   Transfer Ratio: [0.019]
# Iter 1400/5000 - Loss: 20354.801   Transfer Ratio: [0.018]
# Iter 1500/5000 - Loss: 13924.518   Transfer Ratio: [0.016]
# Iter 1600/5000 - Loss: 20682.885   Transfer Ratio: [0.015]
# Iter 1700/5000 - Loss: 9069.784   Transfer Ratio: [0.014]
# Iter 1800/5000 - Loss: 9543.730   Transfer Ratio: [0.013]
# Iter 1900/5000 - Loss: 10843.148   Transfer Ratio: [0.013]
# Iter 2000/5000 - Loss: 17407.607   Transfer Ratio: [0.012]
# Iter 2100/5000 - Loss: 14080.742   Transfer Ratio: [0.012]
# Iter 2200/5000 - Loss: 13088.647   Transfer Ratio: [0.011]
# Iter 2300/5000 - Loss: 14217.506   Transfer Ratio: [0.011]
# Iter 2400/5000 - Loss: 15699.362   Transfer Ratio: [0.01]
# Iter 2500/5000 - Loss: 4789.665   Transfer Ratio: [0.01]
# Iter 2600/5000 - Loss: 13420.777   Transfer Ratio: [0.009]
# Iter 2700/5000 - Loss: 11912.698   Transfer Ratio: [0.009]
# Iter 2800/5000 - Loss: 11156.230   Transfer Ratio: [0.009]
# Iter 2900/5000 - Loss: 11713.487   Transfer Ratio: [0.008]
# Iter 3000/5000 - Loss: 20937.461   Transfer Ratio: [0.008]
# Iter 3100/5000 - Loss: 14770.699   Transfer Ratio: [0.008]
# Iter 3200/5000 - Loss: 7951.084   Transfer Ratio: [0.007]
# Iter 3300/5000 - Loss: 30384.033   Transfer Ratio: [0.007]
# Iter 3400/5000 - Loss: 15401.720   Transfer Ratio: [0.006]
# Iter 3500/5000 - Loss: 11845.764   Transfer Ratio: [0.006]
# Iter 3600/5000 - Loss: 14842.310   Transfer Ratio: [0.005]
# Iter 3700/5000 - Loss: 18344.854   Transfer Ratio: [0.005]
# Iter 3800/5000 - Loss: 10445.612   Transfer Ratio: [0.005]
# Iter 3900/5000 - Loss: 13592.273   Transfer Ratio: [0.005]
# Iter 4000/5000 - Loss: 17490.441   Transfer Ratio: [0.005]
# Iter 4100/5000 - Loss: 24767.049   Transfer Ratio: [0.005]
# Iter 4200/5000 - Loss: 19654.582   Transfer Ratio: [0.004]
# Iter 4300/5000 - Loss: 18742.676   Transfer Ratio: [0.004]
# Iter 4400/5000 - Loss: 19445.547   Transfer Ratio: [0.004]
# Iter 4500/5000 - Loss: 15911.486   Transfer Ratio: [0.004]
# Iter 4600/5000 - Loss: 12378.896   Transfer Ratio: [0.004]
# Iter 4700/5000 - Loss: 19463.645   Transfer Ratio: [0.004]
# Iter 4800/5000 - Loss: 20054.740   Transfer Ratio: [0.004]
# Iter 4900/5000 - Loss: 12879.287   Transfer Ratio: [0.004]
# Iter 5000/5000 - Loss: 14500.124   Transfer Ratio: [0.004]
# *** P(Z|Y,X,W) and P(Y|W,Z)
# Iter 100/5000 - Loss: 383862.500   Transfer Ratio: [0.199]
# Iter 200/5000 - Loss: 139652.516   Transfer Ratio: [0.199]
# Iter 300/5000 - Loss: 119231.031   Transfer Ratio: [0.199]
# Iter 400/5000 - Loss: 111579.836   Transfer Ratio: [0.199]
# Iter 500/5000 - Loss: 108514.570   Transfer Ratio: [0.199]
# Iter 600/5000 - Loss: 107051.781   Transfer Ratio: [0.199]
# Iter 700/5000 - Loss: 106347.766   Transfer Ratio: [0.199]
# Iter 800/5000 - Loss: 106069.875   Transfer Ratio: [0.199]
# Iter 900/5000 - Loss: 105663.805   Transfer Ratio: [0.199]
# Iter 1000/5000 - Loss: 105671.328   Transfer Ratio: [0.199]
# Iter 1100/5000 - Loss: 105715.398   Transfer Ratio: [0.199]
# Iter 1200/5000 - Loss: 105898.711   Transfer Ratio: [0.199]
# Iter 1300/5000 - Loss: 105613.922   Transfer Ratio: [0.199]
# Iter 1400/5000 - Loss: 105922.688   Transfer Ratio: [0.199]
# Iter 1500/5000 - Loss: 106029.531   Transfer Ratio: [0.199]
# Iter 1600/5000 - Loss: 106002.664   Transfer Ratio: [0.199]
# Iter 1700/5000 - Loss: 106111.344   Transfer Ratio: [0.199]
# Iter 1800/5000 - Loss: 105551.453   Transfer Ratio: [0.199]
# Iter 1900/5000 - Loss: 106976.750   Transfer Ratio: [0.199]
# Iter 2000/5000 - Loss: 107177.078   Transfer Ratio: [0.199]
# Iter 2100/5000 - Loss: 107150.016   Transfer Ratio: [0.199]
# Iter 2200/5000 - Loss: 109712.328   Transfer Ratio: [0.199]
# Iter 2300/5000 - Loss: 107393.742   Transfer Ratio: [0.199]
# Iter 2400/5000 - Loss: 111608.773   Transfer Ratio: [0.199]
# Iter 2500/5000 - Loss: 109034.086   Transfer Ratio: [0.199]
# Iter 2600/5000 - Loss: 107470.148   Transfer Ratio: [0.199]
# Iter 2700/5000 - Loss: 107701.430   Transfer Ratio: [0.199]
# Iter 2800/5000 - Loss: 107837.961   Transfer Ratio: [0.199]
# Iter 2900/5000 - Loss: 107988.703   Transfer Ratio: [0.199]
# Iter 3000/5000 - Loss: 107865.266   Transfer Ratio: [0.199]
# Iter 3100/5000 - Loss: 108507.781   Transfer Ratio: [0.199]
# Iter 3200/5000 - Loss: 108048.820   Transfer Ratio: [0.199]
# Iter 3300/5000 - Loss: 108738.797   Transfer Ratio: [0.199]
# Iter 3400/5000 - Loss: 109050.391   Transfer Ratio: [0.199]
# Iter 3500/5000 - Loss: 109504.680   Transfer Ratio: [0.199]
# Iter 3600/5000 - Loss: 109878.461   Transfer Ratio: [0.199]
# Iter 3700/5000 - Loss: 107868.945   Transfer Ratio: [0.199]
# Iter 3800/5000 - Loss: 107810.539   Transfer Ratio: [0.199]
# Iter 3900/5000 - Loss: 107289.203   Transfer Ratio: [0.199]
# Iter 4000/5000 - Loss: 108045.500   Transfer Ratio: [0.199]
# Iter 4100/5000 - Loss: 108150.234   Transfer Ratio: [0.199]
# Iter 4200/5000 - Loss: 108324.383   Transfer Ratio: [0.199]
# Iter 4300/5000 - Loss: 118003.703   Transfer Ratio: [0.199]
# Iter 4400/5000 - Loss: 113641.523   Transfer Ratio: [0.199]
# Iter 4500/5000 - Loss: 118559.227   Transfer Ratio: [0.198]
# Iter 4600/5000 - Loss: 127431.375   Transfer Ratio: [0.198]
# Iter 4700/5000 - Loss: 146831.094   Transfer Ratio: [0.198]
# Iter 4800/5000 - Loss: 111359.141   Transfer Ratio: [0.198]
# Iter 4900/5000 - Loss: 111527.688   Transfer Ratio: [0.198]
# Iter 5000/5000 - Loss: 635073.000   Transfer Ratio: [0.198]
# ======================================================================================
# #Delta: 0.0, Replicate: 9
# ======================================================================================
# *** P(W|X)
# Iter 100/5000 - Loss: 32253.375   Transfer Ratio: [0.108]
# Iter 200/5000 - Loss: 9273.845   Transfer Ratio: [0.08]
# Iter 300/5000 - Loss: 30190.236   Transfer Ratio: [0.065]
# Iter 400/5000 - Loss: 7599.673   Transfer Ratio: [0.051]
# Iter 500/5000 - Loss: 8252.086   Transfer Ratio: [0.044]
# Iter 600/5000 - Loss: 9093.145   Transfer Ratio: [0.036]
# Iter 700/5000 - Loss: 20332.932   Transfer Ratio: [0.033]
# Iter 800/5000 - Loss: 9976.615   Transfer Ratio: [0.027]
# Iter 900/5000 - Loss: 25413.709   Transfer Ratio: [0.025]
# Iter 1000/5000 - Loss: 26145.375   Transfer Ratio: [0.021]
# Iter 1100/5000 - Loss: 12033.894   Transfer Ratio: [0.02]
# Iter 1200/5000 - Loss: 10619.737   Transfer Ratio: [0.018]
# Iter 1300/5000 - Loss: 9693.281   Transfer Ratio: [0.017]
# Iter 1400/5000 - Loss: 19995.334   Transfer Ratio: [0.016]
# Iter 1500/5000 - Loss: 19464.934   Transfer Ratio: [0.015]
# Iter 1600/5000 - Loss: 12323.488   Transfer Ratio: [0.013]
# Iter 1700/5000 - Loss: 28256.270   Transfer Ratio: [0.012]
# Iter 1800/5000 - Loss: 19884.979   Transfer Ratio: [0.011]
# Iter 1900/5000 - Loss: 23668.176   Transfer Ratio: [0.011]
# Iter 2000/5000 - Loss: 35529.785   Transfer Ratio: [0.01]
# Iter 2100/5000 - Loss: 9584.214   Transfer Ratio: [0.009]
# Iter 2200/5000 - Loss: 7713.793   Transfer Ratio: [0.009]
# Iter 2300/5000 - Loss: 10635.645   Transfer Ratio: [0.008]
# Iter 2400/5000 - Loss: 19456.785   Transfer Ratio: [0.007]
# Iter 2500/5000 - Loss: 9164.782   Transfer Ratio: [0.007]
# Iter 2600/5000 - Loss: 20210.035   Transfer Ratio: [0.006]
# Iter 2700/5000 - Loss: 9664.390   Transfer Ratio: [0.006]
# Iter 2800/5000 - Loss: 26913.148   Transfer Ratio: [0.006]
# Iter 2900/5000 - Loss: 25902.248   Transfer Ratio: [0.005]
# Iter 3000/5000 - Loss: 24999.607   Transfer Ratio: [0.005]
# Iter 3100/5000 - Loss: 9890.666   Transfer Ratio: [0.005]
# Iter 3200/5000 - Loss: 19531.748   Transfer Ratio: [0.004]
# Iter 3300/5000 - Loss: 8571.343   Transfer Ratio: [0.004]
# Iter 3400/5000 - Loss: 18811.840   Transfer Ratio: [0.004]
# Iter 3500/5000 - Loss: 20992.199   Transfer Ratio: [0.004]
# Iter 3600/5000 - Loss: 21088.719   Transfer Ratio: [0.004]
# Iter 3700/5000 - Loss: 18276.824   Transfer Ratio: [0.003]
# Iter 3800/5000 - Loss: 24213.305   Transfer Ratio: [0.003]
# Iter 3900/5000 - Loss: 23271.076   Transfer Ratio: [0.003]
# Iter 4000/5000 - Loss: 30444.041   Transfer Ratio: [0.003]
# Iter 4100/5000 - Loss: 9641.596   Transfer Ratio: [0.003]
# Iter 4200/5000 - Loss: 11751.985   Transfer Ratio: [0.003]
# Iter 4300/5000 - Loss: 13148.736   Transfer Ratio: [0.003]
# Iter 4400/5000 - Loss: 11253.122   Transfer Ratio: [0.002]
# Iter 4500/5000 - Loss: 14205.708   Transfer Ratio: [0.002]
# Iter 4600/5000 - Loss: 16406.199   Transfer Ratio: [0.002]
# Iter 4700/5000 - Loss: 11866.495   Transfer Ratio: [0.002]
# Iter 4800/5000 - Loss: 19857.256   Transfer Ratio: [0.002]
# Iter 4900/5000 - Loss: 15754.952   Transfer Ratio: [0.002]
# Iter 5000/5000 - Loss: 21982.475   Transfer Ratio: [0.002]
# *** P(Y|X,W)
# Iter 100/5000 - Loss: 13044.800   Transfer Ratio: [0.105]
# Iter 200/5000 - Loss: 14480.060   Transfer Ratio: [0.092]
# Iter 300/5000 - Loss: 14161.434   Transfer Ratio: [0.079]
# Iter 400/5000 - Loss: 21216.465   Transfer Ratio: [0.066]
# Iter 500/5000 - Loss: 16951.373   Transfer Ratio: [0.056]
# Iter 600/5000 - Loss: 7437.366   Transfer Ratio: [0.047]
# Iter 700/5000 - Loss: 19105.486   Transfer Ratio: [0.04]
# Iter 800/5000 - Loss: 15596.622   Transfer Ratio: [0.035]
# Iter 900/5000 - Loss: 17612.777   Transfer Ratio: [0.031]
# Iter 1000/5000 - Loss: 13292.122   Transfer Ratio: [0.027]
# Iter 1100/5000 - Loss: 19351.697   Transfer Ratio: [0.024]
# Iter 1200/5000 - Loss: 15683.221   Transfer Ratio: [0.022]
# Iter 1300/5000 - Loss: 13580.616   Transfer Ratio: [0.019]
# Iter 1400/5000 - Loss: 18029.805   Transfer Ratio: [0.018]
# Iter 1500/5000 - Loss: 18974.852   Transfer Ratio: [0.016]
# Iter 1600/5000 - Loss: 11404.116   Transfer Ratio: [0.015]
# Iter 1700/5000 - Loss: 26170.484   Transfer Ratio: [0.014]
# Iter 1800/5000 - Loss: 16028.636   Transfer Ratio: [0.013]
# Iter 1900/5000 - Loss: 12647.035   Transfer Ratio: [0.012]
# Iter 2000/5000 - Loss: 16815.494   Transfer Ratio: [0.011]
# Iter 2100/5000 - Loss: 17329.582   Transfer Ratio: [0.01]
# Iter 2200/5000 - Loss: 17862.559   Transfer Ratio: [0.01]
# Iter 2300/5000 - Loss: 10412.597   Transfer Ratio: [0.009]
# Iter 2400/5000 - Loss: 16817.785   Transfer Ratio: [0.009]
# Iter 2500/5000 - Loss: 24644.695   Transfer Ratio: [0.008]
# Iter 2600/5000 - Loss: 15681.284   Transfer Ratio: [0.008]
# Iter 2700/5000 - Loss: 11642.296   Transfer Ratio: [0.007]
# Iter 2800/5000 - Loss: 23067.783   Transfer Ratio: [0.007]
# Iter 2900/5000 - Loss: 24496.805   Transfer Ratio: [0.007]
# Iter 3000/5000 - Loss: 15156.932   Transfer Ratio: [0.007]
# Iter 3100/5000 - Loss: 22430.002   Transfer Ratio: [0.007]
# Iter 3200/5000 - Loss: 21974.693   Transfer Ratio: [0.007]
# Iter 3300/5000 - Loss: 12653.465   Transfer Ratio: [0.007]
# Iter 3400/5000 - Loss: 20650.875   Transfer Ratio: [0.006]
# Iter 3500/5000 - Loss: 12726.256   Transfer Ratio: [0.006]
# Iter 3600/5000 - Loss: 18726.543   Transfer Ratio: [0.006]
# Iter 3700/5000 - Loss: 14802.146   Transfer Ratio: [0.006]
# Iter 3800/5000 - Loss: 18108.277   Transfer Ratio: [0.006]
# Iter 3900/5000 - Loss: 17085.068   Transfer Ratio: [0.006]
# Iter 4000/5000 - Loss: 15394.256   Transfer Ratio: [0.006]
# Iter 4100/5000 - Loss: 18633.018   Transfer Ratio: [0.005]
# Iter 4200/5000 - Loss: 16575.332   Transfer Ratio: [0.005]
# Iter 4300/5000 - Loss: 13984.458   Transfer Ratio: [0.005]
# Iter 4400/5000 - Loss: 11678.382   Transfer Ratio: [0.005]
# Iter 4500/5000 - Loss: 16641.760   Transfer Ratio: [0.005]
# Iter 4600/5000 - Loss: 12704.790   Transfer Ratio: [0.004]
# Iter 4700/5000 - Loss: 19203.059   Transfer Ratio: [0.004]
# Iter 4800/5000 - Loss: 19530.191   Transfer Ratio: [0.004]
# Iter 4900/5000 - Loss: 21054.961   Transfer Ratio: [0.004]
# Iter 5000/5000 - Loss: 8055.309   Transfer Ratio: [0.003]
# *** P(Z|Y,X,W) and P(Y|W,Z)
# Iter 100/5000 - Loss: 388722.562   Transfer Ratio: [0.2]
# Iter 200/5000 - Loss: 139825.391   Transfer Ratio: [0.199]
# Iter 300/5000 - Loss: 119292.375   Transfer Ratio: [0.199]
# Iter 400/5000 - Loss: 111352.891   Transfer Ratio: [0.2]
# Iter 500/5000 - Loss: 108392.898   Transfer Ratio: [0.2]
# Iter 600/5000 - Loss: 106986.727   Transfer Ratio: [0.2]
# Iter 700/5000 - Loss: 106171.539   Transfer Ratio: [0.2]
# Iter 800/5000 - Loss: 105854.461   Transfer Ratio: [0.2]
# Iter 900/5000 - Loss: 105641.258   Transfer Ratio: [0.2]
# Iter 1000/5000 - Loss: 105573.492   Transfer Ratio: [0.2]
# Iter 1100/5000 - Loss: 105630.875   Transfer Ratio: [0.2]
# Iter 1200/5000 - Loss: 105863.719   Transfer Ratio: [0.2]
# Iter 1300/5000 - Loss: 106029.438   Transfer Ratio: [0.2]
# Iter 1400/5000 - Loss: 105799.828   Transfer Ratio: [0.2]
# Iter 1500/5000 - Loss: 105293.953   Transfer Ratio: [0.2]
# Iter 1600/5000 - Loss: 106114.742   Transfer Ratio: [0.2]
# Iter 1700/5000 - Loss: 109388.062   Transfer Ratio: [0.2]
# Iter 1800/5000 - Loss: 105690.203   Transfer Ratio: [0.2]
# Iter 1900/5000 - Loss: 105676.625   Transfer Ratio: [0.2]
# Iter 2000/5000 - Loss: 108231.820   Transfer Ratio: [0.2]
# Iter 2100/5000 - Loss: 106767.367   Transfer Ratio: [0.2]
# Iter 2200/5000 - Loss: 107849.602   Transfer Ratio: [0.2]
# Iter 2300/5000 - Loss: 110596.516   Transfer Ratio: [0.2]
# Iter 2400/5000 - Loss: 107073.156   Transfer Ratio: [0.2]
# Iter 2500/5000 - Loss: 108243.523   Transfer Ratio: [0.2]
# Iter 2600/5000 - Loss: 107170.078   Transfer Ratio: [0.2]
# Iter 2700/5000 - Loss: 107746.320   Transfer Ratio: [0.2]
# Iter 2800/5000 - Loss: 107465.320   Transfer Ratio: [0.2]
# Iter 2900/5000 - Loss: 107903.234   Transfer Ratio: [0.2]
# Iter 3000/5000 - Loss: 108177.422   Transfer Ratio: [0.2]
# Iter 3100/5000 - Loss: 108450.977   Transfer Ratio: [0.2]
# Iter 3200/5000 - Loss: 108578.656   Transfer Ratio: [0.2]
# Iter 3300/5000 - Loss: 108543.406   Transfer Ratio: [0.2]
# Iter 3400/5000 - Loss: 108792.586   Transfer Ratio: [0.2]
# Iter 3500/5000 - Loss: 109353.125   Transfer Ratio: [0.2]
# Iter 3600/5000 - Loss: 109621.914   Transfer Ratio: [0.2]
# Iter 3700/5000 - Loss: 110161.406   Transfer Ratio: [0.2]
# Iter 3800/5000 - Loss: 108157.398   Transfer Ratio: [0.2]
# Iter 3900/5000 - Loss: 107694.016   Transfer Ratio: [0.199]
# Iter 4000/5000 - Loss: 109873.883   Transfer Ratio: [0.199]
# Iter 4100/5000 - Loss: 113107.750   Transfer Ratio: [0.199]
# Iter 4200/5000 - Loss: 126003.773   Transfer Ratio: [0.199]
# Iter 4300/5000 - Loss: 112247.648   Transfer Ratio: [0.199]
# Iter 4400/5000 - Loss: 112437.758   Transfer Ratio: [0.199]
# Iter 4500/5000 - Loss: 123257.906   Transfer Ratio: [0.199]
# Iter 4600/5000 - Loss: 117692.094   Transfer Ratio: [0.199]
# Iter 4700/5000 - Loss: 106484.844   Transfer Ratio: [0.199]
# Iter 4800/5000 - Loss: 110528.602   Transfer Ratio: [0.199]
# Iter 4900/5000 - Loss: 111837.930   Transfer Ratio: [0.199]
# Iter 5000/5000 - Loss: 408852.688   Transfer Ratio: [0.198]

# %% [markdown]
# ### Print $\epsilon_{\text{ATE}}, \sqrt{\epsilon_{\text{PEHE}}}$

# %%
learn_transfer_stats_mean = np.array([np.mean(test_stats,axis=0) for test_stats in learn_transfer_test_stats_lst])
learn_transfer_stats_stderr = np.array([stats.sem(test_stats,axis=0) for test_stats in learn_transfer_test_stats_lst])
learn_transfer_stats_mean
# Out:
# array([[0.00704312, 0.30221926]])
